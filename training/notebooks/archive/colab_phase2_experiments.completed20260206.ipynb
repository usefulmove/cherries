# %% [markdown]
# # Phase 2: SOTA Optimization Experiments
#
# This notebook executes the updated Phase 2 experimental roadmap incorporating external research feedback:
#
# **New State-of-the-Art Experiments:**
# 1. **EXP-001**: Threshold Optimization (CPU, 4-6 hours)
# 2. **EXP-002A**: ConvNeXt V2-Tiny Baseline (GPU, ~12 hours) - *FCMAE pre-training*
# 3. **EXP-002B**: ConvNeXt V2-Tiny + Label Smoothing (GPU, ~12 hours)
# 4. **EXP-003A**: EfficientNet-B2 Baseline (GPU, ~10 hours) - *Speed-focused*
# 5. **EXP-003B**: EfficientNet-B2 + Label Smoothing (GPU, ~10 hours)
# 6. **EXP-006A**: DINOv2 ViT-S/14 Linear Probe (GPU, ~4 hours) - *Foundation model*
#
# **Key Improvements:**
# - **Enhanced augmentations**: Motion blur + stronger color jitter for conveyor realism
# - **ConvNeXt V2**: Upgraded from V1 to V2 with FCMAE pre-training (better for defects)
# - **DINOv2**: Foundation model approach with frozen backbone + linear probe
#
# **Current Baseline:**
# - ResNet50: 94.05% accuracy, 16ms latency, 25.6M params
#
# **Target:**
# - Accuracy: ≥94.5% (stretch: 95%)
# - Pit Recall: ≥99.0% (food safety)
# - Latency: <30ms on CPU
#
# **Prerequisites:**
# - Google Colab Pro (GPU required for training experiments)
# - Baseline model uploaded to Google Drive
# - Data in Drive at: `cherry_classification/data/`

# %% [markdown]
# ## Cell 1: Experiment Configuration
#
# Set skip flags to control which experiments run. Use `SMOKE_TEST=True` for quick validation (1 epoch, 3 batches).

# %%
# === EXPERIMENT CONFIGURATION ===
# Set these flags to control execution

SMOKE_TEST = False  # Set True for quick validation (1 epoch, 3 batches)

# Skip flags - set True to skip already completed experiments
SKIP_EXP_001 = False    # Threshold optimization (CPU only)
SKIP_EXP_002A = False   # ConvNeXt V2-Tiny baseline (NEW - Phase 2)
SKIP_EXP_002B = False   # ConvNeXt V2-Tiny + label smoothing (NEW)
SKIP_EXP_003A = False   # EfficientNet-B2 baseline
SKIP_EXP_003B = False   # EfficientNet-B2 + label smoothing
SKIP_EXP_006A = False   # DINOv2 ViT-S/14 linear probe (NEW - Phase 2)

# Random seed for reproducibility
RANDOM_SEED = 42

# Paths (adjust for your Drive structure)
DRIVE_MOUNT_PATH = "/content/drive"
DRIVE_BASE_PATH = "/content/drive/MyDrive/cherry_experiments"
DATA_PATH = "/content/cherry_classification/data"
BASELINE_MODEL_PATH = "/content/drive/MyDrive/cherry_experiments/resnet50_augmented_unnormalized/model_best_fixed.pt"

# Print configuration
print("=" * 60)
print("EXPERIMENT CONFIGURATION - Phase 2 SOTA")
print("=" * 60)
print(f"SMOKE_TEST: {SMOKE_TEST}")
print(f"RANDOM_SEED: {RANDOM_SEED}")
print("\nPhase 2 NEW Experiments:")
print(f"  EXP-002A (ConvNeXt V2 baseline): {SKIP_EXP_002A}")
print(f"  EXP-002B (ConvNeXt V2 + LS): {SKIP_EXP_002B}")
print(f"  EXP-006A (DINOv2 linear probe): {SKIP_EXP_006A}")
print("\nOther Experiments:")
print(f"  EXP-001 (Threshold opt): {SKIP_EXP_001}")
print(f"  EXP-003A (EfficientNet B2): {SKIP_EXP_003A}")
print(f"  EXP-003B (EfficientNet B2 + LS): {SKIP_EXP_003B}")
print("=" * 60)
# Out:
# ============================================================
# EXPERIMENT CONFIGURATION - Phase 2 SOTA
# ============================================================
# SMOKE_TEST: False
# RANDOM_SEED: 42
#
# Phase 2 NEW Experiments:
#   EXP-002A (ConvNeXt V2 baseline): False
#   EXP-002B (ConvNeXt V2 + LS): False
#   EXP-006A (DINOv2 linear probe): False
#
# Other Experiments:
#   EXP-001 (Threshold opt): False
#   EXP-003A (EfficientNet B2): False
#   EXP-003B (EfficientNet B2 + LS): False
# ============================================================

# %% [markdown]
# ## Cell 2: Environment Setup & Dependencies
#
# Install required packages including `timm` for ConvNeXt V2 support.

# %%
# Install dependencies
print("Installing dependencies...")
# !pip install -q pyyaml scikit-learn matplotlib tqdm

# NEW: Install timm for ConvNeXt V2
print("Installing timm for ConvNeXt V2...")
# !pip install -q timm

# Verify installations
import importlib

print("\n" + "=" * 60)
print("DEPENDENCY CHECK")
print("=" * 60)

# Check timm
try:
    import timm
    print(f"✓ timm installed: {timm.__version__}")
except ImportError:
    print("✗ timm not available - ConvNeXt V2 will fail")

# Check torch
import torch
print(f"✓ PyTorch: {torch.__version__}")
print("=" * 60)
# Out:
# Installing dependencies...
# Installing timm for ConvNeXt V2...
#
# ============================================================
# DEPENDENCY CHECK
# ============================================================
# ✓ timm installed: 1.0.24
# ✓ PyTorch: 2.9.0+cu126
# ============================================================

# %% [markdown]
# ## Cell 3: GPU Check & Drive Mount

# %%
# Mount Google Drive
from google.colab import drive
drive.mount(DRIVE_MOUNT_PATH, force_remount=True)

# Check GPU availability
print("\n" + "=" * 60)
print("GPU CHECK")
print("=" * 60)
print(f"CUDA available: {torch.cuda.is_available()}")

if not torch.cuda.is_available():
    # Check if we're running training experiments
    needs_gpu = not (SKIP_EXP_002A and SKIP_EXP_002B and SKIP_EXP_003A and SKIP_EXP_003B and SKIP_EXP_006A)

    if needs_gpu:
        raise RuntimeError(
            "\n" + "!" * 60 + "\n" +
            "GPU REQUIRED FOR TRAINING EXPERIMENTS!\n" +
            "Go to: Runtime -> Change runtime type -> GPU\n" +
            "Then re-run this cell.\n" +
            "!" * 60
        )
    else:
        print("WARNING: No GPU available, but only running EXP-001 (CPU). Continuing...")
else:
    print(f"CUDA version: {torch.version.cuda}")
    print(f"GPU: {torch.cuda.get_device_name(0)}")
    print(f"GPU memory: {torch.cuda.get_device_properties(0).total_memory / 1e9:.2f} GB")

print("=" * 60)
# Out:
# Mounted at /content/drive
#
# ============================================================
# GPU CHECK
# ============================================================
# CUDA available: True
# CUDA version: 12.6
# GPU: NVIDIA A100-SXM4-80GB
# GPU memory: 85.17 GB
# ============================================================

# %% [markdown]
# ## Cell 4: Clone Repositories

# %%
# Clone training repository
# !if [ ! -d "/content/cherries" ]; then \
    git clone https://github.com/usefulmove/cherries.git /content/cherries; \
else \
    cd /content/cherries && git pull; \
fi

# Clone dataset repository (shallow clone)
# !if [ ! -d "/content/cherry_classification" ]; then \
    git clone --depth 1 https://github.com/weshavener/cherry_classification.git /content/cherry_classification; \
fi

# Add training scripts to path
import sys
sys.path.insert(0, '/content/cherries/training')

# Create output directories
import os
from pathlib import Path

output_dirs = [
    f"{DRIVE_BASE_PATH}/threshold_optimization",
    f"{DRIVE_BASE_PATH}/convnextv2_tiny_baseline_seed42",  # NEW: ConvNeXt V2
    f"{DRIVE_BASE_PATH}/convnextv2_tiny_label_smooth_seed42",
    f"{DRIVE_BASE_PATH}/efficientnet_b2_baseline_seed42",
    f"{DRIVE_BASE_PATH}/efficientnet_b2_label_smooth_seed42",
    f"{DRIVE_BASE_PATH}/dinov2_vits14_linear_probe_seed42",  # NEW: DINOv2
]

for dir_path in output_dirs:
    Path(dir_path).mkdir(parents=True, exist_ok=True)

print("\n" + "=" * 60)
print("SETUP COMPLETE")
print("=" * 60)
print(f"Training code: /content/traina")
print(f"Data: {DATA_PATH}")
print(f"Output base: {DRIVE_BASE_PATH}")

# Verify data exists
if not os.path.exists(DATA_PATH):
    print(f"\nWARNING: Data not found at {DATA_PATH}")
else:
    print(f"\nData verified: {DATA_PATH}")
    # !ls -lh {DATA_PATH}
print("=" * 60)
# Out:
# Already up to date.
#
# ============================================================
# SETUP COMPLETE
# ============================================================
# Training code: /content/traina
# Data: /content/cherry_classification/data
# Output base: /content/drive/MyDrive/cherry_experiments
#
# Data verified: /content/cherry_classification/data
# total 8.0K
# drwxr-xr-x 4 root root 4.0K Feb  7 06:11 train
# drwxr-xr-x 4 root root 4.0K Feb  7 06:11 val
# ============================================================

# %% [markdown]
# ## Cell 5: EXP-001 - Threshold Optimization
#
# **Type:** Analysis (no training)
# **Duration:** 4-6 hours
# **Requires:** Baseline model (94.05% ResNet50)
#
# Find optimal decision boundaries for 3-class classification (clean/pit/maybe).

# %%
if SKIP_EXP_001:
    print("EXP-001: SKIPPED (set SKIP_EXP_001=False to run)")
else:
    print("\n" + "=" * 60)
    print("RUNNING EXP-001: Threshold Optimization")
    print("=" * 60)

    # Verify baseline model exists
    if not os.path.exists(BASELINE_MODEL_PATH):
        print(f"ERROR: Baseline model not found: {BASELINE_MODEL_PATH}")
        print("Please upload the 94.05% ResNet50 model to Google Drive")
        print("Expected location: MyDrive/cherry_experiments/resnet50_augmented_unnormalized/model_best_fixed.pt")
    else:
        output_dir = f"{DRIVE_BASE_PATH}/threshold_optimization"

        # Run threshold optimization
        # !python /content/cherries/training/scripts/optimize_thresholds.py \
            --model-path {BASELINE_MODEL_PATH} \
            --data-root {DATA_PATH} \
            --architecture resnet50 \
            --output-dir {output_dir} \
            --min-recall 0.99 \
            --device cpu

        print("\n" + "=" * 60)
        print(f"Results saved to: {output_dir}")
        print("\nKey files to download:")
        print("  - threshold_results.json")
        print("  - optimal_thresholds.yaml")
        print("  - threshold_analysis.png")
        print("  - probability_distributions.png")
        print("=" * 60)
# Out:
# ============================================================
# RUNNING EXP-001: Threshold Optimization
# ============================================================
# ERROR: Baseline model not found: /content/drive/MyDrive/cherry_experiments/resnet50_augmented_unnormalized/model_best_fixed.pt
# Please upload the 94.05% ResNet50 model to Google Drive
# Expected location: MyDrive/cherry_experiments/resnet50_augmented_unnormalized/model_best_fixed.pt

# %% [markdown]
# ## Cell 6: EXP-002A - ConvNeXt V2-Tiny Baseline (NEW - Phase 2)
#
# **Type:** Training
# **Duration:** ~12 hours (30 epochs)
# **Architecture:** ConvNeXt V2-Tiny with FCMAE pre-training (via timm)
# **Key Feature:** Enhanced augmentations with motion blur for conveyor realism
# **Hypothesis:** FCMAE pre-training superior for defect detection, ≥94.5% accuracy

# %%
if SKIP_EXP_002A:
    print("EXP-002A: SKIPPED (set SKIP_EXP_002A=False to run)")
else:
    print("\n" + "=" * 60)
    print("RUNNING EXP-002A: ConvNeXt V2-Tiny Baseline (Phase 2)")
    print("Features: FCMAE pre-training, AdamW optimizer, enhanced augmentations")
    print("=" * 60)

    # Set random seed
    import random
    import numpy as np

    random.seed(RANDOM_SEED)
    np.random.seed(RANDOM_SEED)
    torch.manual_seed(RANDOM_SEED)
    if torch.cuda.is_available():
        torch.cuda.manual_seed_all(RANDOM_SEED)

    print(f"Random seed set: {RANDOM_SEED}")

    # Load config
    import yaml

    config_path = "/content/cherries/training/configs/experiments/convnextv2_tiny_baseline_seed42.yaml"

    with open(config_path, 'r') as f:
        config = yaml.safe_load(f)

    # Override paths for Colab
    config['checkpointing']['output_dir'] = f"{DRIVE_BASE_PATH}/convnextv2_tiny_baseline_seed42"
    config['data']['root'] = DATA_PATH

    # Apply smoke test settings
    if SMOKE_TEST:
        print("\nSMOKE TEST MODE: 1 epoch, 3 batches")
        config['training']['epochs'] = 1
        config['checkpointing']['save_every'] = 1

    # Save temp config
    temp_config = "/tmp/convnextv2_tiny_baseline_seed42.yaml"
    with open(temp_config, 'w') as f:
        yaml.dump(config, f)

    # Run training
    # !python /content/cherries/training/scripts/train.py \
        --config {temp_config} \
        --data-root {DATA_PATH}

    print("\n" + "=" * 60)
    print(f"Training complete! Results: {config['checkpointing']['output_dir']}")
    print("\nKey files to download:")
    print("  - model_best.pt")
    print("  - metrics.json")
    print("=" * 60)
# Out:
# ============================================================
# RUNNING EXP-002A: ConvNeXt V2-Tiny Baseline (Phase 2)
# Features: FCMAE pre-training, AdamW optimizer, enhanced augmentations
# ============================================================
# Random seed set: 42
# Using cache found in /root/.cache/torch/hub/facebookresearch_dinov2_main
# /root/.cache/torch/hub/facebookresearch_dinov2_main/dinov2/layers/swiglu_ffn.py:51: UserWarning: xFormers is not available (SwiGLU)
#   warnings.warn("xFormers is not available (SwiGLU)")
# /root/.cache/torch/hub/facebookresearch_dinov2_main/dinov2/layers/attention.py:33: UserWarning: xFormers is not available (Attention)
#   warnings.warn("xFormers is not available (Attention)")
# /root/.cache/torch/hub/facebookresearch_dinov2_main/dinov2/layers/block.py:40: UserWarning: xFormers is not available (Block)
#   warnings.warn("xFormers is not available (Block)")
#
# Loading config from: /tmp/convnextv2_tiny_baseline_seed42.yaml
# Output directory: /content/drive/MyDrive/cherry_experiments/convnextv2_tiny_baseline_seed42
# Config saved to: /content/drive/MyDrive/cherry_experiments/convnextv2_tiny_baseline_seed42/config.yaml
# Using device: cuda
#
# ============================================================
# LOADING DATA
# ============================================================
#
# Dataset loaded from: /content/cherry_classification/data
# Training samples: 3676
# Validation samples: 1226
# Classes: ['cherry_clean', 'cherry_pit']
# Class distribution (train): {'cherry_clean': 1978, 'cherry_pit': 1698}
# Class distribution (val): {'cherry_clean': 660, 'cherry_pit': 566}
#
# Class names: ['cherry_clean', 'cherry_pit']
#
# ============================================================
# CREATING MODEL
# ============================================================
# Architecture: convnextv2_tiny
# Loaded convnextv2_tiny.fcmae_ft_in1k with FCMAE pre-training
# Model moved to device: cuda
# Optimizer: adamw
# Learning rate: 0.0001
# Weight decay: 0.05
# Using scheduler: cosine
# Using standard CrossEntropyLoss (no label smoothing)
#
# ============================================================
# STARTING TRAINING
# ============================================================
# Training for 30 epochs
# Starting from epoch 0
#
# ============================================================
# EPOCH 1/30
# ============================================================
# Epoch [1] Batch [10/114] Loss: 0.3945
# Epoch [1] Batch [20/114] Loss: 0.4568
# Epoch [1] Batch [30/114] Loss: 0.1339
# Epoch [1] Batch [40/114] Loss: 0.1004
# Epoch [1] Batch [50/114] Loss: 0.3799
# Epoch [1] Batch [60/114] Loss: 0.2722
# Epoch [1] Batch [70/114] Loss: 0.2818
# Epoch [1] Batch [80/114] Loss: 0.4654
# Epoch [1] Batch [90/114] Loss: 0.2232
# Epoch [1] Batch [100/114] Loss: 0.1218
# Epoch [1] Batch [110/114] Loss: 0.2445
#
# Training Loss: 0.3362
# Validation Loss: 0.2308
# Stepped scheduler. New LR: 0.000100
#
# ============================================================
# Epoch 1 - VAL
# ============================================================
# Accuracy:  0.9135
# Precision: 0.9133
# Recall:    0.9127
# F1 Score:  0.9130
#
# Confusion Matrix:
# [[610  50]
#  [ 56 510]]
#
# Per-Class Metrics:
#   cherry_clean:
#     Precision: 0.9159
#     Recall:    0.9242
#     F1:        0.9201
#   cherry_pit:
#     Precision: 0.9107
#     Recall:    0.9011
#     F1:        0.9059
# ============================================================
#
# Model weights saved: /content/drive/MyDrive/cherry_experiments/convnextv2_tiny_baseline_seed42/model_best.pt
#
# New best model saved! Validation accuracy: 0.9135
#
# Epoch completed in 15.0 seconds
#
# ============================================================
# EPOCH 2/30
# ============================================================
# Epoch [2] Batch [10/114] Loss: 0.1972
# Epoch [2] Batch [20/114] Loss: 0.3524
# Epoch [2] Batch [30/114] Loss: 0.2136
# Epoch [2] Batch [40/114] Loss: 0.1590
# Epoch [2] Batch [50/114] Loss: 0.0932
# Epoch [2] Batch [60/114] Loss: 0.2444
# Epoch [2] Batch [70/114] Loss: 0.3871
# Epoch [2] Batch [80/114] Loss: 0.4031
# Epoch [2] Batch [90/114] Loss: 0.1784
# Epoch [2] Batch [100/114] Loss: 0.2999
# Epoch [2] Batch [110/114] Loss: 0.2354
#
# Training Loss: 0.2495
# Validation Loss: 0.2713
# Stepped scheduler. New LR: 0.000099
#
# ============================================================
# Epoch 2 - VAL
# ============================================================
# Accuracy:  0.8972
# Precision: 0.9152
# Recall:    0.8896
# F1 Score:  0.8942
#
# Confusion Matrix:
# [[653   7]
#  [119 447]]
#
# Per-Class Metrics:
#   cherry_clean:
#     Precision: 0.8459
#     Recall:    0.9894
#     F1:        0.9120
#   cherry_pit:
#     Precision: 0.9846
#     Recall:    0.7898
#     F1:        0.8765
# ============================================================
#
#
# Epoch completed in 9.6 seconds
#
# ============================================================
# EPOCH 3/30
# ============================================================
# Epoch [3] Batch [10/114] Loss: 0.3903
# Epoch [3] Batch [20/114] Loss: 0.2288
# Epoch [3] Batch [30/114] Loss: 0.1716
# Epoch [3] Batch [40/114] Loss: 0.1686
# Epoch [3] Batch [50/114] Loss: 0.2087
# Epoch [3] Batch [60/114] Loss: 0.4315
# Epoch [3] Batch [70/114] Loss: 0.1341
# Epoch [3] Batch [80/114] Loss: 0.1461
# Epoch [3] Batch [90/114] Loss: 0.1400
# Epoch [3] Batch [100/114] Loss: 0.1192
# Epoch [3] Batch [110/114] Loss: 0.1899
#
# Training Loss: 0.2271
# Validation Loss: 0.2097
# Stepped scheduler. New LR: 0.000098
#
# ============================================================
# Epoch 3 - VAL
# ============================================================
# Accuracy:  0.9103
# Precision: 0.9105
# Recall:    0.9089
# F1 Score:  0.9096
#
# Confusion Matrix:
# [[612  48]
#  [ 62 504]]
#
# Per-Class Metrics:
#   cherry_clean:
#     Precision: 0.9080
#     Recall:    0.9273
#     F1:        0.9175
#   cherry_pit:
#     Precision: 0.9130
#     Recall:    0.8905
#     F1:        0.9016
# ============================================================
#
#
# Epoch completed in 7.8 seconds
#
# ============================================================
# EPOCH 4/30
# ============================================================
# Epoch [4] Batch [10/114] Loss: 0.2189
# Epoch [4] Batch [20/114] Loss: 0.1017
# Epoch [4] Batch [30/114] Loss: 0.2514
# Epoch [4] Batch [40/114] Loss: 0.2671
# Epoch [4] Batch [50/114] Loss: 0.2462
# Epoch [4] Batch [60/114] Loss: 0.3831
# Epoch [4] Batch [70/114] Loss: 0.1367
# Epoch [4] Batch [80/114] Loss: 0.2419
# Epoch [4] Batch [90/114] Loss: 0.1489
# Epoch [4] Batch [100/114] Loss: 0.1077
# Epoch [4] Batch [110/114] Loss: 0.1220
#
# Training Loss: 0.2227
# Validation Loss: 0.1962
# Stepped scheduler. New LR: 0.000096
#
# ============================================================
# Epoch 4 - VAL
# ============================================================
# Accuracy:  0.9299
# Precision: 0.9350
# Recall:    0.9262
# F1 Score:  0.9288
#
# Confusion Matrix:
# [[643  17]
#  [ 69 497]]
#
# Per-Class Metrics:
#   cherry_clean:
#     Precision: 0.9031
#     Recall:    0.9742
#     F1:        0.9373
#   cherry_pit:
#     Precision: 0.9669
#     Recall:    0.8781
#     F1:        0.9204
# ============================================================
#
# Model weights saved: /content/drive/MyDrive/cherry_experiments/convnextv2_tiny_baseline_seed42/model_best.pt
#
# New best model saved! Validation accuracy: 0.9299
#
# Epoch completed in 8.1 seconds
#
# ============================================================
# EPOCH 5/30
# ============================================================
# Epoch [5] Batch [10/114] Loss: 0.2333
# Epoch [5] Batch [20/114] Loss: 0.3497
# Epoch [5] Batch [30/114] Loss: 0.1333
# Epoch [5] Batch [40/114] Loss: 0.1580
# Epoch [5] Batch [50/114] Loss: 0.3189
# Epoch [5] Batch [60/114] Loss: 0.2374
# Epoch [5] Batch [70/114] Loss: 0.2541
# Epoch [5] Batch [80/114] Loss: 0.2565
# Epoch [5] Batch [90/114] Loss: 0.2685
# Epoch [5] Batch [100/114] Loss: 0.1144
# Epoch [5] Batch [110/114] Loss: 0.1166
#
# Training Loss: 0.2431
# Validation Loss: 0.2564
# Stepped scheduler. New LR: 0.000093
#
# ============================================================
# Epoch 5 - VAL
# ============================================================
# Accuracy:  0.8980
# Precision: 0.9170
# Recall:    0.8902
# F1 Score:  0.8950
#
# Confusion Matrix:
# [[655   5]
#  [120 446]]
#
# Per-Class Metrics:
#   cherry_clean:
#     Precision: 0.8452
#     Recall:    0.9924
#     F1:        0.9129
#   cherry_pit:
#     Precision: 0.9889
#     Recall:    0.7880
#     F1:        0.8771
# ============================================================
#
# Checkpoint saved: /content/drive/MyDrive/cherry_experiments/convnextv2_tiny_baseline_seed42/checkpoint_epoch_5.pt
#
# Epoch completed in 10.7 seconds
#
# ============================================================
# EPOCH 6/30
# ============================================================
# Epoch [6] Batch [10/114] Loss: 0.2097
# Epoch [6] Batch [20/114] Loss: 0.2559
# Epoch [6] Batch [30/114] Loss: 0.1062
# Epoch [6] Batch [40/114] Loss: 0.3487
# Epoch [6] Batch [50/114] Loss: 0.2121
# Epoch [6] Batch [60/114] Loss: 0.2854
# Epoch [6] Batch [70/114] Loss: 0.1532
# Epoch [6] Batch [80/114] Loss: 0.3380
# Epoch [6] Batch [90/114] Loss: 0.1040
# Epoch [6] Batch [100/114] Loss: 0.1857
# Epoch [6] Batch [110/114] Loss: 0.2513
#
# Training Loss: 0.2141
# Validation Loss: 0.2183
# Stepped scheduler. New LR: 0.000090
#
# ============================================================
# Epoch 6 - VAL
# ============================================================
# Accuracy:  0.9299
# Precision: 0.9368
# Recall:    0.9255
# F1 Score:  0.9287
#
# Confusion Matrix:
# [[648  12]
#  [ 74 492]]
#
# Per-Class Metrics:
#   cherry_clean:
#     Precision: 0.8975
#     Recall:    0.9818
#     F1:        0.9378
#   cherry_pit:
#     Precision: 0.9762
#     Recall:    0.8693
#     F1:        0.9196
# ============================================================
#
#
# Epoch completed in 7.9 seconds
#
# ============================================================
# EPOCH 7/30
# ============================================================
# Epoch [7] Batch [10/114] Loss: 0.1999
# Epoch [7] Batch [20/114] Loss: 0.2805
# Epoch [7] Batch [30/114] Loss: 0.4240
# Epoch [7] Batch [40/114] Loss: 0.2290
# Epoch [7] Batch [50/114] Loss: 0.2275
# Epoch [7] Batch [60/114] Loss: 0.1441
# Epoch [7] Batch [70/114] Loss: 0.2261
# Epoch [7] Batch [80/114] Loss: 0.1937
# Epoch [7] Batch [90/114] Loss: 0.0639
# Epoch [7] Batch [100/114] Loss: 0.2458
# Epoch [7] Batch [110/114] Loss: 0.0979
#
# Training Loss: 0.2081
# Validation Loss: 0.1916
# Stepped scheduler. New LR: 0.000087
#
# ============================================================
# Epoch 7 - VAL
# ============================================================
# Accuracy:  0.9258
# Precision: 0.9258
# Recall:    0.9248
# F1 Score:  0.9252
#
# Confusion Matrix:
# [[619  41]
#  [ 50 516]]
#
# Per-Class Metrics:
#   cherry_clean:
#     Precision: 0.9253
#     Recall:    0.9379
#     F1:        0.9315
#   cherry_pit:
#     Precision: 0.9264
#     Recall:    0.9117
#     F1:        0.9190
# ============================================================
#
#
# Epoch completed in 7.7 seconds
#
# ============================================================
# EPOCH 8/30
# ============================================================
# Epoch [8] Batch [10/114] Loss: 0.1845
# Epoch [8] Batch [20/114] Loss: 0.4114
# Epoch [8] Batch [30/114] Loss: 0.2872
# Epoch [8] Batch [40/114] Loss: 0.2374
# Epoch [8] Batch [50/114] Loss: 0.1521
# Epoch [8] Batch [60/114] Loss: 0.1283
# Epoch [8] Batch [70/114] Loss: 0.1039
# Epoch [8] Batch [80/114] Loss: 0.2211
# Epoch [8] Batch [90/114] Loss: 0.2928
# Epoch [8] Batch [100/114] Loss: 0.4514
# Epoch [8] Batch [110/114] Loss: 0.2644
#
# Training Loss: 0.2075
# Validation Loss: 0.2104
# Stepped scheduler. New LR: 0.000083
#
# ============================================================
# Epoch 8 - VAL
# ============================================================
# Accuracy:  0.9152
# Precision: 0.9246
# Recall:    0.9099
# F1 Score:  0.9135
#
# Confusion Matrix:
# [[646  14]
#  [ 90 476]]
#
# Per-Class Metrics:
#   cherry_clean:
#     Precision: 0.8777
#     Recall:    0.9788
#     F1:        0.9255
#   cherry_pit:
#     Precision: 0.9714
#     Recall:    0.8410
#     F1:        0.9015
# ============================================================
#
#
# Epoch completed in 7.8 seconds
#
# ============================================================
# EPOCH 9/30
# ============================================================
# Epoch [9] Batch [10/114] Loss: 0.2390
# Epoch [9] Batch [20/114] Loss: 0.2042
# Epoch [9] Batch [30/114] Loss: 0.0921
# Epoch [9] Batch [40/114] Loss: 0.5586
# Epoch [9] Batch [50/114] Loss: 0.1058
# Epoch [9] Batch [60/114] Loss: 0.4817
# Epoch [9] Batch [70/114] Loss: 0.2218
# Epoch [9] Batch [80/114] Loss: 0.1426
# Epoch [9] Batch [90/114] Loss: 0.1264
# Epoch [9] Batch [100/114] Loss: 0.4240
# Epoch [9] Batch [110/114] Loss: 0.0654
#
# Training Loss: 0.1963
# Validation Loss: 0.2024
# Stepped scheduler. New LR: 0.000079
#
# ============================================================
# Epoch 9 - VAL
# ============================================================
# Accuracy:  0.9209
# Precision: 0.9274
# Recall:    0.9166
# F1 Score:  0.9196
#
# Confusion Matrix:
# [[642  18]
#  [ 79 487]]
#
# Per-Class Metrics:
#   cherry_clean:
#     Precision: 0.8904
#     Recall:    0.9727
#     F1:        0.9298
#   cherry_pit:
#     Precision: 0.9644
#     Recall:    0.8604
#     F1:        0.9094
# ============================================================
#
#
# Epoch completed in 7.8 seconds
#
# ============================================================
# EPOCH 10/30
# ============================================================
# Epoch [10] Batch [10/114] Loss: 0.2289
# Epoch [10] Batch [20/114] Loss: 0.0945
# Epoch [10] Batch [30/114] Loss: 0.2292
# Epoch [10] Batch [40/114] Loss: 0.1039
# Epoch [10] Batch [50/114] Loss: 0.1957
# Epoch [10] Batch [60/114] Loss: 0.2477
# Epoch [10] Batch [70/114] Loss: 0.2689
# Epoch [10] Batch [80/114] Loss: 0.2162
# Epoch [10] Batch [90/114] Loss: 0.1095
# Epoch [10] Batch [100/114] Loss: 0.2194
# Epoch [10] Batch [110/114] Loss: 0.1700
#
# Training Loss: 0.1965
# Validation Loss: 0.1964
# Stepped scheduler. New LR: 0.000075
#
# ============================================================
# Epoch 10 - VAL
# ============================================================
# Accuracy:  0.9135
# Precision: 0.9131
# Recall:    0.9129
# F1 Score:  0.9130
#
# Confusion Matrix:
# [[608  52]
#  [ 54 512]]
#
# Per-Class Metrics:
#   cherry_clean:
#     Precision: 0.9184
#     Recall:    0.9212
#     F1:        0.9198
#   cherry_pit:
#     Precision: 0.9078
#     Recall:    0.9046
#     F1:        0.9062
# ============================================================
#
# Checkpoint saved: /content/drive/MyDrive/cherry_experiments/convnextv2_tiny_baseline_seed42/checkpoint_epoch_10.pt
#
# Epoch completed in 8.6 seconds
#
# ============================================================
# EPOCH 11/30
# ============================================================
# Epoch [11] Batch [10/114] Loss: 0.3355
# Epoch [11] Batch [20/114] Loss: 0.0964
# Epoch [11] Batch [30/114] Loss: 0.1356
# Epoch [11] Batch [40/114] Loss: 0.2171
# Epoch [11] Batch [50/114] Loss: 0.2524
# Epoch [11] Batch [60/114] Loss: 0.2222
# Epoch [11] Batch [70/114] Loss: 0.1130
# Epoch [11] Batch [80/114] Loss: 0.2946
# Epoch [11] Batch [90/114] Loss: 0.3226
# Epoch [11] Batch [100/114] Loss: 0.2821
# Epoch [11] Batch [110/114] Loss: 0.1268
#
# Training Loss: 0.1926
# Validation Loss: 0.1993
# Stepped scheduler. New LR: 0.000070
#
# ============================================================
# Epoch 11 - VAL
# ============================================================
# Accuracy:  0.9290
# Precision: 0.9337
# Recall:    0.9255
# F1 Score:  0.9281
#
# Confusion Matrix:
# [[641  19]
#  [ 68 498]]
#
# Per-Class Metrics:
#   cherry_clean:
#     Precision: 0.9041
#     Recall:    0.9712
#     F1:        0.9364
#   cherry_pit:
#     Precision: 0.9632
#     Recall:    0.8799
#     F1:        0.9197
# ============================================================
#
#
# Epoch completed in 8.3 seconds
#
# ============================================================
# EPOCH 12/30
# ============================================================
# Epoch [12] Batch [10/114] Loss: 0.2213
# Epoch [12] Batch [20/114] Loss: 0.1091
# Epoch [12] Batch [30/114] Loss: 0.2062
# Epoch [12] Batch [40/114] Loss: 0.1768
# Epoch [12] Batch [50/114] Loss: 0.2352
# Epoch [12] Batch [60/114] Loss: 0.1699
# Epoch [12] Batch [70/114] Loss: 0.1442
# Epoch [12] Batch [80/114] Loss: 0.1756
# Epoch [12] Batch [90/114] Loss: 0.2645
# Epoch [12] Batch [100/114] Loss: 0.1842
# Epoch [12] Batch [110/114] Loss: 0.2532
#
# Training Loss: 0.1819
# Validation Loss: 0.1672
# Stepped scheduler. New LR: 0.000065
#
# ============================================================
# Epoch 12 - VAL
# ============================================================
# Accuracy:  0.9315
# Precision: 0.9329
# Recall:    0.9296
# F1 Score:  0.9308
#
# Confusion Matrix:
# [[630  30]
#  [ 54 512]]
#
# Per-Class Metrics:
#   cherry_clean:
#     Precision: 0.9211
#     Recall:    0.9545
#     F1:        0.9375
#   cherry_pit:
#     Precision: 0.9446
#     Recall:    0.9046
#     F1:        0.9242
# ============================================================
#
# Model weights saved: /content/drive/MyDrive/cherry_experiments/convnextv2_tiny_baseline_seed42/model_best.pt
#
# New best model saved! Validation accuracy: 0.9315
#
# Epoch completed in 8.1 seconds
#
# ============================================================
# EPOCH 13/30
# ============================================================
# Epoch [13] Batch [10/114] Loss: 0.0861
# Epoch [13] Batch [20/114] Loss: 0.1524
# Epoch [13] Batch [30/114] Loss: 0.3389
# Epoch [13] Batch [40/114] Loss: 0.1184
# Epoch [13] Batch [50/114] Loss: 0.1028
# Epoch [13] Batch [60/114] Loss: 0.2069
# Epoch [13] Batch [70/114] Loss: 0.0823
# Epoch [13] Batch [80/114] Loss: 0.1227
# Epoch [13] Batch [90/114] Loss: 0.0886
# Epoch [13] Batch [100/114] Loss: 0.2508
# Epoch [13] Batch [110/114] Loss: 0.1327
#
# Training Loss: 0.1764
# Validation Loss: 0.1892
# Stepped scheduler. New LR: 0.000060
#
# ============================================================
# Epoch 13 - VAL
# ============================================================
# Accuracy:  0.9282
# Precision: 0.9321
# Recall:    0.9250
# F1 Score:  0.9273
#
# Confusion Matrix:
# [[638  22]
#  [ 66 500]]
#
# Per-Class Metrics:
#   cherry_clean:
#     Precision: 0.9062
#     Recall:    0.9667
#     F1:        0.9355
#   cherry_pit:
#     Precision: 0.9579
#     Recall:    0.8834
#     F1:        0.9191
# ============================================================
#
#
# Epoch completed in 7.8 seconds
#
# ============================================================
# EPOCH 14/30
# ============================================================
# Epoch [14] Batch [10/114] Loss: 0.1515
# Epoch [14] Batch [20/114] Loss: 0.0519
# Epoch [14] Batch [30/114] Loss: 0.1733
# Epoch [14] Batch [40/114] Loss: 0.1405
# Epoch [14] Batch [50/114] Loss: 0.2014
# Epoch [14] Batch [60/114] Loss: 0.3179
# Epoch [14] Batch [70/114] Loss: 0.1120
# Epoch [14] Batch [80/114] Loss: 0.1234
# Epoch [14] Batch [90/114] Loss: 0.2421
# Epoch [14] Batch [100/114] Loss: 0.1656
# Epoch [14] Batch [110/114] Loss: 0.1730
#
# Training Loss: 0.1664
# Validation Loss: 0.1798
# Stepped scheduler. New LR: 0.000055
#
# ============================================================
# Epoch 14 - VAL
# ============================================================
# Accuracy:  0.9315
# Precision: 0.9345
# Recall:    0.9287
# F1 Score:  0.9307
#
# Confusion Matrix:
# [[637  23]
#  [ 61 505]]
#
# Per-Class Metrics:
#   cherry_clean:
#     Precision: 0.9126
#     Recall:    0.9652
#     F1:        0.9381
#   cherry_pit:
#     Precision: 0.9564
#     Recall:    0.8922
#     F1:        0.9232
# ============================================================
#
#
# Epoch completed in 7.8 seconds
#
# ============================================================
# EPOCH 15/30
# ============================================================
# Epoch [15] Batch [10/114] Loss: 0.1576
# Epoch [15] Batch [20/114] Loss: 0.1270
# Epoch [15] Batch [30/114] Loss: 0.2490
# Epoch [15] Batch [40/114] Loss: 0.1096
# Epoch [15] Batch [50/114] Loss: 0.0465
# Epoch [15] Batch [60/114] Loss: 0.1710
# Epoch [15] Batch [70/114] Loss: 0.1529
# Epoch [15] Batch [80/114] Loss: 0.2897
# Epoch [15] Batch [90/114] Loss: 0.0470
# Epoch [15] Batch [100/114] Loss: 0.1202
# Epoch [15] Batch [110/114] Loss: 0.0444
#
# Training Loss: 0.1624
# Validation Loss: 0.2030
# Stepped scheduler. New LR: 0.000050
#
# ============================================================
# Epoch 15 - VAL
# ============================================================
# Accuracy:  0.9250
# Precision: 0.9339
# Recall:    0.9200
# F1 Score:  0.9236
#
# Confusion Matrix:
# [[650  10]
#  [ 82 484]]
#
# Per-Class Metrics:
#   cherry_clean:
#     Precision: 0.8880
#     Recall:    0.9848
#     F1:        0.9339
#   cherry_pit:
#     Precision: 0.9798
#     Recall:    0.8551
#     F1:        0.9132
# ============================================================
#
# Checkpoint saved: /content/drive/MyDrive/cherry_experiments/convnextv2_tiny_baseline_seed42/checkpoint_epoch_15.pt
#
# Epoch completed in 8.4 seconds
#
# ============================================================
# EPOCH 16/30
# ============================================================
# Epoch [16] Batch [10/114] Loss: 0.1362
# Epoch [16] Batch [20/114] Loss: 0.1645
# Epoch [16] Batch [30/114] Loss: 0.0320
# Epoch [16] Batch [40/114] Loss: 0.1239
# Epoch [16] Batch [50/114] Loss: 0.4567
# Epoch [16] Batch [60/114] Loss: 0.1679
# Epoch [16] Batch [70/114] Loss: 0.1755
# Epoch [16] Batch [80/114] Loss: 0.1203
# Epoch [16] Batch [90/114] Loss: 0.1075
# Epoch [16] Batch [100/114] Loss: 0.4541
# Epoch [16] Batch [110/114] Loss: 0.1162
#
# Training Loss: 0.1570
# Validation Loss: 0.1837
# Stepped scheduler. New LR: 0.000045
#
# ============================================================
# Epoch 16 - VAL
# ============================================================
# Accuracy:  0.9323
# Precision: 0.9342
# Recall:    0.9301
# F1 Score:  0.9316
#
# Confusion Matrix:
# [[633  27]
#  [ 56 510]]
#
# Per-Class Metrics:
#   cherry_clean:
#     Precision: 0.9187
#     Recall:    0.9591
#     F1:        0.9385
#   cherry_pit:
#     Precision: 0.9497
#     Recall:    0.9011
#     F1:        0.9248
# ============================================================
#
# Model weights saved: /content/drive/MyDrive/cherry_experiments/convnextv2_tiny_baseline_seed42/model_best.pt
#
# New best model saved! Validation accuracy: 0.9323
#
# Epoch completed in 8.1 seconds
#
# ============================================================
# EPOCH 17/30
# ============================================================
# Epoch [17] Batch [10/114] Loss: 0.1095
# Epoch [17] Batch [20/114] Loss: 0.1054
# Epoch [17] Batch [30/114] Loss: 0.2797
# Epoch [17] Batch [40/114] Loss: 0.0913
# Epoch [17] Batch [50/114] Loss: 0.2223
# Epoch [17] Batch [60/114] Loss: 0.2212
# Epoch [17] Batch [70/114] Loss: 0.0837
# Epoch [17] Batch [80/114] Loss: 0.1141
# Epoch [17] Batch [90/114] Loss: 0.1410
# Epoch [17] Batch [100/114] Loss: 0.1409
# Epoch [17] Batch [110/114] Loss: 0.1558
#
# Training Loss: 0.1573
# Validation Loss: 0.2131
# Stepped scheduler. New LR: 0.000040
#
# ============================================================
# Epoch 17 - VAL
# ============================================================
# Accuracy:  0.9290
# Precision: 0.9358
# Recall:    0.9248
# F1 Score:  0.9279
#
# Confusion Matrix:
# [[647  13]
#  [ 74 492]]
#
# Per-Class Metrics:
#   cherry_clean:
#     Precision: 0.8974
#     Recall:    0.9803
#     F1:        0.9370
#   cherry_pit:
#     Precision: 0.9743
#     Recall:    0.8693
#     F1:        0.9188
# ============================================================
#
#
# Epoch completed in 7.8 seconds
#
# ============================================================
# EPOCH 18/30
# ============================================================
# Epoch [18] Batch [10/114] Loss: 0.2070
# Epoch [18] Batch [20/114] Loss: 0.0456
# Epoch [18] Batch [30/114] Loss: 0.1291
# Epoch [18] Batch [40/114] Loss: 0.1968
# Epoch [18] Batch [50/114] Loss: 0.1483
# Epoch [18] Batch [60/114] Loss: 0.1921
# Epoch [18] Batch [70/114] Loss: 0.1490
# Epoch [18] Batch [80/114] Loss: 0.0484
# Epoch [18] Batch [90/114] Loss: 0.0631
# Epoch [18] Batch [100/114] Loss: 0.2459
# Epoch [18] Batch [110/114] Loss: 0.1990
#
# Training Loss: 0.1539
# Validation Loss: 0.2005
# Stepped scheduler. New LR: 0.000035
#
# ============================================================
# Epoch 18 - VAL
# ============================================================
# Accuracy:  0.9315
# Precision: 0.9370
# Recall:    0.9277
# F1 Score:  0.9305
#
# Confusion Matrix:
# [[645  15]
#  [ 69 497]]
#
# Per-Class Metrics:
#   cherry_clean:
#     Precision: 0.9034
#     Recall:    0.9773
#     F1:        0.9389
#   cherry_pit:
#     Precision: 0.9707
#     Recall:    0.8781
#     F1:        0.9221
# ============================================================
#
#
# Epoch completed in 7.7 seconds
#
# ============================================================
# EPOCH 19/30
# ============================================================
# Epoch [19] Batch [10/114] Loss: 0.1307
# Epoch [19] Batch [20/114] Loss: 0.2235
# Epoch [19] Batch [30/114] Loss: 0.4398
# Epoch [19] Batch [40/114] Loss: 0.2248
# Epoch [19] Batch [50/114] Loss: 0.2026
# Epoch [19] Batch [60/114] Loss: 0.2372
# Epoch [19] Batch [70/114] Loss: 0.0493
# Epoch [19] Batch [80/114] Loss: 0.1925
# Epoch [19] Batch [90/114] Loss: 0.0744
# Epoch [19] Batch [100/114] Loss: 0.2620
# Epoch [19] Batch [110/114] Loss: 0.0841
#
# Training Loss: 0.1452
# Validation Loss: 0.1727
# Stepped scheduler. New LR: 0.000030
#
# ============================================================
# Epoch 19 - VAL
# ============================================================
# Accuracy:  0.9331
# Precision: 0.9352
# Recall:    0.9308
# F1 Score:  0.9324
#
# Confusion Matrix:
# [[634  26]
#  [ 56 510]]
#
# Per-Class Metrics:
#   cherry_clean:
#     Precision: 0.9188
#     Recall:    0.9606
#     F1:        0.9393
#   cherry_pit:
#     Precision: 0.9515
#     Recall:    0.9011
#     F1:        0.9256
# ============================================================
#
# Model weights saved: /content/drive/MyDrive/cherry_experiments/convnextv2_tiny_baseline_seed42/model_best.pt
#
# New best model saved! Validation accuracy: 0.9331
#
# Epoch completed in 8.1 seconds
#
# ============================================================
# EPOCH 20/30
# ============================================================
# Epoch [20] Batch [10/114] Loss: 0.0725
# Epoch [20] Batch [20/114] Loss: 0.0503
# Epoch [20] Batch [30/114] Loss: 0.1249
# Epoch [20] Batch [40/114] Loss: 0.2415
# Epoch [20] Batch [50/114] Loss: 0.2924
# Epoch [20] Batch [60/114] Loss: 0.0371
# Epoch [20] Batch [70/114] Loss: 0.1466
# Epoch [20] Batch [80/114] Loss: 0.0383
# Epoch [20] Batch [90/114] Loss: 0.0250
# Epoch [20] Batch [100/114] Loss: 0.1160
# Epoch [20] Batch [110/114] Loss: 0.1772
#
# Training Loss: 0.1369
# Validation Loss: 0.1853
# Stepped scheduler. New LR: 0.000025
#
# ============================================================
# Epoch 20 - VAL
# ============================================================
# Accuracy:  0.9315
# Precision: 0.9340
# Recall:    0.9289
# F1 Score:  0.9307
#
# Confusion Matrix:
# [[635  25]
#  [ 59 507]]
#
# Per-Class Metrics:
#   cherry_clean:
#     Precision: 0.9150
#     Recall:    0.9621
#     F1:        0.9380
#   cherry_pit:
#     Precision: 0.9530
#     Recall:    0.8958
#     F1:        0.9235
# ============================================================
#
# Checkpoint saved: /content/drive/MyDrive/cherry_experiments/convnextv2_tiny_baseline_seed42/checkpoint_epoch_20.pt
#
# Epoch completed in 10.6 seconds
#
# ============================================================
# EPOCH 21/30
# ============================================================
# Epoch [21] Batch [10/114] Loss: 0.1129
# Epoch [21] Batch [20/114] Loss: 0.0609
# Epoch [21] Batch [30/114] Loss: 0.1952
# Epoch [21] Batch [40/114] Loss: 0.1394
# Epoch [21] Batch [50/114] Loss: 0.2316
# Epoch [21] Batch [60/114] Loss: 0.1320
# Epoch [21] Batch [70/114] Loss: 0.0843
# Epoch [21] Batch [80/114] Loss: 0.2683
# Epoch [21] Batch [90/114] Loss: 0.0594
# Epoch [21] Batch [100/114] Loss: 0.1432
# Epoch [21] Batch [110/114] Loss: 0.2353
#
# Training Loss: 0.1275
# Validation Loss: 0.1815
# Stepped scheduler. New LR: 0.000021
#
# ============================================================
# Epoch 21 - VAL
# ============================================================
# Accuracy:  0.9290
# Precision: 0.9307
# Recall:    0.9269
# F1 Score:  0.9283
#
# Confusion Matrix:
# [[630  30]
#  [ 57 509]]
#
# Per-Class Metrics:
#   cherry_clean:
#     Precision: 0.9170
#     Recall:    0.9545
#     F1:        0.9354
#   cherry_pit:
#     Precision: 0.9443
#     Recall:    0.8993
#     F1:        0.9213
# ============================================================
#
#
# Epoch completed in 7.8 seconds
#
# ============================================================
# EPOCH 22/30
# ============================================================
# Epoch [22] Batch [10/114] Loss: 0.1290
# Epoch [22] Batch [20/114] Loss: 0.0963
# Epoch [22] Batch [30/114] Loss: 0.0667
# Epoch [22] Batch [40/114] Loss: 0.0629
# Epoch [22] Batch [50/114] Loss: 0.2442
# Epoch [22] Batch [60/114] Loss: 0.2666
# Epoch [22] Batch [70/114] Loss: 0.0522
# Epoch [22] Batch [80/114] Loss: 0.2208
# Epoch [22] Batch [90/114] Loss: 0.0718
# Epoch [22] Batch [100/114] Loss: 0.1141
# Epoch [22] Batch [110/114] Loss: 0.0911
#
# Training Loss: 0.1246
# Validation Loss: 0.1740
# Stepped scheduler. New LR: 0.000017
#
# ============================================================
# Epoch 22 - VAL
# ============================================================
# Accuracy:  0.9421
# Precision: 0.9426
# Recall:    0.9409
# F1 Score:  0.9416
#
# Confusion Matrix:
# [[631  29]
#  [ 42 524]]
#
# Per-Class Metrics:
#   cherry_clean:
#     Precision: 0.9376
#     Recall:    0.9561
#     F1:        0.9467
#   cherry_pit:
#     Precision: 0.9476
#     Recall:    0.9258
#     F1:        0.9366
# ============================================================
#
# Model weights saved: /content/drive/MyDrive/cherry_experiments/convnextv2_tiny_baseline_seed42/model_best.pt
#
# New best model saved! Validation accuracy: 0.9421
#
# Epoch completed in 8.1 seconds
#
# ============================================================
# EPOCH 23/30
# ============================================================
# Epoch [23] Batch [10/114] Loss: 0.0594
# Epoch [23] Batch [20/114] Loss: 0.1506
# Epoch [23] Batch [30/114] Loss: 0.0256
# Epoch [23] Batch [40/114] Loss: 0.0629
# Epoch [23] Batch [50/114] Loss: 0.0860
# Epoch [23] Batch [60/114] Loss: 0.1648
# Epoch [23] Batch [70/114] Loss: 0.0830
# Epoch [23] Batch [80/114] Loss: 0.0481
# Epoch [23] Batch [90/114] Loss: 0.0955
# Epoch [23] Batch [100/114] Loss: 0.1124
# Epoch [23] Batch [110/114] Loss: 0.1077
#
# Training Loss: 0.1166
# Validation Loss: 0.1909
# Stepped scheduler. New LR: 0.000013
#
# ============================================================
# Epoch 23 - VAL
# ============================================================
# Accuracy:  0.9339
# Precision: 0.9374
# Recall:    0.9310
# F1 Score:  0.9331
#
# Confusion Matrix:
# [[640  20]
#  [ 61 505]]
#
# Per-Class Metrics:
#   cherry_clean:
#     Precision: 0.9130
#     Recall:    0.9697
#     F1:        0.9405
#   cherry_pit:
#     Precision: 0.9619
#     Recall:    0.8922
#     F1:        0.9258
# ============================================================
#
#
# Epoch completed in 7.7 seconds
#
# ============================================================
# EPOCH 24/30
# ============================================================
# Epoch [24] Batch [10/114] Loss: 0.1917
# Epoch [24] Batch [20/114] Loss: 0.2653
# Epoch [24] Batch [30/114] Loss: 0.1738
# Epoch [24] Batch [40/114] Loss: 0.3208
# Epoch [24] Batch [50/114] Loss: 0.1458
# Epoch [24] Batch [60/114] Loss: 0.0747
# Epoch [24] Batch [70/114] Loss: 0.1468
# Epoch [24] Batch [80/114] Loss: 0.0784
# Epoch [24] Batch [90/114] Loss: 0.1430
# Epoch [24] Batch [100/114] Loss: 0.1364
# Epoch [24] Batch [110/114] Loss: 0.2612
#
# Training Loss: 0.1144
# Validation Loss: 0.1771
# Stepped scheduler. New LR: 0.000010
#
# ============================================================
# Epoch 24 - VAL
# ============================================================
# Accuracy:  0.9372
# Precision: 0.9380
# Recall:    0.9358
# F1 Score:  0.9367
#
# Confusion Matrix:
# [[630  30]
#  [ 47 519]]
#
# Per-Class Metrics:
#   cherry_clean:
#     Precision: 0.9306
#     Recall:    0.9545
#     F1:        0.9424
#   cherry_pit:
#     Precision: 0.9454
#     Recall:    0.9170
#     F1:        0.9309
# ============================================================
#
#
# Epoch completed in 7.7 seconds
#
# ============================================================
# EPOCH 25/30
# ============================================================
# Epoch [25] Batch [10/114] Loss: 0.0143
# Epoch [25] Batch [20/114] Loss: 0.0573
# Epoch [25] Batch [30/114] Loss: 0.0534
# Epoch [25] Batch [40/114] Loss: 0.1077
# Epoch [25] Batch [50/114] Loss: 0.1080
# Epoch [25] Batch [60/114] Loss: 0.1893
# Epoch [25] Batch [70/114] Loss: 0.0718
# Epoch [25] Batch [80/114] Loss: 0.1197
# Epoch [25] Batch [90/114] Loss: 0.1135
# Epoch [25] Batch [100/114] Loss: 0.1290
# Epoch [25] Batch [110/114] Loss: 0.0653
#
# Training Loss: 0.1077
# Validation Loss: 0.1804
# Stepped scheduler. New LR: 0.000007
#
# ============================================================
# Epoch 25 - VAL
# ============================================================
# Accuracy:  0.9339
# Precision: 0.9339
# Recall:    0.9331
# F1 Score:  0.9335
#
# Confusion Matrix:
# [[623  37]
#  [ 44 522]]
#
# Per-Class Metrics:
#   cherry_clean:
#     Precision: 0.9340
#     Recall:    0.9439
#     F1:        0.9390
#   cherry_pit:
#     Precision: 0.9338
#     Recall:    0.9223
#     F1:        0.9280
# ============================================================
#
# Checkpoint saved: /content/drive/MyDrive/cherry_experiments/convnextv2_tiny_baseline_seed42/checkpoint_epoch_25.pt
#
# Epoch completed in 8.4 seconds
#
# ============================================================
# EPOCH 26/30
# ============================================================
# Epoch [26] Batch [10/114] Loss: 0.2046
# Epoch [26] Batch [20/114] Loss: 0.0621
# Epoch [26] Batch [30/114] Loss: 0.1251
# Epoch [26] Batch [40/114] Loss: 0.0946
# Epoch [26] Batch [50/114] Loss: 0.1622
# Epoch [26] Batch [60/114] Loss: 0.0068
# Epoch [26] Batch [70/114] Loss: 0.1404
# Epoch [26] Batch [80/114] Loss: 0.3154
# Epoch [26] Batch [90/114] Loss: 0.0970
# Epoch [26] Batch [100/114] Loss: 0.1844
# Epoch [26] Batch [110/114] Loss: 0.0850
#
# Training Loss: 0.1094
# Validation Loss: 0.1825
# Stepped scheduler. New LR: 0.000004
#
# ============================================================
# Epoch 26 - VAL
# ============================================================
# Accuracy:  0.9356
# Precision: 0.9369
# Recall:    0.9337
# F1 Score:  0.9350
#
# Confusion Matrix:
# [[632  28]
#  [ 51 515]]
#
# Per-Class Metrics:
#   cherry_clean:
#     Precision: 0.9253
#     Recall:    0.9576
#     F1:        0.9412
#   cherry_pit:
#     Precision: 0.9484
#     Recall:    0.9099
#     F1:        0.9288
# ============================================================
#
#
# Epoch completed in 7.7 seconds
#
# ============================================================
# EPOCH 27/30
# ============================================================
# Epoch [27] Batch [10/114] Loss: 0.0353
# Epoch [27] Batch [20/114] Loss: 0.0375
# Epoch [27] Batch [30/114] Loss: 0.1160
# Epoch [27] Batch [40/114] Loss: 0.0247
# Epoch [27] Batch [50/114] Loss: 0.1506
# Epoch [27] Batch [60/114] Loss: 0.2225
# Epoch [27] Batch [70/114] Loss: 0.1342
# Epoch [27] Batch [80/114] Loss: 0.0433
# Epoch [27] Batch [90/114] Loss: 0.1423
# Epoch [27] Batch [100/114] Loss: 0.0320
# Epoch [27] Batch [110/114] Loss: 0.1767
#
# Training Loss: 0.1057
# Validation Loss: 0.1837
# Stepped scheduler. New LR: 0.000002
#
# ============================================================
# Epoch 27 - VAL
# ============================================================
# Accuracy:  0.9364
# Precision: 0.9366
# Recall:    0.9354
# F1 Score:  0.9359
#
# Confusion Matrix:
# [[626  34]
#  [ 44 522]]
#
# Per-Class Metrics:
#   cherry_clean:
#     Precision: 0.9343
#     Recall:    0.9485
#     F1:        0.9414
#   cherry_pit:
#     Precision: 0.9388
#     Recall:    0.9223
#     F1:        0.9305
# ============================================================
#
#
# Epoch completed in 7.9 seconds
#
# ============================================================
# EPOCH 28/30
# ============================================================
# Epoch [28] Batch [10/114] Loss: 0.1263
# Epoch [28] Batch [20/114] Loss: 0.0905
# Epoch [28] Batch [30/114] Loss: 0.0266
# Epoch [28] Batch [40/114] Loss: 0.1218
# Epoch [28] Batch [50/114] Loss: 0.0317
# Epoch [28] Batch [60/114] Loss: 0.1437
# Epoch [28] Batch [70/114] Loss: 0.0829
# Epoch [28] Batch [80/114] Loss: 0.2258
# Epoch [28] Batch [90/114] Loss: 0.2044
# Epoch [28] Batch [100/114] Loss: 0.1228
# Epoch [28] Batch [110/114] Loss: 0.0639
#
# Training Loss: 0.0967
# Validation Loss: 0.1854
# Stepped scheduler. New LR: 0.000001
#
# ============================================================
# Epoch 28 - VAL
# ============================================================
# Accuracy:  0.9388
# Precision: 0.9396
# Recall:    0.9374
# F1 Score:  0.9383
#
# Confusion Matrix:
# [[631  29]
#  [ 46 520]]
#
# Per-Class Metrics:
#   cherry_clean:
#     Precision: 0.9321
#     Recall:    0.9561
#     F1:        0.9439
#   cherry_pit:
#     Precision: 0.9472
#     Recall:    0.9187
#     F1:        0.9327
# ============================================================
#
#
# Epoch completed in 7.7 seconds
#
# ============================================================
# EPOCH 29/30
# ============================================================
# Epoch [29] Batch [10/114] Loss: 0.0454
# Epoch [29] Batch [20/114] Loss: 0.1425
# Epoch [29] Batch [30/114] Loss: 0.2728
# Epoch [29] Batch [40/114] Loss: 0.0198
# Epoch [29] Batch [50/114] Loss: 0.0220
# Epoch [29] Batch [60/114] Loss: 0.1030
# Epoch [29] Batch [70/114] Loss: 0.1735
# Epoch [29] Batch [80/114] Loss: 0.0376
# Epoch [29] Batch [90/114] Loss: 0.0308
# Epoch [29] Batch [100/114] Loss: 0.1333
# Epoch [29] Batch [110/114] Loss: 0.0809
#
# Training Loss: 0.1060
# Validation Loss: 0.1867
# Stepped scheduler. New LR: 0.000000
#
# ============================================================
# Epoch 29 - VAL
# ============================================================
# Accuracy:  0.9388
# Precision: 0.9400
# Recall:    0.9371
# F1 Score:  0.9383
#
# Confusion Matrix:
# [[633  27]
#  [ 48 518]]
#
# Per-Class Metrics:
#   cherry_clean:
#     Precision: 0.9295
#     Recall:    0.9591
#     F1:        0.9441
#   cherry_pit:
#     Precision: 0.9505
#     Recall:    0.9152
#     F1:        0.9325
# ============================================================
#
#
# Epoch completed in 7.8 seconds
#
# ============================================================
# EPOCH 30/30
# ============================================================
# Epoch [30] Batch [10/114] Loss: 0.1030
# Epoch [30] Batch [20/114] Loss: 0.0370
# Epoch [30] Batch [30/114] Loss: 0.0381
# Epoch [30] Batch [40/114] Loss: 0.0584
# Epoch [30] Batch [50/114] Loss: 0.2041
# Epoch [30] Batch [60/114] Loss: 0.0370
# Epoch [30] Batch [70/114] Loss: 0.2382
# Epoch [30] Batch [80/114] Loss: 0.0418
# Epoch [30] Batch [90/114] Loss: 0.0801
# Epoch [30] Batch [100/114] Loss: 0.2389
# Epoch [30] Batch [110/114] Loss: 0.0684
#
# Training Loss: 0.1014
# Validation Loss: 0.1865
# Stepped scheduler. New LR: 0.000000
#
# ============================================================
# Epoch 30 - VAL
# ============================================================
# Accuracy:  0.9388
# Precision: 0.9400
# Recall:    0.9371
# F1 Score:  0.9383
#
# Confusion Matrix:
# [[633  27]
#  [ 48 518]]
#
# Per-Class Metrics:
#   cherry_clean:
#     Precision: 0.9295
#     Recall:    0.9591
#     F1:        0.9441
#   cherry_pit:
#     Precision: 0.9505
#     Recall:    0.9152
#     F1:        0.9325
# ============================================================
#
# Checkpoint saved: /content/drive/MyDrive/cherry_experiments/convnextv2_tiny_baseline_seed42/checkpoint_epoch_30.pt
#
# Epoch completed in 8.4 seconds
# Model weights saved: /content/drive/MyDrive/cherry_experiments/convnextv2_tiny_baseline_seed42/model_final.pt
#
# ============================================================
# TRAINING COMPLETE
# ============================================================
# Final model saved to: /content/drive/MyDrive/cherry_experiments/convnextv2_tiny_baseline_seed42/model_final.pt
# Best validation accuracy: 0.9421
# Logs saved to: /content/drive/MyDrive/cherry_experiments/convnextv2_tiny_baseline_seed42/metrics.json
#
# ============================================================
# Training complete! Results: /content/drive/MyDrive/cherry_experiments/convnextv2_tiny_baseline_seed42
#
# Key files to download:
#   - model_best.pt
#   - metrics.json
# ============================================================

# %% [markdown]
# ## Cell 7: EXP-002B - ConvNeXt V2-Tiny with Label Smoothing

# %%
if SKIP_EXP_002B:
    print("EXP-002B: SKIPPED (set SKIP_EXP_002B=False to run)")
else:
    print("\n" + "=" * 60)
    print("RUNNING EXP-002B: ConvNeXt V2-Tiny with Label Smoothing")
    print("=" * 60)

    # Set random seed
    random.seed(RANDOM_SEED)
    np.random.seed(RANDOM_SEED)
    torch.manual_seed(RANDOM_SEED)
    if torch.cuda.is_available():
        torch.cuda.manual_seed_all(RANDOM_SEED)

    print(f"Random seed set: {RANDOM_SEED}")
    print("Label smoothing: alpha=0.1")

    # Load config
    config_path = "/content/cherries/training/configs/experiments/convnextv2_tiny_label_smooth_seed42.yaml"

    with open(config_path, 'r') as f:
        config = yaml.safe_load(f)

    # Override paths
    config['checkpointing']['output_dir'] = f"{DRIVE_BASE_PATH}/convnextv2_tiny_label_smooth_seed42"
    config['data']['root'] = DATA_PATH

    # Apply smoke test settings
    if SMOKE_TEST:
        print("\nSMOKE TEST MODE: 1 epoch, 3 batches")
        config['training']['epochs'] = 1
        config['checkpointing']['save_every'] = 1

    # Save temp config
    temp_config = "/tmp/convnextv2_tiny_label_smooth_seed42.yaml"
    with open(temp_config, 'w') as f:
        yaml.dump(config, f)

    # Run training
    # !python /content/cherries/training/scripts/train.py \
        --config {temp_config} \
        --data-root {DATA_PATH}

    print("\n" + "=" * 60)
    print(f"Training complete! Results: {config['checkpointing']['output_dir']}")
    print("=" * 60)
# Out:
# ============================================================
# RUNNING EXP-002B: ConvNeXt V2-Tiny with Label Smoothing
# ============================================================
# Random seed set: 42
# Label smoothing: alpha=0.1
# Using cache found in /root/.cache/torch/hub/facebookresearch_dinov2_main
# /root/.cache/torch/hub/facebookresearch_dinov2_main/dinov2/layers/swiglu_ffn.py:51: UserWarning: xFormers is not available (SwiGLU)
#   warnings.warn("xFormers is not available (SwiGLU)")
# /root/.cache/torch/hub/facebookresearch_dinov2_main/dinov2/layers/attention.py:33: UserWarning: xFormers is not available (Attention)
#   warnings.warn("xFormers is not available (Attention)")
# /root/.cache/torch/hub/facebookresearch_dinov2_main/dinov2/layers/block.py:40: UserWarning: xFormers is not available (Block)
#   warnings.warn("xFormers is not available (Block)")
#
# Loading config from: /tmp/convnextv2_tiny_label_smooth_seed42.yaml
# Output directory: /content/drive/MyDrive/cherry_experiments/convnextv2_tiny_label_smooth_seed42
# Config saved to: /content/drive/MyDrive/cherry_experiments/convnextv2_tiny_label_smooth_seed42/config.yaml
# Using device: cuda
#
# ============================================================
# LOADING DATA
# ============================================================
#
# Dataset loaded from: /content/cherry_classification/data
# Training samples: 3676
# Validation samples: 1226
# Classes: ['cherry_clean', 'cherry_pit']
# Class distribution (train): {'cherry_clean': 1978, 'cherry_pit': 1698}
# Class distribution (val): {'cherry_clean': 660, 'cherry_pit': 566}
#
# Class names: ['cherry_clean', 'cherry_pit']
#
# ============================================================
# CREATING MODEL
# ============================================================
# Architecture: convnextv2_tiny
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Loaded convnextv2_tiny.fcmae_ft_in1k with FCMAE pre-training
# Model moved to device: cuda
# Optimizer: adamw
# Learning rate: 0.0001
# Weight decay: 0.05
# Using scheduler: cosine
# Using CrossEntropyLoss with label_smoothing=0.1
#
# ============================================================
# STARTING TRAINING
# ============================================================
# Training for 30 epochs
# Starting from epoch 0
#
# ============================================================
# EPOCH 1/30
# ============================================================
# Epoch [1] Batch [10/114] Loss: 0.6684
# Epoch [1] Batch [20/114] Loss: 0.6894
# Epoch [1] Batch [30/114] Loss: 0.7004
# Epoch [1] Batch [40/114] Loss: 0.8408
# Epoch [1] Batch [50/114] Loss: 0.6890
# Epoch [1] Batch [60/114] Loss: 0.6983
# Epoch [1] Batch [70/114] Loss: 0.6865
# Epoch [1] Batch [80/114] Loss: 0.6887
# Epoch [1] Batch [90/114] Loss: 0.7094
# Epoch [1] Batch [100/114] Loss: 0.6904
# Epoch [1] Batch [110/114] Loss: 0.6922
#
# Training Loss: 0.6941
# Validation Loss: 0.6863
# Stepped scheduler. New LR: 0.000100
#
# ============================================================
# Epoch 1 - VAL
# ============================================================
# Accuracy:  0.5383
# Precision: 0.2692
# Recall:    0.5000
# F1 Score:  0.3499
#
# Confusion Matrix:
# [[660   0]
#  [566   0]]
#
# Per-Class Metrics:
#   cherry_clean:
#     Precision: 0.5383
#     Recall:    1.0000
#     F1:        0.6999
#   cherry_pit:
#     Precision: 0.0000
#     Recall:    0.0000
#     F1:        0.0000
# ============================================================
#
# Model weights saved: /content/drive/MyDrive/cherry_experiments/convnextv2_tiny_label_smooth_seed42/model_best.pt
#
# New best model saved! Validation accuracy: 0.5383
#
# Epoch completed in 15.3 seconds
#
# ============================================================
# EPOCH 2/30
# ============================================================
# Epoch [2] Batch [10/114] Loss: 0.7225
# Epoch [2] Batch [20/114] Loss: 0.6942
# Epoch [2] Batch [30/114] Loss: 0.6789
# Epoch [2] Batch [40/114] Loss: 0.6997
# Epoch [2] Batch [50/114] Loss: 0.7053
# Epoch [2] Batch [60/114] Loss: 0.6939
# Epoch [2] Batch [70/114] Loss: 0.7025
# Epoch [2] Batch [80/114] Loss: 0.7448
# Epoch [2] Batch [90/114] Loss: 0.7415
# Epoch [2] Batch [100/114] Loss: 0.6934
# Epoch [2] Batch [110/114] Loss: 0.6979
#
# Training Loss: 0.6943
# Validation Loss: 0.6919
# Stepped scheduler. New LR: 0.000099
#
# ============================================================
# Epoch 2 - VAL
# ============================================================
# Accuracy:  0.5383
# Precision: 0.2692
# Recall:    0.5000
# F1 Score:  0.3499
#
# Confusion Matrix:
# [[660   0]
#  [566   0]]
#
# Per-Class Metrics:
#   cherry_clean:
#     Precision: 0.5383
#     Recall:    1.0000
#     F1:        0.6999
#   cherry_pit:
#     Precision: 0.0000
#     Recall:    0.0000
#     F1:        0.0000
# ============================================================
#
#
# Epoch completed in 8.7 seconds
#
# ============================================================
# EPOCH 3/30
# ============================================================
# Epoch [3] Batch [10/114] Loss: 0.6917
# Epoch [3] Batch [20/114] Loss: 0.6889
# Epoch [3] Batch [30/114] Loss: 0.7002
# Epoch [3] Batch [40/114] Loss: 0.6882
# Epoch [3] Batch [50/114] Loss: 0.6871
# Epoch [3] Batch [60/114] Loss: 0.7396
# Epoch [3] Batch [70/114] Loss: 0.6942
# Epoch [3] Batch [80/114] Loss: 0.6932
# Epoch [3] Batch [90/114] Loss: 0.7175
# Epoch [3] Batch [100/114] Loss: 0.6988
# Epoch [3] Batch [110/114] Loss: 0.6916
#
# Training Loss: 0.6917
# Validation Loss: 0.6919
# Stepped scheduler. New LR: 0.000098
#
# ============================================================
# Epoch 3 - VAL
# ============================================================
# Accuracy:  0.5383
# Precision: 0.2692
# Recall:    0.5000
# F1 Score:  0.3499
#
# Confusion Matrix:
# [[660   0]
#  [566   0]]
#
# Per-Class Metrics:
#   cherry_clean:
#     Precision: 0.5383
#     Recall:    1.0000
#     F1:        0.6999
#   cherry_pit:
#     Precision: 0.0000
#     Recall:    0.0000
#     F1:        0.0000
# ============================================================
#
#
# Epoch completed in 7.8 seconds
#
# ============================================================
# EPOCH 4/30
# ============================================================
# Epoch [4] Batch [10/114] Loss: 0.6790
# Epoch [4] Batch [20/114] Loss: 0.7064
# Epoch [4] Batch [30/114] Loss: 0.6887
# Epoch [4] Batch [40/114] Loss: 0.6747
# Epoch [4] Batch [50/114] Loss: 0.7014
# Epoch [4] Batch [60/114] Loss: 0.6949
# Epoch [4] Batch [70/114] Loss: 0.6935
# Epoch [4] Batch [80/114] Loss: 0.6975
# Epoch [4] Batch [90/114] Loss: 0.7079
# Epoch [4] Batch [100/114] Loss: 0.6917
# Epoch [4] Batch [110/114] Loss: 0.6786
#
# Training Loss: 0.6929
# Validation Loss: 0.6941
# Stepped scheduler. New LR: 0.000096
#
# ============================================================
# Epoch 4 - VAL
# ============================================================
# Accuracy:  0.5383
# Precision: 0.2692
# Recall:    0.5000
# F1 Score:  0.3499
#
# Confusion Matrix:
# [[660   0]
#  [566   0]]
#
# Per-Class Metrics:
#   cherry_clean:
#     Precision: 0.5383
#     Recall:    1.0000
#     F1:        0.6999
#   cherry_pit:
#     Precision: 0.0000
#     Recall:    0.0000
#     F1:        0.0000
# ============================================================
#
#
# Epoch completed in 7.8 seconds
#
# ============================================================
# EPOCH 5/30
# ============================================================
# Epoch [5] Batch [10/114] Loss: 0.6823
# Epoch [5] Batch [20/114] Loss: 0.6940
# Epoch [5] Batch [30/114] Loss: 0.6838
# Epoch [5] Batch [40/114] Loss: 0.6971
# Epoch [5] Batch [50/114] Loss: 0.6875
# Epoch [5] Batch [60/114] Loss: 0.7150
# Epoch [5] Batch [70/114] Loss: 0.6916
# Epoch [5] Batch [80/114] Loss: 0.6889
# Epoch [5] Batch [90/114] Loss: 0.7016
# Epoch [5] Batch [100/114] Loss: 0.7023
# Epoch [5] Batch [110/114] Loss: 0.6858
#
# Training Loss: 0.6914
# Validation Loss: 0.6918
# Stepped scheduler. New LR: 0.000093
#
# ============================================================
# Epoch 5 - VAL
# ============================================================
# Accuracy:  0.5383
# Precision: 0.2692
# Recall:    0.5000
# F1 Score:  0.3499
#
# Confusion Matrix:
# [[660   0]
#  [566   0]]
#
# Per-Class Metrics:
#   cherry_clean:
#     Precision: 0.5383
#     Recall:    1.0000
#     F1:        0.6999
#   cherry_pit:
#     Precision: 0.0000
#     Recall:    0.0000
#     F1:        0.0000
# ============================================================
#
# Checkpoint saved: /content/drive/MyDrive/cherry_experiments/convnextv2_tiny_label_smooth_seed42/checkpoint_epoch_5.pt
#
# Epoch completed in 8.4 seconds
#
# ============================================================
# EPOCH 6/30
# ============================================================
# Epoch [6] Batch [10/114] Loss: 0.7063
# Epoch [6] Batch [20/114] Loss: 0.6973
# Epoch [6] Batch [30/114] Loss: 0.6801
# Epoch [6] Batch [40/114] Loss: 0.6621
# Epoch [6] Batch [50/114] Loss: 0.7005
# Epoch [6] Batch [60/114] Loss: 0.6917
# Epoch [6] Batch [70/114] Loss: 0.6728
# Epoch [6] Batch [80/114] Loss: 0.6960
# Epoch [6] Batch [90/114] Loss: 0.6933
# Epoch [6] Batch [100/114] Loss: 0.6857
# Epoch [6] Batch [110/114] Loss: 0.7149
#
# Training Loss: 0.6917
# Validation Loss: 0.6930
# Stepped scheduler. New LR: 0.000090
#
# ============================================================
# Epoch 6 - VAL
# ============================================================
# Accuracy:  0.5383
# Precision: 0.2692
# Recall:    0.5000
# F1 Score:  0.3499
#
# Confusion Matrix:
# [[660   0]
#  [566   0]]
#
# Per-Class Metrics:
#   cherry_clean:
#     Precision: 0.5383
#     Recall:    1.0000
#     F1:        0.6999
#   cherry_pit:
#     Precision: 0.0000
#     Recall:    0.0000
#     F1:        0.0000
# ============================================================
#
#
# Epoch completed in 7.8 seconds
#
# ============================================================
# EPOCH 7/30
# ============================================================
# Epoch [7] Batch [10/114] Loss: 0.6802
# Epoch [7] Batch [20/114] Loss: 0.6920
# Epoch [7] Batch [30/114] Loss: 0.6656
# Epoch [7] Batch [40/114] Loss: 0.7060
# Epoch [7] Batch [50/114] Loss: 0.7119
# Epoch [7] Batch [60/114] Loss: 0.6918
# Epoch [7] Batch [70/114] Loss: 0.7001
# Epoch [7] Batch [80/114] Loss: 0.7111
# Epoch [7] Batch [90/114] Loss: 0.6597
# Epoch [7] Batch [100/114] Loss: 0.6850
# Epoch [7] Batch [110/114] Loss: 0.6659
#
# Training Loss: 0.6919
# Validation Loss: 0.6924
# Stepped scheduler. New LR: 0.000087
#
# ============================================================
# Epoch 7 - VAL
# ============================================================
# Accuracy:  0.5383
# Precision: 0.2692
# Recall:    0.5000
# F1 Score:  0.3499
#
# Confusion Matrix:
# [[660   0]
#  [566   0]]
#
# Per-Class Metrics:
#   cherry_clean:
#     Precision: 0.5383
#     Recall:    1.0000
#     F1:        0.6999
#   cherry_pit:
#     Precision: 0.0000
#     Recall:    0.0000
#     F1:        0.0000
# ============================================================
#
#
# Epoch completed in 7.9 seconds
#
# ============================================================
# EPOCH 8/30
# ============================================================
# Epoch [8] Batch [10/114] Loss: 0.6958
# Epoch [8] Batch [20/114] Loss: 0.6687
# Epoch [8] Batch [30/114] Loss: 0.6882
# Epoch [8] Batch [40/114] Loss: 0.7079
# Epoch [8] Batch [50/114] Loss: 0.6932
# Epoch [8] Batch [60/114] Loss: 0.6849
# Epoch [8] Batch [70/114] Loss: 0.6585
# Epoch [8] Batch [80/114] Loss: 0.6589
# Epoch [8] Batch [90/114] Loss: 0.6795
# Epoch [8] Batch [100/114] Loss: 0.7084
# Epoch [8] Batch [110/114] Loss: 0.7119
#
# Training Loss: 0.6913
# Validation Loss: 0.6917
# Stepped scheduler. New LR: 0.000083
#
# ============================================================
# Epoch 8 - VAL
# ============================================================
# Accuracy:  0.5383
# Precision: 0.2692
# Recall:    0.5000
# F1 Score:  0.3499
#
# Confusion Matrix:
# [[660   0]
#  [566   0]]
#
# Per-Class Metrics:
#   cherry_clean:
#     Precision: 0.5383
#     Recall:    1.0000
#     F1:        0.6999
#   cherry_pit:
#     Precision: 0.0000
#     Recall:    0.0000
#     F1:        0.0000
# ============================================================
#
#
# Epoch completed in 7.8 seconds
#
# ============================================================
# EPOCH 9/30
# ============================================================
# Epoch [9] Batch [10/114] Loss: 0.6873
# Epoch [9] Batch [20/114] Loss: 0.6784
# Epoch [9] Batch [30/114] Loss: 0.6853
# Epoch [9] Batch [40/114] Loss: 0.6867
# Epoch [9] Batch [50/114] Loss: 0.6823
# Epoch [9] Batch [60/114] Loss: 0.7123
# Epoch [9] Batch [70/114] Loss: 0.6970
# Epoch [9] Batch [80/114] Loss: 0.6983
# Epoch [9] Batch [90/114] Loss: 0.6996
# Epoch [9] Batch [100/114] Loss: 0.7057
# Epoch [9] Batch [110/114] Loss: 0.6940
#
# Training Loss: 0.6920
# Validation Loss: 0.6920
# Stepped scheduler. New LR: 0.000079
#
# ============================================================
# Epoch 9 - VAL
# ============================================================
# Accuracy:  0.5383
# Precision: 0.2692
# Recall:    0.5000
# F1 Score:  0.3499
#
# Confusion Matrix:
# [[660   0]
#  [566   0]]
#
# Per-Class Metrics:
#   cherry_clean:
#     Precision: 0.5383
#     Recall:    1.0000
#     F1:        0.6999
#   cherry_pit:
#     Precision: 0.0000
#     Recall:    0.0000
#     F1:        0.0000
# ============================================================
#
#
# Epoch completed in 7.7 seconds
#
# ============================================================
# EPOCH 10/30
# ============================================================
# Epoch [10] Batch [10/114] Loss: 0.6881
# Epoch [10] Batch [20/114] Loss: 0.7132
# Epoch [10] Batch [30/114] Loss: 0.6972
# Epoch [10] Batch [40/114] Loss: 0.7191
# Epoch [10] Batch [50/114] Loss: 0.7049
# Epoch [10] Batch [60/114] Loss: 0.7008
# Epoch [10] Batch [70/114] Loss: 0.6990
# Epoch [10] Batch [80/114] Loss: 0.6847
# Epoch [10] Batch [90/114] Loss: 0.6917
# Epoch [10] Batch [100/114] Loss: 0.6948
# Epoch [10] Batch [110/114] Loss: 0.6835
#
# Training Loss: 0.6914
# Validation Loss: 0.6922
# Stepped scheduler. New LR: 0.000075
#
# ============================================================
# Epoch 10 - VAL
# ============================================================
# Accuracy:  0.5383
# Precision: 0.2692
# Recall:    0.5000
# F1 Score:  0.3499
#
# Confusion Matrix:
# [[660   0]
#  [566   0]]
#
# Per-Class Metrics:
#   cherry_clean:
#     Precision: 0.5383
#     Recall:    1.0000
#     F1:        0.6999
#   cherry_pit:
#     Precision: 0.0000
#     Recall:    0.0000
#     F1:        0.0000
# ============================================================
#
# Checkpoint saved: /content/drive/MyDrive/cherry_experiments/convnextv2_tiny_label_smooth_seed42/checkpoint_epoch_10.pt
#
# Epoch completed in 8.7 seconds
#
# ============================================================
# EPOCH 11/30
# ============================================================
# Epoch [11] Batch [10/114] Loss: 0.6911
# Epoch [11] Batch [20/114] Loss: 0.7052
# Epoch [11] Batch [30/114] Loss: 0.6830
# Epoch [11] Batch [40/114] Loss: 0.6936
# Epoch [11] Batch [50/114] Loss: 0.6845
# Epoch [11] Batch [60/114] Loss: 0.6994
# Epoch [11] Batch [70/114] Loss: 0.6869
# Epoch [11] Batch [80/114] Loss: 0.6917
# Epoch [11] Batch [90/114] Loss: 0.6805
# Epoch [11] Batch [100/114] Loss: 0.6751
# Epoch [11] Batch [110/114] Loss: 0.6923
#
# Training Loss: 0.6918
# Validation Loss: 0.6924
# Stepped scheduler. New LR: 0.000070
#
# ============================================================
# Epoch 11 - VAL
# ============================================================
# Accuracy:  0.5383
# Precision: 0.2692
# Recall:    0.5000
# F1 Score:  0.3499
#
# Confusion Matrix:
# [[660   0]
#  [566   0]]
#
# Per-Class Metrics:
#   cherry_clean:
#     Precision: 0.5383
#     Recall:    1.0000
#     F1:        0.6999
#   cherry_pit:
#     Precision: 0.0000
#     Recall:    0.0000
#     F1:        0.0000
# ============================================================
#
#
# Epoch completed in 8.4 seconds
#
# ============================================================
# EPOCH 12/30
# ============================================================
# Epoch [12] Batch [10/114] Loss: 0.6873
# Epoch [12] Batch [20/114] Loss: 0.6922
# Epoch [12] Batch [30/114] Loss: 0.6945
# Epoch [12] Batch [40/114] Loss: 0.6938
# Epoch [12] Batch [50/114] Loss: 0.6959
# Epoch [12] Batch [60/114] Loss: 0.7135
# Epoch [12] Batch [70/114] Loss: 0.7244
# Epoch [12] Batch [80/114] Loss: 0.6834
# Epoch [12] Batch [90/114] Loss: 0.6926
# Epoch [12] Batch [100/114] Loss: 0.6993
# Epoch [12] Batch [110/114] Loss: 0.7033
#
# Training Loss: 0.6920
# Validation Loss: 0.6925
# Stepped scheduler. New LR: 0.000065
#
# ============================================================
# Epoch 12 - VAL
# ============================================================
# Accuracy:  0.5383
# Precision: 0.2692
# Recall:    0.5000
# F1 Score:  0.3499
#
# Confusion Matrix:
# [[660   0]
#  [566   0]]
#
# Per-Class Metrics:
#   cherry_clean:
#     Precision: 0.5383
#     Recall:    1.0000
#     F1:        0.6999
#   cherry_pit:
#     Precision: 0.0000
#     Recall:    0.0000
#     F1:        0.0000
# ============================================================
#
#
# Epoch completed in 7.8 seconds
#
# ============================================================
# EPOCH 13/30
# ============================================================
# Epoch [13] Batch [10/114] Loss: 0.6973
# Epoch [13] Batch [20/114] Loss: 0.7091
# Epoch [13] Batch [30/114] Loss: 0.6640
# Epoch [13] Batch [40/114] Loss: 0.7018
# Epoch [13] Batch [50/114] Loss: 0.6916
# Epoch [13] Batch [60/114] Loss: 0.7088
# Epoch [13] Batch [70/114] Loss: 0.6815
# Epoch [13] Batch [80/114] Loss: 0.6918
# Epoch [13] Batch [90/114] Loss: 0.7031
# Epoch [13] Batch [100/114] Loss: 0.6888
# Epoch [13] Batch [110/114] Loss: 0.6848
#
# Training Loss: 0.6908
# Validation Loss: 0.6920
# Stepped scheduler. New LR: 0.000060
#
# ============================================================
# Epoch 13 - VAL
# ============================================================
# Accuracy:  0.5383
# Precision: 0.2692
# Recall:    0.5000
# F1 Score:  0.3499
#
# Confusion Matrix:
# [[660   0]
#  [566   0]]
#
# Per-Class Metrics:
#   cherry_clean:
#     Precision: 0.5383
#     Recall:    1.0000
#     F1:        0.6999
#   cherry_pit:
#     Precision: 0.0000
#     Recall:    0.0000
#     F1:        0.0000
# ============================================================
#
#
# Epoch completed in 7.8 seconds
#
# ============================================================
# EPOCH 14/30
# ============================================================
# Epoch [14] Batch [10/114] Loss: 0.6869
# Epoch [14] Batch [20/114] Loss: 0.6736
# Epoch [14] Batch [30/114] Loss: 0.6993
# Epoch [14] Batch [40/114] Loss: 0.6742
# Epoch [14] Batch [50/114] Loss: 0.6852
# Epoch [14] Batch [60/114] Loss: 0.6857
# Epoch [14] Batch [70/114] Loss: 0.6897
# Epoch [14] Batch [80/114] Loss: 0.6804
# Epoch [14] Batch [90/114] Loss: 0.6757
# Epoch [14] Batch [100/114] Loss: 0.6686
# Epoch [14] Batch [110/114] Loss: 0.6822
#
# Training Loss: 0.6914
# Validation Loss: 0.6921
# Stepped scheduler. New LR: 0.000055
#
# ============================================================
# Epoch 14 - VAL
# ============================================================
# Accuracy:  0.5383
# Precision: 0.2692
# Recall:    0.5000
# F1 Score:  0.3499
#
# Confusion Matrix:
# [[660   0]
#  [566   0]]
#
# Per-Class Metrics:
#   cherry_clean:
#     Precision: 0.5383
#     Recall:    1.0000
#     F1:        0.6999
#   cherry_pit:
#     Precision: 0.0000
#     Recall:    0.0000
#     F1:        0.0000
# ============================================================
#
#
# Epoch completed in 7.8 seconds
#
# ============================================================
# EPOCH 15/30
# ============================================================
# Epoch [15] Batch [10/114] Loss: 0.6796
# Epoch [15] Batch [20/114] Loss: 0.6917
# Epoch [15] Batch [30/114] Loss: 0.6801
# Epoch [15] Batch [40/114] Loss: 0.6687
# Epoch [15] Batch [50/114] Loss: 0.6804
# Epoch [15] Batch [60/114] Loss: 0.6731
# Epoch [15] Batch [70/114] Loss: 0.6822
# Epoch [15] Batch [80/114] Loss: 0.6875
# Epoch [15] Batch [90/114] Loss: 0.6778
# Epoch [15] Batch [100/114] Loss: 0.6867
# Epoch [15] Batch [110/114] Loss: 0.6940
#
# Training Loss: 0.6910
# Validation Loss: 0.6918
# Stepped scheduler. New LR: 0.000050
#
# ============================================================
# Epoch 15 - VAL
# ============================================================
# Accuracy:  0.5383
# Precision: 0.2692
# Recall:    0.5000
# F1 Score:  0.3499
#
# Confusion Matrix:
# [[660   0]
#  [566   0]]
#
# Per-Class Metrics:
#   cherry_clean:
#     Precision: 0.5383
#     Recall:    1.0000
#     F1:        0.6999
#   cherry_pit:
#     Precision: 0.0000
#     Recall:    0.0000
#     F1:        0.0000
# ============================================================
#
# Checkpoint saved: /content/drive/MyDrive/cherry_experiments/convnextv2_tiny_label_smooth_seed42/checkpoint_epoch_15.pt
#
# Epoch completed in 8.4 seconds
#
# ============================================================
# EPOCH 16/30
# ============================================================
# Epoch [16] Batch [10/114] Loss: 0.6960
# Epoch [16] Batch [20/114] Loss: 0.7192
# Epoch [16] Batch [30/114] Loss: 0.6827
# Epoch [16] Batch [40/114] Loss: 0.6804
# Epoch [16] Batch [50/114] Loss: 0.6916
# Epoch [16] Batch [60/114] Loss: 0.6916
# Epoch [16] Batch [70/114] Loss: 0.6880
# Epoch [16] Batch [80/114] Loss: 0.6997
# Epoch [16] Batch [90/114] Loss: 0.7025
# Epoch [16] Batch [100/114] Loss: 0.6887
# Epoch [16] Batch [110/114] Loss: 0.7110
#
# Training Loss: 0.6915
# Validation Loss: 0.6923
# Stepped scheduler. New LR: 0.000045
#
# ============================================================
# Epoch 16 - VAL
# ============================================================
# Accuracy:  0.5383
# Precision: 0.2692
# Recall:    0.5000
# F1 Score:  0.3499
#
# Confusion Matrix:
# [[660   0]
#  [566   0]]
#
# Per-Class Metrics:
#   cherry_clean:
#     Precision: 0.5383
#     Recall:    1.0000
#     F1:        0.6999
#   cherry_pit:
#     Precision: 0.0000
#     Recall:    0.0000
#     F1:        0.0000
# ============================================================
#
#
# Epoch completed in 7.8 seconds
#
# ============================================================
# EPOCH 17/30
# ============================================================
# Epoch [17] Batch [10/114] Loss: 0.6849
# Epoch [17] Batch [20/114] Loss: 0.6891
# Epoch [17] Batch [30/114] Loss: 0.6857
# Epoch [17] Batch [40/114] Loss: 0.6885
# Epoch [17] Batch [50/114] Loss: 0.6954
# Epoch [17] Batch [60/114] Loss: 0.6663
# Epoch [17] Batch [70/114] Loss: 0.6869
# Epoch [17] Batch [80/114] Loss: 0.6925
# Epoch [17] Batch [90/114] Loss: 0.6872
# Epoch [17] Batch [100/114] Loss: 0.7190
# Epoch [17] Batch [110/114] Loss: 0.6842
#
# Training Loss: 0.6911
# Validation Loss: 0.6919
# Stepped scheduler. New LR: 0.000040
#
# ============================================================
# Epoch 17 - VAL
# ============================================================
# Accuracy:  0.5383
# Precision: 0.2692
# Recall:    0.5000
# F1 Score:  0.3499
#
# Confusion Matrix:
# [[660   0]
#  [566   0]]
#
# Per-Class Metrics:
#   cherry_clean:
#     Precision: 0.5383
#     Recall:    1.0000
#     F1:        0.6999
#   cherry_pit:
#     Precision: 0.0000
#     Recall:    0.0000
#     F1:        0.0000
# ============================================================
#
#
# Epoch completed in 7.8 seconds
#
# ============================================================
# EPOCH 18/30
# ============================================================
# Epoch [18] Batch [10/114] Loss: 0.6789
# Epoch [18] Batch [20/114] Loss: 0.6850
# Epoch [18] Batch [30/114] Loss: 0.7013
# Epoch [18] Batch [40/114] Loss: 0.7148
# Epoch [18] Batch [50/114] Loss: 0.6868
# Epoch [18] Batch [60/114] Loss: 0.6761
# Epoch [18] Batch [70/114] Loss: 0.6974
# Epoch [18] Batch [80/114] Loss: 0.6800
# Epoch [18] Batch [90/114] Loss: 0.6886
# Epoch [18] Batch [100/114] Loss: 0.6958
# Epoch [18] Batch [110/114] Loss: 0.6905
#
# Training Loss: 0.6909
# Validation Loss: 0.6919
# Stepped scheduler. New LR: 0.000035
#
# ============================================================
# Epoch 18 - VAL
# ============================================================
# Accuracy:  0.5383
# Precision: 0.2692
# Recall:    0.5000
# F1 Score:  0.3499
#
# Confusion Matrix:
# [[660   0]
#  [566   0]]
#
# Per-Class Metrics:
#   cherry_clean:
#     Precision: 0.5383
#     Recall:    1.0000
#     F1:        0.6999
#   cherry_pit:
#     Precision: 0.0000
#     Recall:    0.0000
#     F1:        0.0000
# ============================================================
#
#
# Epoch completed in 7.8 seconds
#
# ============================================================
# EPOCH 19/30
# ============================================================
# Epoch [19] Batch [10/114] Loss: 0.6860
# Epoch [19] Batch [20/114] Loss: 0.6917
# Epoch [19] Batch [30/114] Loss: 0.6779
# Epoch [19] Batch [40/114] Loss: 0.6729
# Epoch [19] Batch [50/114] Loss: 0.6868
# Epoch [19] Batch [60/114] Loss: 0.6923
# Epoch [19] Batch [70/114] Loss: 0.7174
# Epoch [19] Batch [80/114] Loss: 0.6916
# Epoch [19] Batch [90/114] Loss: 0.6972
# Epoch [19] Batch [100/114] Loss: 0.6888
# Epoch [19] Batch [110/114] Loss: 0.7044
#
# Training Loss: 0.6911
# Validation Loss: 0.6917
# Stepped scheduler. New LR: 0.000030
#
# ============================================================
# Epoch 19 - VAL
# ============================================================
# Accuracy:  0.5383
# Precision: 0.2692
# Recall:    0.5000
# F1 Score:  0.3499
#
# Confusion Matrix:
# [[660   0]
#  [566   0]]
#
# Per-Class Metrics:
#   cherry_clean:
#     Precision: 0.5383
#     Recall:    1.0000
#     F1:        0.6999
#   cherry_pit:
#     Precision: 0.0000
#     Recall:    0.0000
#     F1:        0.0000
# ============================================================
#
#
# Epoch completed in 7.8 seconds
#
# ============================================================
# EPOCH 20/30
# ============================================================
# Epoch [20] Batch [10/114] Loss: 0.6859
# Epoch [20] Batch [20/114] Loss: 0.6915
# Epoch [20] Batch [30/114] Loss: 0.6941
# Epoch [20] Batch [40/114] Loss: 0.6824
# Epoch [20] Batch [50/114] Loss: 0.6746
# Epoch [20] Batch [60/114] Loss: 0.6917
# Epoch [20] Batch [70/114] Loss: 0.6957
# Epoch [20] Batch [80/114] Loss: 0.7009
# Epoch [20] Batch [90/114] Loss: 0.6601
# Epoch [20] Batch [100/114] Loss: 0.6916
# Epoch [20] Batch [110/114] Loss: 0.6914
#
# Training Loss: 0.6913
# Validation Loss: 0.6918
# Stepped scheduler. New LR: 0.000025
#
# ============================================================
# Epoch 20 - VAL
# ============================================================
# Accuracy:  0.5383
# Precision: 0.2692
# Recall:    0.5000
# F1 Score:  0.3499
#
# Confusion Matrix:
# [[660   0]
#  [566   0]]
#
# Per-Class Metrics:
#   cherry_clean:
#     Precision: 0.5383
#     Recall:    1.0000
#     F1:        0.6999
#   cherry_pit:
#     Precision: 0.0000
#     Recall:    0.0000
#     F1:        0.0000
# ============================================================
#
# Checkpoint saved: /content/drive/MyDrive/cherry_experiments/convnextv2_tiny_label_smooth_seed42/checkpoint_epoch_20.pt
#
# Epoch completed in 8.4 seconds
#
# ============================================================
# EPOCH 21/30
# ============================================================
# Epoch [21] Batch [10/114] Loss: 0.6780
# Epoch [21] Batch [20/114] Loss: 0.6992
# Epoch [21] Batch [30/114] Loss: 0.6853
# Epoch [21] Batch [40/114] Loss: 0.6920
# Epoch [21] Batch [50/114] Loss: 0.7023
# Epoch [21] Batch [60/114] Loss: 0.6954
# Epoch [21] Batch [70/114] Loss: 0.6849
# Epoch [21] Batch [80/114] Loss: 0.6955
# Epoch [21] Batch [90/114] Loss: 0.6699
# Epoch [21] Batch [100/114] Loss: 0.6879
# Epoch [21] Batch [110/114] Loss: 0.6963
#
# Training Loss: 0.6910
# Validation Loss: 0.6919
# Stepped scheduler. New LR: 0.000021
#
# ============================================================
# Epoch 21 - VAL
# ============================================================
# Accuracy:  0.5383
# Precision: 0.2692
# Recall:    0.5000
# F1 Score:  0.3499
#
# Confusion Matrix:
# [[660   0]
#  [566   0]]
#
# Per-Class Metrics:
#   cherry_clean:
#     Precision: 0.5383
#     Recall:    1.0000
#     F1:        0.6999
#   cherry_pit:
#     Precision: 0.0000
#     Recall:    0.0000
#     F1:        0.0000
# ============================================================
#
#
# Epoch completed in 7.7 seconds
#
# ============================================================
# EPOCH 22/30
# ============================================================
# Epoch [22] Batch [10/114] Loss: 0.6831
# Epoch [22] Batch [20/114] Loss: 0.6915
# Epoch [22] Batch [30/114] Loss: 0.6939
# Epoch [22] Batch [40/114] Loss: 0.7008
# Epoch [22] Batch [50/114] Loss: 0.6920
# Epoch [22] Batch [60/114] Loss: 0.6913
# Epoch [22] Batch [70/114] Loss: 0.6873
# Epoch [22] Batch [80/114] Loss: 0.6939
# Epoch [22] Batch [90/114] Loss: 0.7018
# Epoch [22] Batch [100/114] Loss: 0.6740
# Epoch [22] Batch [110/114] Loss: 0.7004
#
# Training Loss: 0.6902
# Validation Loss: 0.6963
# Stepped scheduler. New LR: 0.000017
#
# ============================================================
# Epoch 22 - VAL
# ============================================================
# Accuracy:  0.5383
# Precision: 0.2692
# Recall:    0.5000
# F1 Score:  0.3499
#
# Confusion Matrix:
# [[660   0]
#  [566   0]]
#
# Per-Class Metrics:
#   cherry_clean:
#     Precision: 0.5383
#     Recall:    1.0000
#     F1:        0.6999
#   cherry_pit:
#     Precision: 0.0000
#     Recall:    0.0000
#     F1:        0.0000
# ============================================================
#
#
# Epoch completed in 7.9 seconds
#
# ============================================================
# EPOCH 23/30
# ============================================================
# Epoch [23] Batch [10/114] Loss: 0.6948
# Epoch [23] Batch [20/114] Loss: 0.6934
# Epoch [23] Batch [30/114] Loss: 0.6958
# Epoch [23] Batch [40/114] Loss: 0.6869
# Epoch [23] Batch [50/114] Loss: 0.6735
# Epoch [23] Batch [60/114] Loss: 0.6714
# Epoch [23] Batch [70/114] Loss: 0.6872
# Epoch [23] Batch [80/114] Loss: 0.6780
# Epoch [23] Batch [90/114] Loss: 0.6831
# Epoch [23] Batch [100/114] Loss: 0.6917
# Epoch [23] Batch [110/114] Loss: 0.6812
#
# Training Loss: 0.6922
# Validation Loss: 0.6919
# Stepped scheduler. New LR: 0.000013
#
# ============================================================
# Epoch 23 - VAL
# ============================================================
# Accuracy:  0.5383
# Precision: 0.2692
# Recall:    0.5000
# F1 Score:  0.3499
#
# Confusion Matrix:
# [[660   0]
#  [566   0]]
#
# Per-Class Metrics:
#   cherry_clean:
#     Precision: 0.5383
#     Recall:    1.0000
#     F1:        0.6999
#   cherry_pit:
#     Precision: 0.0000
#     Recall:    0.0000
#     F1:        0.0000
# ============================================================
#
#
# Epoch completed in 7.7 seconds
#
# ============================================================
# EPOCH 24/30
# ============================================================
# Epoch [24] Batch [10/114] Loss: 0.6876
# Epoch [24] Batch [20/114] Loss: 0.6919
# Epoch [24] Batch [30/114] Loss: 0.7184
# Epoch [24] Batch [40/114] Loss: 0.6872
# Epoch [24] Batch [50/114] Loss: 0.6874
# Epoch [24] Batch [60/114] Loss: 0.6741
# Epoch [24] Batch [70/114] Loss: 0.6996
# Epoch [24] Batch [80/114] Loss: 0.6842
# Epoch [24] Batch [90/114] Loss: 0.6768
# Epoch [24] Batch [100/114] Loss: 0.6841
# Epoch [24] Batch [110/114] Loss: 0.6988
#
# Training Loss: 0.6909
# Validation Loss: 0.6919
# Stepped scheduler. New LR: 0.000010
#
# ============================================================
# Epoch 24 - VAL
# ============================================================
# Accuracy:  0.5383
# Precision: 0.2692
# Recall:    0.5000
# F1 Score:  0.3499
#
# Confusion Matrix:
# [[660   0]
#  [566   0]]
#
# Per-Class Metrics:
#   cherry_clean:
#     Precision: 0.5383
#     Recall:    1.0000
#     F1:        0.6999
#   cherry_pit:
#     Precision: 0.0000
#     Recall:    0.0000
#     F1:        0.0000
# ============================================================
#
#
# Epoch completed in 7.7 seconds
#
# ============================================================
# EPOCH 25/30
# ============================================================
# Epoch [25] Batch [10/114] Loss: 0.7071
# Epoch [25] Batch [20/114] Loss: 0.7029
# Epoch [25] Batch [30/114] Loss: 0.6916
# Epoch [25] Batch [40/114] Loss: 0.6988
# Epoch [25] Batch [50/114] Loss: 0.6882
# Epoch [25] Batch [60/114] Loss: 0.6784
# Epoch [25] Batch [70/114] Loss: 0.6979
# Epoch [25] Batch [80/114] Loss: 0.7007
# Epoch [25] Batch [90/114] Loss: 0.6946
# Epoch [25] Batch [100/114] Loss: 0.6882
# Epoch [25] Batch [110/114] Loss: 0.6805
#
# Training Loss: 0.6909
# Validation Loss: 0.6920
# Stepped scheduler. New LR: 0.000007
#
# ============================================================
# Epoch 25 - VAL
# ============================================================
# Accuracy:  0.5383
# Precision: 0.2692
# Recall:    0.5000
# F1 Score:  0.3499
#
# Confusion Matrix:
# [[660   0]
#  [566   0]]
#
# Per-Class Metrics:
#   cherry_clean:
#     Precision: 0.5383
#     Recall:    1.0000
#     F1:        0.6999
#   cherry_pit:
#     Precision: 0.0000
#     Recall:    0.0000
#     F1:        0.0000
# ============================================================
#
# Checkpoint saved: /content/drive/MyDrive/cherry_experiments/convnextv2_tiny_label_smooth_seed42/checkpoint_epoch_25.pt
#
# Epoch completed in 8.6 seconds
#
# ============================================================
# EPOCH 26/30
# ============================================================
# Epoch [26] Batch [10/114] Loss: 0.7041
# Epoch [26] Batch [20/114] Loss: 0.6834
# Epoch [26] Batch [30/114] Loss: 0.7113
# Epoch [26] Batch [40/114] Loss: 0.6987
# Epoch [26] Batch [50/114] Loss: 0.6951
# Epoch [26] Batch [60/114] Loss: 0.6881
# Epoch [26] Batch [70/114] Loss: 0.6916
# Epoch [26] Batch [80/114] Loss: 0.6838
# Epoch [26] Batch [90/114] Loss: 0.6876
# Epoch [26] Batch [100/114] Loss: 0.6918
# Epoch [26] Batch [110/114] Loss: 0.6958
#
# Training Loss: 0.6910
# Validation Loss: 0.6920
# Stepped scheduler. New LR: 0.000004
#
# ============================================================
# Epoch 26 - VAL
# ============================================================
# Accuracy:  0.5383
# Precision: 0.2692
# Recall:    0.5000
# F1 Score:  0.3499
#
# Confusion Matrix:
# [[660   0]
#  [566   0]]
#
# Per-Class Metrics:
#   cherry_clean:
#     Precision: 0.5383
#     Recall:    1.0000
#     F1:        0.6999
#   cherry_pit:
#     Precision: 0.0000
#     Recall:    0.0000
#     F1:        0.0000
# ============================================================
#
#
# Epoch completed in 7.7 seconds
#
# ============================================================
# EPOCH 27/30
# ============================================================
# Epoch [27] Batch [10/114] Loss: 0.6958
# Epoch [27] Batch [20/114] Loss: 0.6789
# Epoch [27] Batch [30/114] Loss: 0.6787
# Epoch [27] Batch [40/114] Loss: 0.6961
# Epoch [27] Batch [50/114] Loss: 0.7047
# Epoch [27] Batch [60/114] Loss: 0.7043
# Epoch [27] Batch [70/114] Loss: 0.7040
# Epoch [27] Batch [80/114] Loss: 0.7039
# Epoch [27] Batch [90/114] Loss: 0.6957
# Epoch [27] Batch [100/114] Loss: 0.6798
# Epoch [27] Batch [110/114] Loss: 0.6996
#
# Training Loss: 0.6908
# Validation Loss: 0.6920
# Stepped scheduler. New LR: 0.000002
#
# ============================================================
# Epoch 27 - VAL
# ============================================================
# Accuracy:  0.5383
# Precision: 0.2692
# Recall:    0.5000
# F1 Score:  0.3499
#
# Confusion Matrix:
# [[660   0]
#  [566   0]]
#
# Per-Class Metrics:
#   cherry_clean:
#     Precision: 0.5383
#     Recall:    1.0000
#     F1:        0.6999
#   cherry_pit:
#     Precision: 0.0000
#     Recall:    0.0000
#     F1:        0.0000
# ============================================================
#
#
# Epoch completed in 8.0 seconds
#
# ============================================================
# EPOCH 28/30
# ============================================================
# Epoch [28] Batch [10/114] Loss: 0.6758
# Epoch [28] Batch [20/114] Loss: 0.7039
# Epoch [28] Batch [30/114] Loss: 0.6917
# Epoch [28] Batch [40/114] Loss: 0.6917
# Epoch [28] Batch [50/114] Loss: 0.6917
# Epoch [28] Batch [60/114] Loss: 0.6584
# Epoch [28] Batch [70/114] Loss: 0.6750
# Epoch [28] Batch [80/114] Loss: 0.6833
# Epoch [28] Batch [90/114] Loss: 0.6959
# Epoch [28] Batch [100/114] Loss: 0.6917
# Epoch [28] Batch [110/114] Loss: 0.6956
#
# Training Loss: 0.6909
# Validation Loss: 0.6920
# Stepped scheduler. New LR: 0.000001
#
# ============================================================
# Epoch 28 - VAL
# ============================================================
# Accuracy:  0.5383
# Precision: 0.2692
# Recall:    0.5000
# F1 Score:  0.3499
#
# Confusion Matrix:
# [[660   0]
#  [566   0]]
#
# Per-Class Metrics:
#   cherry_clean:
#     Precision: 0.5383
#     Recall:    1.0000
#     F1:        0.6999
#   cherry_pit:
#     Precision: 0.0000
#     Recall:    0.0000
#     F1:        0.0000
# ============================================================
#
#
# Epoch completed in 8.0 seconds
#
# ============================================================
# EPOCH 29/30
# ============================================================
# Epoch [29] Batch [10/114] Loss: 0.6839
# Epoch [29] Batch [20/114] Loss: 0.7032
# Epoch [29] Batch [30/114] Loss: 0.6955
# Epoch [29] Batch [40/114] Loss: 0.6839
# Epoch [29] Batch [50/114] Loss: 0.6798
# Epoch [29] Batch [60/114] Loss: 0.6837
# Epoch [29] Batch [70/114] Loss: 0.6996
# Epoch [29] Batch [80/114] Loss: 0.6917
# Epoch [29] Batch [90/114] Loss: 0.6956
# Epoch [29] Batch [100/114] Loss: 0.6916
# Epoch [29] Batch [110/114] Loss: 0.6762
#
# Training Loss: 0.6908
# Validation Loss: 0.6919
# Stepped scheduler. New LR: 0.000000
#
# ============================================================
# Epoch 29 - VAL
# ============================================================
# Accuracy:  0.5383
# Precision: 0.2692
# Recall:    0.5000
# F1 Score:  0.3499
#
# Confusion Matrix:
# [[660   0]
#  [566   0]]
#
# Per-Class Metrics:
#   cherry_clean:
#     Precision: 0.5383
#     Recall:    1.0000
#     F1:        0.6999
#   cherry_pit:
#     Precision: 0.0000
#     Recall:    0.0000
#     F1:        0.0000
# ============================================================
#
#
# Epoch completed in 7.7 seconds
#
# ============================================================
# EPOCH 30/30
# ============================================================
# Epoch [30] Batch [10/114] Loss: 0.6955
# Epoch [30] Batch [20/114] Loss: 0.6762
# Epoch [30] Batch [30/114] Loss: 0.6994
# Epoch [30] Batch [40/114] Loss: 0.7149
# Epoch [30] Batch [50/114] Loss: 0.6761
# Epoch [30] Batch [60/114] Loss: 0.6994
# Epoch [30] Batch [70/114] Loss: 0.7033
# Epoch [30] Batch [80/114] Loss: 0.6994
# Epoch [30] Batch [90/114] Loss: 0.6994
# Epoch [30] Batch [100/114] Loss: 0.6916
# Epoch [30] Batch [110/114] Loss: 0.6684
#
# Training Loss: 0.6909
# Validation Loss: 0.6919
# Stepped scheduler. New LR: 0.000000
#
# ============================================================
# Epoch 30 - VAL
# ============================================================
# Accuracy:  0.5383
# Precision: 0.2692
# Recall:    0.5000
# F1 Score:  0.3499
#
# Confusion Matrix:
# [[660   0]
#  [566   0]]
#
# Per-Class Metrics:
#   cherry_clean:
#     Precision: 0.5383
#     Recall:    1.0000
#     F1:        0.6999
#   cherry_pit:
#     Precision: 0.0000
#     Recall:    0.0000
#     F1:        0.0000
# ============================================================
#
# Checkpoint saved: /content/drive/MyDrive/cherry_experiments/convnextv2_tiny_label_smooth_seed42/checkpoint_epoch_30.pt
#
# Epoch completed in 8.5 seconds
# Model weights saved: /content/drive/MyDrive/cherry_experiments/convnextv2_tiny_label_smooth_seed42/model_final.pt
#
# ============================================================
# TRAINING COMPLETE
# ============================================================
# Final model saved to: /content/drive/MyDrive/cherry_experiments/convnextv2_tiny_label_smooth_seed42/model_final.pt
# Best validation accuracy: 0.5383
# Logs saved to: /content/drive/MyDrive/cherry_experiments/convnextv2_tiny_label_smooth_seed42/metrics.json
#
# ============================================================
# Training complete! Results: /content/drive/MyDrive/cherry_experiments/convnextv2_tiny_label_smooth_seed42
# ============================================================

# %% [markdown]
# ## Cell 8: EXP-003A - EfficientNet-B2 Baseline
#
# **Type:** Training
# **Duration:** ~10 hours
# **Architecture:** EfficientNet-B2 (9.2M params)
# **Key Feature:** Speed-focused alternative, unnormalized training

# %%
if SKIP_EXP_003A:
    print("EXP-003A: SKIPPED (set SKIP_EXP_003A=False to run)")
else:
    print("\n" + "=" * 60)
    print("RUNNING EXP-003A: EfficientNet-B2 Baseline")
    print("=" * 60)

    # Set random seed
    random.seed(RANDOM_SEED)
    np.random.seed(RANDOM_SEED)
    torch.manual_seed(RANDOM_SEED)
    if torch.cuda.is_available():
        torch.cuda.manual_seed_all(RANDOM_SEED)

    print(f"Random seed set: {RANDOM_SEED}")

    # Load config
    config_path = "/content/cherries/training/configs/experiments/efficientnet_b2_baseline_seed42.yaml"

    with open(config_path, 'r') as f:
        config = yaml.safe_load(f)

    # Override paths
    config['checkpointing']['output_dir'] = f"{DRIVE_BASE_PATH}/efficientnet_b2_baseline_seed42"
    config['data']['root'] = DATA_PATH

    # Apply smoke test settings
    if SMOKE_TEST:
        print("\nSMOKE TEST MODE: 1 epoch, 3 batches")
        config['training']['epochs'] = 1
        config['checkpointing']['save_every'] = 1

    # Save temp config
    temp_config = "/tmp/efficientnet_b2_baseline_seed42.yaml"
    with open(temp_config, 'w') as f:
        yaml.dump(config, f)

    # Run training
    # !python /content/cherries/training/scripts/train.py \
        --config {temp_config} \
        --data-root {DATA_PATH}

    print("\n" + "=" * 60)
    print(f"Training complete! Results: {config['checkpointing']['output_dir']}")
    print("=" * 60)
# Out:
# ============================================================
# RUNNING EXP-003A: EfficientNet-B2 Baseline
# ============================================================
# Random seed set: 42
# Using cache found in /root/.cache/torch/hub/facebookresearch_dinov2_main
# /root/.cache/torch/hub/facebookresearch_dinov2_main/dinov2/layers/swiglu_ffn.py:51: UserWarning: xFormers is not available (SwiGLU)
#   warnings.warn("xFormers is not available (SwiGLU)")
# /root/.cache/torch/hub/facebookresearch_dinov2_main/dinov2/layers/attention.py:33: UserWarning: xFormers is not available (Attention)
#   warnings.warn("xFormers is not available (Attention)")
# /root/.cache/torch/hub/facebookresearch_dinov2_main/dinov2/layers/block.py:40: UserWarning: xFormers is not available (Block)
#   warnings.warn("xFormers is not available (Block)")
#
# Loading config from: /tmp/efficientnet_b2_baseline_seed42.yaml
# Output directory: /content/drive/MyDrive/cherry_experiments/efficientnet_b2_baseline_seed42
# Config saved to: /content/drive/MyDrive/cherry_experiments/efficientnet_b2_baseline_seed42/config.yaml
# Using device: cuda
#
# ============================================================
# LOADING DATA
# ============================================================
#
# Dataset loaded from: /content/cherry_classification/data
# Training samples: 3676
# Validation samples: 1226
# Classes: ['cherry_clean', 'cherry_pit']
# Class distribution (train): {'cherry_clean': 1978, 'cherry_pit': 1698}
# Class distribution (val): {'cherry_clean': 660, 'cherry_pit': 566}
#
# Class names: ['cherry_clean', 'cherry_pit']
#
# ============================================================
# CREATING MODEL
# ============================================================
# Architecture: efficientnet_b2
# Loaded EfficientNet-B2 with ImageNet weights
# Replaced classifier head: Linear(1408, 2)
# Model moved to device: cuda
# Optimizer: adam
# Learning rate: 0.0001
# Weight decay: 1e-05
# Using standard CrossEntropyLoss (no label smoothing)
#
# ============================================================
# STARTING TRAINING
# ============================================================
# Training for 30 epochs
# Starting from epoch 0
#
# ============================================================
# EPOCH 1/30
# ============================================================
# Epoch [1] Batch [10/114] Loss: 0.6161
# Epoch [1] Batch [20/114] Loss: 0.6137
# Epoch [1] Batch [30/114] Loss: 0.6152
# Epoch [1] Batch [40/114] Loss: 0.4820
# Epoch [1] Batch [50/114] Loss: 0.4416
# Epoch [1] Batch [60/114] Loss: 0.3414
# Epoch [1] Batch [70/114] Loss: 0.3087
# Epoch [1] Batch [80/114] Loss: 0.3222
# Epoch [1] Batch [90/114] Loss: 0.3414
# Epoch [1] Batch [100/114] Loss: 0.2809
# Epoch [1] Batch [110/114] Loss: 0.4785
#
# Training Loss: 0.4624
# Validation Loss: 0.3266
#
# ============================================================
# Epoch 1 - VAL
# ============================================================
# Accuracy:  0.8695
# Precision: 0.8818
# Recall:    0.8626
# F1 Score:  0.8662
#
# Confusion Matrix:
# [[629  31]
#  [129 437]]
#
# Per-Class Metrics:
#   cherry_clean:
#     Precision: 0.8298
#     Recall:    0.9530
#     F1:        0.8872
#   cherry_pit:
#     Precision: 0.9338
#     Recall:    0.7721
#     F1:        0.8453
# ============================================================
#
# Model weights saved: /content/drive/MyDrive/cherry_experiments/efficientnet_b2_baseline_seed42/model_best.pt
#
# New best model saved! Validation accuracy: 0.8695
#
# Epoch completed in 11.4 seconds
#
# ============================================================
# EPOCH 2/30
# ============================================================
# Epoch [2] Batch [10/114] Loss: 0.3051
# Epoch [2] Batch [20/114] Loss: 0.2275
# Epoch [2] Batch [30/114] Loss: 0.4154
# Epoch [2] Batch [40/114] Loss: 0.5604
# Epoch [2] Batch [50/114] Loss: 0.2736
# Epoch [2] Batch [60/114] Loss: 0.3274
# Epoch [2] Batch [70/114] Loss: 0.2607
# Epoch [2] Batch [80/114] Loss: 0.2209
# Epoch [2] Batch [90/114] Loss: 0.3922
# Epoch [2] Batch [100/114] Loss: 0.4020
# Epoch [2] Batch [110/114] Loss: 0.3496
#
# Training Loss: 0.3228
# Validation Loss: 0.2652
#
# ============================================================
# Epoch 2 - VAL
# ============================================================
# Accuracy:  0.9013
# Precision: 0.9044
# Recall:    0.8980
# F1 Score:  0.9001
#
# Confusion Matrix:
# [[621  39]
#  [ 82 484]]
#
# Per-Class Metrics:
#   cherry_clean:
#     Precision: 0.8834
#     Recall:    0.9409
#     F1:        0.9112
#   cherry_pit:
#     Precision: 0.9254
#     Recall:    0.8551
#     F1:        0.8889
# ============================================================
#
# Model weights saved: /content/drive/MyDrive/cherry_experiments/efficientnet_b2_baseline_seed42/model_best.pt
#
# New best model saved! Validation accuracy: 0.9013
#
# Epoch completed in 8.6 seconds
#
# ============================================================
# EPOCH 3/30
# ============================================================
# Epoch [3] Batch [10/114] Loss: 0.2176
# Epoch [3] Batch [20/114] Loss: 0.2657
# Epoch [3] Batch [30/114] Loss: 0.2261
# Epoch [3] Batch [40/114] Loss: 0.3736
# Epoch [3] Batch [50/114] Loss: 0.2651
# Epoch [3] Batch [60/114] Loss: 0.2790
# Epoch [3] Batch [70/114] Loss: 0.1107
# Epoch [3] Batch [80/114] Loss: 0.2210
# Epoch [3] Batch [90/114] Loss: 0.2444
# Epoch [3] Batch [100/114] Loss: 0.3403
# Epoch [3] Batch [110/114] Loss: 0.4591
#
# Training Loss: 0.2985
# Validation Loss: 0.2517
#
# ============================================================
# Epoch 3 - VAL
# ============================================================
# Accuracy:  0.9005
# Precision: 0.8996
# Recall:    0.9008
# F1 Score:  0.9001
#
# Confusion Matrix:
# [[592  68]
#  [ 54 512]]
#
# Per-Class Metrics:
#   cherry_clean:
#     Precision: 0.9164
#     Recall:    0.8970
#     F1:        0.9066
#   cherry_pit:
#     Precision: 0.8828
#     Recall:    0.9046
#     F1:        0.8935
# ============================================================
#
#
# Epoch completed in 7.9 seconds
#
# ============================================================
# EPOCH 4/30
# ============================================================
# Epoch [4] Batch [10/114] Loss: 0.1707
# Epoch [4] Batch [20/114] Loss: 0.3114
# Epoch [4] Batch [30/114] Loss: 0.3404
# Epoch [4] Batch [40/114] Loss: 0.2456
# Epoch [4] Batch [50/114] Loss: 0.4126
# Epoch [4] Batch [60/114] Loss: 0.1843
# Epoch [4] Batch [70/114] Loss: 0.1888
# Epoch [4] Batch [80/114] Loss: 0.4361
# Epoch [4] Batch [90/114] Loss: 0.5719
# Epoch [4] Batch [100/114] Loss: 0.1357
# Epoch [4] Batch [110/114] Loss: 0.5708
#
# Training Loss: 0.2764
# Validation Loss: 0.2496
#
# ============================================================
# Epoch 4 - VAL
# ============================================================
# Accuracy:  0.9029
# Precision: 0.9112
# Recall:    0.8978
# F1 Score:  0.9011
#
# Confusion Matrix:
# [[637  23]
#  [ 96 470]]
#
# Per-Class Metrics:
#   cherry_clean:
#     Precision: 0.8690
#     Recall:    0.9652
#     F1:        0.9146
#   cherry_pit:
#     Precision: 0.9533
#     Recall:    0.8304
#     F1:        0.8876
# ============================================================
#
# Model weights saved: /content/drive/MyDrive/cherry_experiments/efficientnet_b2_baseline_seed42/model_best.pt
#
# New best model saved! Validation accuracy: 0.9029
#
# Epoch completed in 8.0 seconds
#
# ============================================================
# EPOCH 5/30
# ============================================================
# Epoch [5] Batch [10/114] Loss: 0.2218
# Epoch [5] Batch [20/114] Loss: 0.3470
# Epoch [5] Batch [30/114] Loss: 0.1625
# Epoch [5] Batch [40/114] Loss: 0.1284
# Epoch [5] Batch [50/114] Loss: 0.2596
# Epoch [5] Batch [60/114] Loss: 0.3977
# Epoch [5] Batch [70/114] Loss: 0.2917
# Epoch [5] Batch [80/114] Loss: 0.2400
# Epoch [5] Batch [90/114] Loss: 0.2227
# Epoch [5] Batch [100/114] Loss: 0.3731
# Epoch [5] Batch [110/114] Loss: 0.2950
#
# Training Loss: 0.2633
# Validation Loss: 0.2307
#
# ============================================================
# Epoch 5 - VAL
# ============================================================
# Accuracy:  0.9135
# Precision: 0.9145
# Recall:    0.9116
# F1 Score:  0.9128
#
# Confusion Matrix:
# [[618  42]
#  [ 64 502]]
#
# Per-Class Metrics:
#   cherry_clean:
#     Precision: 0.9062
#     Recall:    0.9364
#     F1:        0.9210
#   cherry_pit:
#     Precision: 0.9228
#     Recall:    0.8869
#     F1:        0.9045
# ============================================================
#
# Checkpoint saved: /content/drive/MyDrive/cherry_experiments/efficientnet_b2_baseline_seed42/checkpoint_epoch_5.pt
# Model weights saved: /content/drive/MyDrive/cherry_experiments/efficientnet_b2_baseline_seed42/model_best.pt
#
# New best model saved! Validation accuracy: 0.9135
#
# Epoch completed in 8.8 seconds
#
# ============================================================
# EPOCH 6/30
# ============================================================
# Epoch [6] Batch [10/114] Loss: 0.2318
# Epoch [6] Batch [20/114] Loss: 0.2818
# Epoch [6] Batch [30/114] Loss: 0.2669
# Epoch [6] Batch [40/114] Loss: 0.1481
# Epoch [6] Batch [50/114] Loss: 0.2911
# Epoch [6] Batch [60/114] Loss: 0.2741
# Epoch [6] Batch [70/114] Loss: 0.2009
# Epoch [6] Batch [80/114] Loss: 0.3417
# Epoch [6] Batch [90/114] Loss: 0.1359
# Epoch [6] Batch [100/114] Loss: 0.1233
# Epoch [6] Batch [110/114] Loss: 0.2583
#
# Training Loss: 0.2575
# Validation Loss: 0.2301
#
# ============================================================
# Epoch 6 - VAL
# ============================================================
# Accuracy:  0.9152
# Precision: 0.9174
# Recall:    0.9125
# F1 Score:  0.9142
#
# Confusion Matrix:
# [[625  35]
#  [ 69 497]]
#
# Per-Class Metrics:
#   cherry_clean:
#     Precision: 0.9006
#     Recall:    0.9470
#     F1:        0.9232
#   cherry_pit:
#     Precision: 0.9342
#     Recall:    0.8781
#     F1:        0.9053
# ============================================================
#
# Model weights saved: /content/drive/MyDrive/cherry_experiments/efficientnet_b2_baseline_seed42/model_best.pt
#
# New best model saved! Validation accuracy: 0.9152
#
# Epoch completed in 8.2 seconds
#
# ============================================================
# EPOCH 7/30
# ============================================================
# Epoch [7] Batch [10/114] Loss: 0.1462
# Epoch [7] Batch [20/114] Loss: 0.4306
# Epoch [7] Batch [30/114] Loss: 0.4168
# Epoch [7] Batch [40/114] Loss: 0.1788
# Epoch [7] Batch [50/114] Loss: 0.1628
# Epoch [7] Batch [60/114] Loss: 0.1827
# Epoch [7] Batch [70/114] Loss: 0.1486
# Epoch [7] Batch [80/114] Loss: 0.2576
# Epoch [7] Batch [90/114] Loss: 0.2971
# Epoch [7] Batch [100/114] Loss: 0.3681
# Epoch [7] Batch [110/114] Loss: 0.3219
#
# Training Loss: 0.2488
# Validation Loss: 0.2281
#
# ============================================================
# Epoch 7 - VAL
# ============================================================
# Accuracy:  0.9184
# Precision: 0.9215
# Recall:    0.9154
# F1 Score:  0.9174
#
# Confusion Matrix:
# [[630  30]
#  [ 70 496]]
#
# Per-Class Metrics:
#   cherry_clean:
#     Precision: 0.9000
#     Recall:    0.9545
#     F1:        0.9265
#   cherry_pit:
#     Precision: 0.9430
#     Recall:    0.8763
#     F1:        0.9084
# ============================================================
#
# Model weights saved: /content/drive/MyDrive/cherry_experiments/efficientnet_b2_baseline_seed42/model_best.pt
#
# New best model saved! Validation accuracy: 0.9184
#
# Epoch completed in 8.2 seconds
#
# ============================================================
# EPOCH 8/30
# ============================================================
# Epoch [8] Batch [10/114] Loss: 0.3472
# Epoch [8] Batch [20/114] Loss: 0.1994
# Epoch [8] Batch [30/114] Loss: 0.2238
# Epoch [8] Batch [40/114] Loss: 0.1481
# Epoch [8] Batch [50/114] Loss: 0.1719
# Epoch [8] Batch [60/114] Loss: 0.4285
# Epoch [8] Batch [70/114] Loss: 0.2625
# Epoch [8] Batch [80/114] Loss: 0.1843
# Epoch [8] Batch [90/114] Loss: 0.0980
# Epoch [8] Batch [100/114] Loss: 0.2211
# Epoch [8] Batch [110/114] Loss: 0.4731
#
# Training Loss: 0.2493
# Validation Loss: 0.2276
#
# ============================================================
# Epoch 8 - VAL
# ============================================================
# Accuracy:  0.9160
# Precision: 0.9156
# Recall:    0.9153
# F1 Score:  0.9155
#
# Confusion Matrix:
# [[610  50]
#  [ 53 513]]
#
# Per-Class Metrics:
#   cherry_clean:
#     Precision: 0.9201
#     Recall:    0.9242
#     F1:        0.9221
#   cherry_pit:
#     Precision: 0.9112
#     Recall:    0.9064
#     F1:        0.9088
# ============================================================
#
#
# Epoch completed in 8.4 seconds
#
# ============================================================
# EPOCH 9/30
# ============================================================
# Epoch [9] Batch [10/114] Loss: 0.3115
# Epoch [9] Batch [20/114] Loss: 0.5064
# Epoch [9] Batch [30/114] Loss: 0.1840
# Epoch [9] Batch [40/114] Loss: 0.2077
# Epoch [9] Batch [50/114] Loss: 0.1740
# Epoch [9] Batch [60/114] Loss: 0.2093
# Epoch [9] Batch [70/114] Loss: 0.1279
# Epoch [9] Batch [80/114] Loss: 0.1787
# Epoch [9] Batch [90/114] Loss: 0.1740
# Epoch [9] Batch [100/114] Loss: 0.2979
# Epoch [9] Batch [110/114] Loss: 0.1005
#
# Training Loss: 0.2397
# Validation Loss: 0.2285
#
# ============================================================
# Epoch 9 - VAL
# ============================================================
# Accuracy:  0.9258
# Precision: 0.9283
# Recall:    0.9231
# F1 Score:  0.9249
#
# Confusion Matrix:
# [[632  28]
#  [ 63 503]]
#
# Per-Class Metrics:
#   cherry_clean:
#     Precision: 0.9094
#     Recall:    0.9576
#     F1:        0.9328
#   cherry_pit:
#     Precision: 0.9473
#     Recall:    0.8887
#     F1:        0.9170
# ============================================================
#
# Model weights saved: /content/drive/MyDrive/cherry_experiments/efficientnet_b2_baseline_seed42/model_best.pt
#
# New best model saved! Validation accuracy: 0.9258
#
# Epoch completed in 8.0 seconds
#
# ============================================================
# EPOCH 10/30
# ============================================================
# Epoch [10] Batch [10/114] Loss: 0.2595
# Epoch [10] Batch [20/114] Loss: 0.1655
# Epoch [10] Batch [30/114] Loss: 0.2634
# Epoch [10] Batch [40/114] Loss: 0.2547
# Epoch [10] Batch [50/114] Loss: 0.1440
# Epoch [10] Batch [60/114] Loss: 0.2778
# Epoch [10] Batch [70/114] Loss: 0.2493
# Epoch [10] Batch [80/114] Loss: 0.1943
# Epoch [10] Batch [90/114] Loss: 0.2147
# Epoch [10] Batch [100/114] Loss: 0.2456
# Epoch [10] Batch [110/114] Loss: 0.2064
#
# Training Loss: 0.2298
# Validation Loss: 0.2258
#
# ============================================================
# Epoch 10 - VAL
# ============================================================
# Accuracy:  0.9217
# Precision: 0.9296
# Recall:    0.9170
# F1 Score:  0.9203
#
# Confusion Matrix:
# [[646  14]
#  [ 82 484]]
#
# Per-Class Metrics:
#   cherry_clean:
#     Precision: 0.8874
#     Recall:    0.9788
#     F1:        0.9308
#   cherry_pit:
#     Precision: 0.9719
#     Recall:    0.8551
#     F1:        0.9098
# ============================================================
#
# Checkpoint saved: /content/drive/MyDrive/cherry_experiments/efficientnet_b2_baseline_seed42/checkpoint_epoch_10.pt
#
# Epoch completed in 8.6 seconds
#
# ============================================================
# EPOCH 11/30
# ============================================================
# Epoch [11] Batch [10/114] Loss: 0.3539
# Epoch [11] Batch [20/114] Loss: 0.2631
# Epoch [11] Batch [30/114] Loss: 0.3729
# Epoch [11] Batch [40/114] Loss: 0.2635
# Epoch [11] Batch [50/114] Loss: 0.3152
# Epoch [11] Batch [60/114] Loss: 0.2426
# Epoch [11] Batch [70/114] Loss: 0.3394
# Epoch [11] Batch [80/114] Loss: 0.0880
# Epoch [11] Batch [90/114] Loss: 0.5391
# Epoch [11] Batch [100/114] Loss: 0.1340
# Epoch [11] Batch [110/114] Loss: 0.2389
#
# Training Loss: 0.2321
# Validation Loss: 0.2089
#
# ============================================================
# Epoch 11 - VAL
# ============================================================
# Accuracy:  0.9241
# Precision: 0.9264
# Recall:    0.9216
# F1 Score:  0.9233
#
# Confusion Matrix:
# [[630  30]
#  [ 63 503]]
#
# Per-Class Metrics:
#   cherry_clean:
#     Precision: 0.9091
#     Recall:    0.9545
#     F1:        0.9313
#   cherry_pit:
#     Precision: 0.9437
#     Recall:    0.8887
#     F1:        0.9154
# ============================================================
#
#
# Epoch completed in 7.9 seconds
#
# ============================================================
# EPOCH 12/30
# ============================================================
# Epoch [12] Batch [10/114] Loss: 0.1543
# Epoch [12] Batch [20/114] Loss: 0.1209
# Epoch [12] Batch [30/114] Loss: 0.1859
# Epoch [12] Batch [40/114] Loss: 0.1385
# Epoch [12] Batch [50/114] Loss: 0.1972
# Epoch [12] Batch [60/114] Loss: 0.1350
# Epoch [12] Batch [70/114] Loss: 0.1625
# Epoch [12] Batch [80/114] Loss: 0.1655
# Epoch [12] Batch [90/114] Loss: 0.2630
# Epoch [12] Batch [100/114] Loss: 0.1876
# Epoch [12] Batch [110/114] Loss: 0.1340
#
# Training Loss: 0.2238
# Validation Loss: 0.2084
#
# ============================================================
# Epoch 12 - VAL
# ============================================================
# Accuracy:  0.9184
# Precision: 0.9177
# Recall:    0.9183
# F1 Score:  0.9180
#
# Confusion Matrix:
# [[607  53]
#  [ 47 519]]
#
# Per-Class Metrics:
#   cherry_clean:
#     Precision: 0.9281
#     Recall:    0.9197
#     F1:        0.9239
#   cherry_pit:
#     Precision: 0.9073
#     Recall:    0.9170
#     F1:        0.9121
# ============================================================
#
#
# Epoch completed in 7.7 seconds
#
# ============================================================
# EPOCH 13/30
# ============================================================
# Epoch [13] Batch [10/114] Loss: 0.2184
# Epoch [13] Batch [20/114] Loss: 0.5389
# Epoch [13] Batch [30/114] Loss: 0.1942
# Epoch [13] Batch [40/114] Loss: 0.2392
# Epoch [13] Batch [50/114] Loss: 0.2979
# Epoch [13] Batch [60/114] Loss: 0.2535
# Epoch [13] Batch [70/114] Loss: 0.2904
# Epoch [13] Batch [80/114] Loss: 0.3096
# Epoch [13] Batch [90/114] Loss: 0.2251
# Epoch [13] Batch [100/114] Loss: 0.2177
# Epoch [13] Batch [110/114] Loss: 0.1391
#
# Training Loss: 0.2244
# Validation Loss: 0.2037
#
# ============================================================
# Epoch 13 - VAL
# ============================================================
# Accuracy:  0.9152
# Precision: 0.9152
# Recall:    0.9140
# F1 Score:  0.9146
#
# Confusion Matrix:
# [[613  47]
#  [ 57 509]]
#
# Per-Class Metrics:
#   cherry_clean:
#     Precision: 0.9149
#     Recall:    0.9288
#     F1:        0.9218
#   cherry_pit:
#     Precision: 0.9155
#     Recall:    0.8993
#     F1:        0.9073
# ============================================================
#
#
# Epoch completed in 7.8 seconds
#
# ============================================================
# EPOCH 14/30
# ============================================================
# Epoch [14] Batch [10/114] Loss: 0.2587
# Epoch [14] Batch [20/114] Loss: 0.3388
# Epoch [14] Batch [30/114] Loss: 0.1775
# Epoch [14] Batch [40/114] Loss: 0.2362
# Epoch [14] Batch [50/114] Loss: 0.1330
# Epoch [14] Batch [60/114] Loss: 0.1689
# Epoch [14] Batch [70/114] Loss: 0.4770
# Epoch [14] Batch [80/114] Loss: 0.1749
# Epoch [14] Batch [90/114] Loss: 0.1226
# Epoch [14] Batch [100/114] Loss: 0.5389
# Epoch [14] Batch [110/114] Loss: 0.1340
#
# Training Loss: 0.2321
# Validation Loss: 0.2144
#
# ============================================================
# Epoch 14 - VAL
# ============================================================
# Accuracy:  0.9176
# Precision: 0.9169
# Recall:    0.9176
# F1 Score:  0.9172
#
# Confusion Matrix:
# [[606  54]
#  [ 47 519]]
#
# Per-Class Metrics:
#   cherry_clean:
#     Precision: 0.9280
#     Recall:    0.9182
#     F1:        0.9231
#   cherry_pit:
#     Precision: 0.9058
#     Recall:    0.9170
#     F1:        0.9113
# ============================================================
#
#
# Epoch completed in 7.9 seconds
#
# ============================================================
# EPOCH 15/30
# ============================================================
# Epoch [15] Batch [10/114] Loss: 0.1710
# Epoch [15] Batch [20/114] Loss: 0.1842
# Epoch [15] Batch [30/114] Loss: 0.4194
# Epoch [15] Batch [40/114] Loss: 0.2811
# Epoch [15] Batch [50/114] Loss: 0.0979
# Epoch [15] Batch [60/114] Loss: 0.1317
# Epoch [15] Batch [70/114] Loss: 0.2694
# Epoch [15] Batch [80/114] Loss: 0.1567
# Epoch [15] Batch [90/114] Loss: 0.2108
# Epoch [15] Batch [100/114] Loss: 0.4259
# Epoch [15] Batch [110/114] Loss: 0.1681
#
# Training Loss: 0.2246
# Validation Loss: 0.1976
#
# ============================================================
# Epoch 15 - VAL
# ============================================================
# Accuracy:  0.9217
# Precision: 0.9219
# Recall:    0.9205
# F1 Score:  0.9211
#
# Confusion Matrix:
# [[618  42]
#  [ 54 512]]
#
# Per-Class Metrics:
#   cherry_clean:
#     Precision: 0.9196
#     Recall:    0.9364
#     F1:        0.9279
#   cherry_pit:
#     Precision: 0.9242
#     Recall:    0.9046
#     F1:        0.9143
# ============================================================
#
# Checkpoint saved: /content/drive/MyDrive/cherry_experiments/efficientnet_b2_baseline_seed42/checkpoint_epoch_15.pt
#
# Epoch completed in 8.2 seconds
#
# ============================================================
# EPOCH 16/30
# ============================================================
# Epoch [16] Batch [10/114] Loss: 0.2028
# Epoch [16] Batch [20/114] Loss: 0.1740
# Epoch [16] Batch [30/114] Loss: 0.1270
# Epoch [16] Batch [40/114] Loss: 0.2708
# Epoch [16] Batch [50/114] Loss: 0.2458
# Epoch [16] Batch [60/114] Loss: 0.2620
# Epoch [16] Batch [70/114] Loss: 0.1627
# Epoch [16] Batch [80/114] Loss: 0.1495
# Epoch [16] Batch [90/114] Loss: 0.2396
# Epoch [16] Batch [100/114] Loss: 0.2861
# Epoch [16] Batch [110/114] Loss: 0.1745
#
# Training Loss: 0.2124
# Validation Loss: 0.1992
#
# ============================================================
# Epoch 16 - VAL
# ============================================================
# Accuracy:  0.9233
# Precision: 0.9227
# Recall:    0.9233
# F1 Score:  0.9229
#
# Confusion Matrix:
# [[610  50]
#  [ 44 522]]
#
# Per-Class Metrics:
#   cherry_clean:
#     Precision: 0.9327
#     Recall:    0.9242
#     F1:        0.9285
#   cherry_pit:
#     Precision: 0.9126
#     Recall:    0.9223
#     F1:        0.9174
# ============================================================
#
#
# Epoch completed in 7.8 seconds
#
# ============================================================
# EPOCH 17/30
# ============================================================
# Epoch [17] Batch [10/114] Loss: 0.2984
# Epoch [17] Batch [20/114] Loss: 0.2640
# Epoch [17] Batch [30/114] Loss: 0.1760
# Epoch [17] Batch [40/114] Loss: 0.2730
# Epoch [17] Batch [50/114] Loss: 0.2198
# Epoch [17] Batch [60/114] Loss: 0.1298
# Epoch [17] Batch [70/114] Loss: 0.2948
# Epoch [17] Batch [80/114] Loss: 0.3208
# Epoch [17] Batch [90/114] Loss: 0.4213
# Epoch [17] Batch [100/114] Loss: 0.0567
# Epoch [17] Batch [110/114] Loss: 0.1700
#
# Training Loss: 0.2160
# Validation Loss: 0.1984
#
# ============================================================
# Epoch 17 - VAL
# ============================================================
# Accuracy:  0.9299
# Precision: 0.9337
# Recall:    0.9267
# F1 Score:  0.9290
#
# Confusion Matrix:
# [[639  21]
#  [ 65 501]]
#
# Per-Class Metrics:
#   cherry_clean:
#     Precision: 0.9077
#     Recall:    0.9682
#     F1:        0.9370
#   cherry_pit:
#     Precision: 0.9598
#     Recall:    0.8852
#     F1:        0.9210
# ============================================================
#
# Model weights saved: /content/drive/MyDrive/cherry_experiments/efficientnet_b2_baseline_seed42/model_best.pt
#
# New best model saved! Validation accuracy: 0.9299
#
# Epoch completed in 8.1 seconds
#
# ============================================================
# EPOCH 18/30
# ============================================================
# Epoch [18] Batch [10/114] Loss: 0.3133
# Epoch [18] Batch [20/114] Loss: 0.2397
# Epoch [18] Batch [30/114] Loss: 0.0812
# Epoch [18] Batch [40/114] Loss: 0.1602
# Epoch [18] Batch [50/114] Loss: 0.0839
# Epoch [18] Batch [60/114] Loss: 0.0864
# Epoch [18] Batch [70/114] Loss: 0.2331
# Epoch [18] Batch [80/114] Loss: 0.4156
# Epoch [18] Batch [90/114] Loss: 0.1889
# Epoch [18] Batch [100/114] Loss: 0.1355
# Epoch [18] Batch [110/114] Loss: 0.1001
#
# Training Loss: 0.2179
# Validation Loss: 0.1980
#
# ============================================================
# Epoch 18 - VAL
# ============================================================
# Accuracy:  0.9282
# Precision: 0.9300
# Recall:    0.9260
# F1 Score:  0.9275
#
# Confusion Matrix:
# [[630  30]
#  [ 58 508]]
#
# Per-Class Metrics:
#   cherry_clean:
#     Precision: 0.9157
#     Recall:    0.9545
#     F1:        0.9347
#   cherry_pit:
#     Precision: 0.9442
#     Recall:    0.8975
#     F1:        0.9203
# ============================================================
#
#
# Epoch completed in 8.1 seconds
#
# ============================================================
# EPOCH 19/30
# ============================================================
# Epoch [19] Batch [10/114] Loss: 0.1668
# Epoch [19] Batch [20/114] Loss: 0.0817
# Epoch [19] Batch [30/114] Loss: 0.1948
# Epoch [19] Batch [40/114] Loss: 0.1304
# Epoch [19] Batch [50/114] Loss: 0.1611
# Epoch [19] Batch [60/114] Loss: 0.3008
# Epoch [19] Batch [70/114] Loss: 0.3412
# Epoch [19] Batch [80/114] Loss: 0.1812
# Epoch [19] Batch [90/114] Loss: 0.3184
# Epoch [19] Batch [100/114] Loss: 0.1673
# Epoch [19] Batch [110/114] Loss: 0.3847
#
# Training Loss: 0.2077
# Validation Loss: 0.1964
#
# ============================================================
# Epoch 19 - VAL
# ============================================================
# Accuracy:  0.9201
# Precision: 0.9203
# Recall:    0.9188
# F1 Score:  0.9195
#
# Confusion Matrix:
# [[617  43]
#  [ 55 511]]
#
# Per-Class Metrics:
#   cherry_clean:
#     Precision: 0.9182
#     Recall:    0.9348
#     F1:        0.9264
#   cherry_pit:
#     Precision: 0.9224
#     Recall:    0.9028
#     F1:        0.9125
# ============================================================
#
#
# Epoch completed in 7.9 seconds
#
# ============================================================
# EPOCH 20/30
# ============================================================
# Epoch [20] Batch [10/114] Loss: 0.2062
# Epoch [20] Batch [20/114] Loss: 0.2814
# Epoch [20] Batch [30/114] Loss: 0.1176
# Epoch [20] Batch [40/114] Loss: 0.2324
# Epoch [20] Batch [50/114] Loss: 0.1276
# Epoch [20] Batch [60/114] Loss: 0.1459
# Epoch [20] Batch [70/114] Loss: 0.1817
# Epoch [20] Batch [80/114] Loss: 0.1796
# Epoch [20] Batch [90/114] Loss: 0.0948
# Epoch [20] Batch [100/114] Loss: 0.2627
# Epoch [20] Batch [110/114] Loss: 0.2391
#
# Training Loss: 0.2111
# Validation Loss: 0.1964
#
# ============================================================
# Epoch 20 - VAL
# ============================================================
# Accuracy:  0.9241
# Precision: 0.9237
# Recall:    0.9236
# F1 Score:  0.9237
#
# Confusion Matrix:
# [[614  46]
#  [ 47 519]]
#
# Per-Class Metrics:
#   cherry_clean:
#     Precision: 0.9289
#     Recall:    0.9303
#     F1:        0.9296
#   cherry_pit:
#     Precision: 0.9186
#     Recall:    0.9170
#     F1:        0.9178
# ============================================================
#
# Checkpoint saved: /content/drive/MyDrive/cherry_experiments/efficientnet_b2_baseline_seed42/checkpoint_epoch_20.pt
#
# Epoch completed in 8.4 seconds
#
# ============================================================
# EPOCH 21/30
# ============================================================
# Epoch [21] Batch [10/114] Loss: 0.0899
# Epoch [21] Batch [20/114] Loss: 0.2634
# Epoch [21] Batch [30/114] Loss: 0.0748
# Epoch [21] Batch [40/114] Loss: 0.1068
# Epoch [21] Batch [50/114] Loss: 0.1476
# Epoch [21] Batch [60/114] Loss: 0.0974
# Epoch [21] Batch [70/114] Loss: 0.2667
# Epoch [21] Batch [80/114] Loss: 0.1641
# Epoch [21] Batch [90/114] Loss: 0.0915
# Epoch [21] Batch [100/114] Loss: 0.1871
# Epoch [21] Batch [110/114] Loss: 0.2745
#
# Training Loss: 0.1981
# Validation Loss: 0.2113
#
# ============================================================
# Epoch 21 - VAL
# ============================================================
# Accuracy:  0.9209
# Precision: 0.9274
# Recall:    0.9166
# F1 Score:  0.9196
#
# Confusion Matrix:
# [[642  18]
#  [ 79 487]]
#
# Per-Class Metrics:
#   cherry_clean:
#     Precision: 0.8904
#     Recall:    0.9727
#     F1:        0.9298
#   cherry_pit:
#     Precision: 0.9644
#     Recall:    0.8604
#     F1:        0.9094
# ============================================================
#
#
# Epoch completed in 8.0 seconds
#
# ============================================================
# EPOCH 22/30
# ============================================================
# Epoch [22] Batch [10/114] Loss: 0.2452
# Epoch [22] Batch [20/114] Loss: 0.1031
# Epoch [22] Batch [30/114] Loss: 0.3840
# Epoch [22] Batch [40/114] Loss: 0.2445
# Epoch [22] Batch [50/114] Loss: 0.1879
# Epoch [22] Batch [60/114] Loss: 0.1393
# Epoch [22] Batch [70/114] Loss: 0.2495
# Epoch [22] Batch [80/114] Loss: 0.1455
# Epoch [22] Batch [90/114] Loss: 0.1293
# Epoch [22] Batch [100/114] Loss: 0.1768
# Epoch [22] Batch [110/114] Loss: 0.3916
#
# Training Loss: 0.2042
# Validation Loss: 0.2078
#
# ============================================================
# Epoch 22 - VAL
# ============================================================
# Accuracy:  0.9250
# Precision: 0.9303
# Recall:    0.9211
# F1 Score:  0.9238
#
# Confusion Matrix:
# [[641  19]
#  [ 73 493]]
#
# Per-Class Metrics:
#   cherry_clean:
#     Precision: 0.8978
#     Recall:    0.9712
#     F1:        0.9330
#   cherry_pit:
#     Precision: 0.9629
#     Recall:    0.8710
#     F1:        0.9147
# ============================================================
#
#
# Epoch completed in 7.9 seconds
#
# ============================================================
# EPOCH 23/30
# ============================================================
# Epoch [23] Batch [10/114] Loss: 0.0782
# Epoch [23] Batch [20/114] Loss: 0.0782
# Epoch [23] Batch [30/114] Loss: 0.2302
# Epoch [23] Batch [40/114] Loss: 0.1238
# Epoch [23] Batch [50/114] Loss: 0.2282
# Epoch [23] Batch [60/114] Loss: 0.1385
# Epoch [23] Batch [70/114] Loss: 0.1481
# Epoch [23] Batch [80/114] Loss: 0.1445
# Epoch [23] Batch [90/114] Loss: 0.2389
# Epoch [23] Batch [100/114] Loss: 0.0950
# Epoch [23] Batch [110/114] Loss: 0.1963
#
# Training Loss: 0.2021
# Validation Loss: 0.1827
#
# ============================================================
# Epoch 23 - VAL
# ============================================================
# Accuracy:  0.9299
# Precision: 0.9303
# Recall:    0.9286
# F1 Score:  0.9293
#
# Confusion Matrix:
# [[624  36]
#  [ 50 516]]
#
# Per-Class Metrics:
#   cherry_clean:
#     Precision: 0.9258
#     Recall:    0.9455
#     F1:        0.9355
#   cherry_pit:
#     Precision: 0.9348
#     Recall:    0.9117
#     F1:        0.9231
# ============================================================
#
#
# Epoch completed in 7.9 seconds
#
# ============================================================
# EPOCH 24/30
# ============================================================
# Epoch [24] Batch [10/114] Loss: 0.4521
# Epoch [24] Batch [20/114] Loss: 0.2358
# Epoch [24] Batch [30/114] Loss: 0.0861
# Epoch [24] Batch [40/114] Loss: 0.1258
# Epoch [24] Batch [50/114] Loss: 0.3587
# Epoch [24] Batch [60/114] Loss: 0.5208
# Epoch [24] Batch [70/114] Loss: 0.2250
# Epoch [24] Batch [80/114] Loss: 0.3082
# Epoch [24] Batch [90/114] Loss: 0.1595
# Epoch [24] Batch [100/114] Loss: 0.1386
# Epoch [24] Batch [110/114] Loss: 0.3506
#
# Training Loss: 0.2016
# Validation Loss: 0.1904
#
# ============================================================
# Epoch 24 - VAL
# ============================================================
# Accuracy:  0.9266
# Precision: 0.9281
# Recall:    0.9245
# F1 Score:  0.9259
#
# Confusion Matrix:
# [[628  32]
#  [ 58 508]]
#
# Per-Class Metrics:
#   cherry_clean:
#     Precision: 0.9155
#     Recall:    0.9515
#     F1:        0.9331
#   cherry_pit:
#     Precision: 0.9407
#     Recall:    0.8975
#     F1:        0.9186
# ============================================================
#
#
# Epoch completed in 8.0 seconds
#
# ============================================================
# EPOCH 25/30
# ============================================================
# Epoch [25] Batch [10/114] Loss: 0.1741
# Epoch [25] Batch [20/114] Loss: 0.1587
# Epoch [25] Batch [30/114] Loss: 0.1537
# Epoch [25] Batch [40/114] Loss: 0.0894
# Epoch [25] Batch [50/114] Loss: 0.1087
# Epoch [25] Batch [60/114] Loss: 0.3921
# Epoch [25] Batch [70/114] Loss: 0.2013
# Epoch [25] Batch [80/114] Loss: 0.2518
# Epoch [25] Batch [90/114] Loss: 0.3101
# Epoch [25] Batch [100/114] Loss: 0.1806
# Epoch [25] Batch [110/114] Loss: 0.1390
#
# Training Loss: 0.1946
# Validation Loss: 0.1978
#
# ============================================================
# Epoch 25 - VAL
# ============================================================
# Accuracy:  0.9274
# Precision: 0.9314
# Recall:    0.9241
# F1 Score:  0.9265
#
# Confusion Matrix:
# [[638  22]
#  [ 67 499]]
#
# Per-Class Metrics:
#   cherry_clean:
#     Precision: 0.9050
#     Recall:    0.9667
#     F1:        0.9348
#   cherry_pit:
#     Precision: 0.9578
#     Recall:    0.8816
#     F1:        0.9181
# ============================================================
#
# Checkpoint saved: /content/drive/MyDrive/cherry_experiments/efficientnet_b2_baseline_seed42/checkpoint_epoch_25.pt
#
# Epoch completed in 8.0 seconds
#
# ============================================================
# EPOCH 26/30
# ============================================================
# Epoch [26] Batch [10/114] Loss: 0.1121
# Epoch [26] Batch [20/114] Loss: 0.1575
# Epoch [26] Batch [30/114] Loss: 0.1918
# Epoch [26] Batch [40/114] Loss: 0.1943
# Epoch [26] Batch [50/114] Loss: 0.2108
# Epoch [26] Batch [60/114] Loss: 0.2132
# Epoch [26] Batch [70/114] Loss: 0.1187
# Epoch [26] Batch [80/114] Loss: 0.1949
# Epoch [26] Batch [90/114] Loss: 0.2129
# Epoch [26] Batch [100/114] Loss: 0.3269
# Epoch [26] Batch [110/114] Loss: 0.1157
#
# Training Loss: 0.1932
# Validation Loss: 0.1908
#
# ============================================================
# Epoch 26 - VAL
# ============================================================
# Accuracy:  0.9274
# Precision: 0.9278
# Recall:    0.9262
# F1 Score:  0.9268
#
# Confusion Matrix:
# [[622  38]
#  [ 51 515]]
#
# Per-Class Metrics:
#   cherry_clean:
#     Precision: 0.9242
#     Recall:    0.9424
#     F1:        0.9332
#   cherry_pit:
#     Precision: 0.9313
#     Recall:    0.9099
#     F1:        0.9205
# ============================================================
#
#
# Epoch completed in 8.0 seconds
#
# ============================================================
# EPOCH 27/30
# ============================================================
# Epoch [27] Batch [10/114] Loss: 0.0884
# Epoch [27] Batch [20/114] Loss: 0.3047
# Epoch [27] Batch [30/114] Loss: 0.1800
# Epoch [27] Batch [40/114] Loss: 0.1097
# Epoch [27] Batch [50/114] Loss: 0.2804
# Epoch [27] Batch [60/114] Loss: 0.0874
# Epoch [27] Batch [70/114] Loss: 0.3020
# Epoch [27] Batch [80/114] Loss: 0.2490
# Epoch [27] Batch [90/114] Loss: 0.0487
# Epoch [27] Batch [100/114] Loss: 0.2724
# Epoch [27] Batch [110/114] Loss: 0.0870
#
# Training Loss: 0.1899
# Validation Loss: 0.1913
#
# ============================================================
# Epoch 27 - VAL
# ============================================================
# Accuracy:  0.9266
# Precision: 0.9270
# Recall:    0.9253
# F1 Score:  0.9260
#
# Confusion Matrix:
# [[622  38]
#  [ 52 514]]
#
# Per-Class Metrics:
#   cherry_clean:
#     Precision: 0.9228
#     Recall:    0.9424
#     F1:        0.9325
#   cherry_pit:
#     Precision: 0.9312
#     Recall:    0.9081
#     F1:        0.9195
# ============================================================
#
#
# Epoch completed in 8.0 seconds
#
# ============================================================
# EPOCH 28/30
# ============================================================
# Epoch [28] Batch [10/114] Loss: 0.1934
# Epoch [28] Batch [20/114] Loss: 0.3135
# Epoch [28] Batch [30/114] Loss: 0.1768
# Epoch [28] Batch [40/114] Loss: 0.1606
# Epoch [28] Batch [50/114] Loss: 0.3593
# Epoch [28] Batch [60/114] Loss: 0.1438
# Epoch [28] Batch [70/114] Loss: 0.1698
# Epoch [28] Batch [80/114] Loss: 0.2855
# Epoch [28] Batch [90/114] Loss: 0.1350
# Epoch [28] Batch [100/114] Loss: 0.2427
# Epoch [28] Batch [110/114] Loss: 0.0806
#
# Training Loss: 0.1974
# Validation Loss: 0.1905
#
# ============================================================
# Epoch 28 - VAL
# ============================================================
# Accuracy:  0.9250
# Precision: 0.9259
# Recall:    0.9233
# F1 Score:  0.9243
#
# Confusion Matrix:
# [[624  36]
#  [ 56 510]]
#
# Per-Class Metrics:
#   cherry_clean:
#     Precision: 0.9176
#     Recall:    0.9455
#     F1:        0.9313
#   cherry_pit:
#     Precision: 0.9341
#     Recall:    0.9011
#     F1:        0.9173
# ============================================================
#
#
# Epoch completed in 7.6 seconds
#
# ============================================================
# EPOCH 29/30
# ============================================================
# Epoch [29] Batch [10/114] Loss: 0.0707
# Epoch [29] Batch [20/114] Loss: 0.3725
# Epoch [29] Batch [30/114] Loss: 0.1455
# Epoch [29] Batch [40/114] Loss: 0.1804
# Epoch [29] Batch [50/114] Loss: 0.0958
# Epoch [29] Batch [60/114] Loss: 0.0527
# Epoch [29] Batch [70/114] Loss: 0.2051
# Epoch [29] Batch [80/114] Loss: 0.1724
# Epoch [29] Batch [90/114] Loss: 0.3394
# Epoch [29] Batch [100/114] Loss: 0.2177
# Epoch [29] Batch [110/114] Loss: 0.1283
#
# Training Loss: 0.1890
# Validation Loss: 0.1945
#
# ============================================================
# Epoch 29 - VAL
# ============================================================
# Accuracy:  0.9307
# Precision: 0.9350
# Recall:    0.9273
# F1 Score:  0.9297
#
# Confusion Matrix:
# [[641  19]
#  [ 66 500]]
#
# Per-Class Metrics:
#   cherry_clean:
#     Precision: 0.9066
#     Recall:    0.9712
#     F1:        0.9378
#   cherry_pit:
#     Precision: 0.9634
#     Recall:    0.8834
#     F1:        0.9217
# ============================================================
#
# Model weights saved: /content/drive/MyDrive/cherry_experiments/efficientnet_b2_baseline_seed42/model_best.pt
#
# New best model saved! Validation accuracy: 0.9307
#
# Epoch completed in 8.2 seconds
#
# ============================================================
# EPOCH 30/30
# ============================================================
# Epoch [30] Batch [10/114] Loss: 0.1361
# Epoch [30] Batch [20/114] Loss: 0.1802
# Epoch [30] Batch [30/114] Loss: 0.1740
# Epoch [30] Batch [40/114] Loss: 0.1293
# Epoch [30] Batch [50/114] Loss: 0.1039
# Epoch [30] Batch [60/114] Loss: 0.3638
# Epoch [30] Batch [70/114] Loss: 0.2873
# Epoch [30] Batch [80/114] Loss: 0.3629
# Epoch [30] Batch [90/114] Loss: 0.1428
# Epoch [30] Batch [100/114] Loss: 0.0706
# Epoch [30] Batch [110/114] Loss: 0.2631
#
# Training Loss: 0.1930
# Validation Loss: 0.1850
#
# ============================================================
# Epoch 30 - VAL
# ============================================================
# Accuracy:  0.9225
# Precision: 0.9225
# Recall:    0.9215
# F1 Score:  0.9220
#
# Confusion Matrix:
# [[617  43]
#  [ 52 514]]
#
# Per-Class Metrics:
#   cherry_clean:
#     Precision: 0.9223
#     Recall:    0.9348
#     F1:        0.9285
#   cherry_pit:
#     Precision: 0.9228
#     Recall:    0.9081
#     F1:        0.9154
# ============================================================
#
# Checkpoint saved: /content/drive/MyDrive/cherry_experiments/efficientnet_b2_baseline_seed42/checkpoint_epoch_30.pt
#
# Epoch completed in 8.2 seconds
# Model weights saved: /content/drive/MyDrive/cherry_experiments/efficientnet_b2_baseline_seed42/model_final.pt
#
# ============================================================
# TRAINING COMPLETE
# ============================================================
# Final model saved to: /content/drive/MyDrive/cherry_experiments/efficientnet_b2_baseline_seed42/model_final.pt
# Best validation accuracy: 0.9307
# Logs saved to: /content/drive/MyDrive/cherry_experiments/efficientnet_b2_baseline_seed42/metrics.json
#
# ============================================================
# Training complete! Results: /content/drive/MyDrive/cherry_experiments/efficientnet_b2_baseline_seed42
# ============================================================

# %% [markdown]
# ## Cell 9: EXP-003B - EfficientNet-B2 with Label Smoothing

# %%
if SKIP_EXP_003B:
    print("EXP-003B: SKIPPED (set SKIP_EXP_003B=False to run)")
else:
    print("\n" + "=" * 60)
    print("RUNNING EXP-003B: EfficientNet-B2 with Label Smoothing")
    print("=" * 60)

    # Set random seed
    random.seed(RANDOM_SEED)
    np.random.seed(RANDOM_SEED)
    torch.manual_seed(RANDOM_SEED)
    if torch.cuda.is_available():
        torch.cuda.manual_seed_all(RANDOM_SEED)

    print(f"Random seed set: {RANDOM_SEED}")
    print("Label smoothing: alpha=0.1")

    # Load config
    config_path = "/content/cherries/training/configs/experiments/efficientnet_b2_label_smooth_seed42.yaml"

    with open(config_path, 'r') as f:
        config = yaml.safe_load(f)

    # Override paths
    config['checkpointing']['output_dir'] = f"{DRIVE_BASE_PATH}/efficientnet_b2_label_smooth_seed42"
    config['data']['root'] = DATA_PATH

    # Apply smoke test settings
    if SMOKE_TEST:
        print("\nSMOKE TEST MODE: 1 epoch, 3 batches")
        config['training']['epochs'] = 1
        config['checkpointing']['save_every'] = 1

    # Save temp config
    temp_config = "/tmp/efficientnet_b2_label_smooth_seed42.yaml"
    with open(temp_config, 'w') as f:
        yaml.dump(config, f)

    # Run training
    # !python /content/cherries/training/scripts/train.py \
        --config {temp_config} \
        --data-root {DATA_PATH}

    print("\n" + "=" * 60)
    print(f"Training complete! Results: {config['checkpointing']['output_dir']}")
    print("=" * 60)
# Out:
# ============================================================
# RUNNING EXP-003B: EfficientNet-B2 with Label Smoothing
# ============================================================
# Random seed set: 42
# Label smoothing: alpha=0.1
# Using cache found in /root/.cache/torch/hub/facebookresearch_dinov2_main
# /root/.cache/torch/hub/facebookresearch_dinov2_main/dinov2/layers/swiglu_ffn.py:51: UserWarning: xFormers is not available (SwiGLU)
#   warnings.warn("xFormers is not available (SwiGLU)")
# /root/.cache/torch/hub/facebookresearch_dinov2_main/dinov2/layers/attention.py:33: UserWarning: xFormers is not available (Attention)
#   warnings.warn("xFormers is not available (Attention)")
# /root/.cache/torch/hub/facebookresearch_dinov2_main/dinov2/layers/block.py:40: UserWarning: xFormers is not available (Block)
#   warnings.warn("xFormers is not available (Block)")
#
# Loading config from: /tmp/efficientnet_b2_label_smooth_seed42.yaml
# Output directory: /content/drive/MyDrive/cherry_experiments/efficientnet_b2_label_smooth_seed42
# Config saved to: /content/drive/MyDrive/cherry_experiments/efficientnet_b2_label_smooth_seed42/config.yaml
# Using device: cuda
#
# ============================================================
# LOADING DATA
# ============================================================
#
# Dataset loaded from: /content/cherry_classification/data
# Training samples: 3676
# Validation samples: 1226
# Classes: ['cherry_clean', 'cherry_pit']
# Class distribution (train): {'cherry_clean': 1978, 'cherry_pit': 1698}
# Class distribution (val): {'cherry_clean': 660, 'cherry_pit': 566}
#
# Class names: ['cherry_clean', 'cherry_pit']
#
# ============================================================
# CREATING MODEL
# ============================================================
# Architecture: efficientnet_b2
# Loaded EfficientNet-B2 with ImageNet weights
# Replaced classifier head: Linear(1408, 2)
# Model moved to device: cuda
# Optimizer: adam
# Learning rate: 0.0001
# Weight decay: 1e-05
# Using CrossEntropyLoss with label_smoothing=0.1
#
# ============================================================
# STARTING TRAINING
# ============================================================
# Training for 30 epochs
# Starting from epoch 0
#
# ============================================================
# EPOCH 1/30
# ============================================================
# Epoch [1] Batch [10/114] Loss: 0.7249
# Epoch [1] Batch [20/114] Loss: 0.6350
# Epoch [1] Batch [30/114] Loss: 0.5600
# Epoch [1] Batch [40/114] Loss: 0.4849
# Epoch [1] Batch [50/114] Loss: 0.5097
# Epoch [1] Batch [60/114] Loss: 0.3995
# Epoch [1] Batch [70/114] Loss: 0.6100
# Epoch [1] Batch [80/114] Loss: 0.3687
# Epoch [1] Batch [90/114] Loss: 0.4419
# Epoch [1] Batch [100/114] Loss: 0.4817
# Epoch [1] Batch [110/114] Loss: 0.3528
#
# Training Loss: 0.5012
# Validation Loss: 0.4094
#
# ============================================================
# Epoch 1 - VAL
# ============================================================
# Accuracy:  0.8679
# Precision: 0.8782
# Recall:    0.8614
# F1 Score:  0.8648
#
# Confusion Matrix:
# [[624  36]
#  [126 440]]
#
# Per-Class Metrics:
#   cherry_clean:
#     Precision: 0.8320
#     Recall:    0.9455
#     F1:        0.8851
#   cherry_pit:
#     Precision: 0.9244
#     Recall:    0.7774
#     F1:        0.8445
# ============================================================
#
# Model weights saved: /content/drive/MyDrive/cherry_experiments/efficientnet_b2_label_smooth_seed42/model_best.pt
#
# New best model saved! Validation accuracy: 0.8679
#
# Epoch completed in 9.5 seconds
#
# ============================================================
# EPOCH 2/30
# ============================================================
# Epoch [2] Batch [10/114] Loss: 0.3684
# Epoch [2] Batch [20/114] Loss: 0.3426
# Epoch [2] Batch [30/114] Loss: 0.3919
# Epoch [2] Batch [40/114] Loss: 0.4540
# Epoch [2] Batch [50/114] Loss: 0.3862
# Epoch [2] Batch [60/114] Loss: 0.4095
# Epoch [2] Batch [70/114] Loss: 0.4129
# Epoch [2] Batch [80/114] Loss: 0.3829
# Epoch [2] Batch [90/114] Loss: 0.3811
# Epoch [2] Batch [100/114] Loss: 0.5308
# Epoch [2] Batch [110/114] Loss: 0.4128
#
# Training Loss: 0.4131
# Validation Loss: 0.3595
#
# ============================================================
# Epoch 2 - VAL
# ============================================================
# Accuracy:  0.8997
# Precision: 0.9005
# Recall:    0.8976
# F1 Score:  0.8988
#
# Confusion Matrix:
# [[610  50]
#  [ 73 493]]
#
# Per-Class Metrics:
#   cherry_clean:
#     Precision: 0.8931
#     Recall:    0.9242
#     F1:        0.9084
#   cherry_pit:
#     Precision: 0.9079
#     Recall:    0.8710
#     F1:        0.8891
# ============================================================
#
# Model weights saved: /content/drive/MyDrive/cherry_experiments/efficientnet_b2_label_smooth_seed42/model_best.pt
#
# New best model saved! Validation accuracy: 0.8997
#
# Epoch completed in 8.4 seconds
#
# ============================================================
# EPOCH 3/30
# ============================================================
# Epoch [3] Batch [10/114] Loss: 0.3455
# Epoch [3] Batch [20/114] Loss: 0.2739
# Epoch [3] Batch [30/114] Loss: 0.3662
# Epoch [3] Batch [40/114] Loss: 0.3152
# Epoch [3] Batch [50/114] Loss: 0.3876
# Epoch [3] Batch [60/114] Loss: 0.4073
# Epoch [3] Batch [70/114] Loss: 0.4949
# Epoch [3] Batch [80/114] Loss: 0.4146
# Epoch [3] Batch [90/114] Loss: 0.3155
# Epoch [3] Batch [100/114] Loss: 0.3689
# Epoch [3] Batch [110/114] Loss: 0.4915
#
# Training Loss: 0.3896
# Validation Loss: 0.3552
#
# ============================================================
# Epoch 3 - VAL
# ============================================================
# Accuracy:  0.9119
# Precision: 0.9169
# Recall:    0.9080
# F1 Score:  0.9106
#
# Confusion Matrix:
# [[633  27]
#  [ 81 485]]
#
# Per-Class Metrics:
#   cherry_clean:
#     Precision: 0.8866
#     Recall:    0.9591
#     F1:        0.9214
#   cherry_pit:
#     Precision: 0.9473
#     Recall:    0.8569
#     F1:        0.8998
# ============================================================
#
# Model weights saved: /content/drive/MyDrive/cherry_experiments/efficientnet_b2_label_smooth_seed42/model_best.pt
#
# New best model saved! Validation accuracy: 0.9119
#
# Epoch completed in 8.4 seconds
#
# ============================================================
# EPOCH 4/30
# ============================================================
# Epoch [4] Batch [10/114] Loss: 0.4583
# Epoch [4] Batch [20/114] Loss: 0.3292
# Epoch [4] Batch [30/114] Loss: 0.3500
# Epoch [4] Batch [40/114] Loss: 0.5063
# Epoch [4] Batch [50/114] Loss: 0.4551
# Epoch [4] Batch [60/114] Loss: 0.3492
# Epoch [4] Batch [70/114] Loss: 0.3948
# Epoch [4] Batch [80/114] Loss: 0.3409
# Epoch [4] Batch [90/114] Loss: 0.4742
# Epoch [4] Batch [100/114] Loss: 0.4074
# Epoch [4] Batch [110/114] Loss: 0.5378
#
# Training Loss: 0.3931
# Validation Loss: 0.3507
#
# ============================================================
# Epoch 4 - VAL
# ============================================================
# Accuracy:  0.9192
# Precision: 0.9246
# Recall:    0.9153
# F1 Score:  0.9180
#
# Confusion Matrix:
# [[638  22]
#  [ 77 489]]
#
# Per-Class Metrics:
#   cherry_clean:
#     Precision: 0.8923
#     Recall:    0.9667
#     F1:        0.9280
#   cherry_pit:
#     Precision: 0.9569
#     Recall:    0.8640
#     F1:        0.9081
# ============================================================
#
# Model weights saved: /content/drive/MyDrive/cherry_experiments/efficientnet_b2_label_smooth_seed42/model_best.pt
#
# New best model saved! Validation accuracy: 0.9192
#
# Epoch completed in 8.3 seconds
#
# ============================================================
# EPOCH 5/30
# ============================================================
# Epoch [5] Batch [10/114] Loss: 0.3277
# Epoch [5] Batch [20/114] Loss: 0.3688
# Epoch [5] Batch [30/114] Loss: 0.3141
# Epoch [5] Batch [40/114] Loss: 0.3103
# Epoch [5] Batch [50/114] Loss: 0.4182
# Epoch [5] Batch [60/114] Loss: 0.4435
# Epoch [5] Batch [70/114] Loss: 0.3234
# Epoch [5] Batch [80/114] Loss: 0.2696
# Epoch [5] Batch [90/114] Loss: 0.2844
# Epoch [5] Batch [100/114] Loss: 0.2680
# Epoch [5] Batch [110/114] Loss: 0.4243
#
# Training Loss: 0.3781
# Validation Loss: 0.3422
#
# ============================================================
# Epoch 5 - VAL
# ============================================================
# Accuracy:  0.9152
# Precision: 0.9150
# Recall:    0.9143
# F1 Score:  0.9146
#
# Confusion Matrix:
# [[611  49]
#  [ 55 511]]
#
# Per-Class Metrics:
#   cherry_clean:
#     Precision: 0.9174
#     Recall:    0.9258
#     F1:        0.9216
#   cherry_pit:
#     Precision: 0.9125
#     Recall:    0.9028
#     F1:        0.9076
# ============================================================
#
# Checkpoint saved: /content/drive/MyDrive/cherry_experiments/efficientnet_b2_label_smooth_seed42/checkpoint_epoch_5.pt
#
# Epoch completed in 8.4 seconds
#
# ============================================================
# EPOCH 6/30
# ============================================================
# Epoch [6] Batch [10/114] Loss: 0.3754
# Epoch [6] Batch [20/114] Loss: 0.3219
# Epoch [6] Batch [30/114] Loss: 0.3905
# Epoch [6] Batch [40/114] Loss: 0.2855
# Epoch [6] Batch [50/114] Loss: 0.4763
# Epoch [6] Batch [60/114] Loss: 0.4263
# Epoch [6] Batch [70/114] Loss: 0.3389
# Epoch [6] Batch [80/114] Loss: 0.3647
# Epoch [6] Batch [90/114] Loss: 0.2930
# Epoch [6] Batch [100/114] Loss: 0.4379
# Epoch [6] Batch [110/114] Loss: 0.3327
#
# Training Loss: 0.3729
# Validation Loss: 0.3464
#
# ============================================================
# Epoch 6 - VAL
# ============================================================
# Accuracy:  0.9046
# Precision: 0.9037
# Recall:    0.9048
# F1 Score:  0.9041
#
# Confusion Matrix:
# [[595  65]
#  [ 52 514]]
#
# Per-Class Metrics:
#   cherry_clean:
#     Precision: 0.9196
#     Recall:    0.9015
#     F1:        0.9105
#   cherry_pit:
#     Precision: 0.8877
#     Recall:    0.9081
#     F1:        0.8978
# ============================================================
#
#
# Epoch completed in 8.0 seconds
#
# ============================================================
# EPOCH 7/30
# ============================================================
# Epoch [7] Batch [10/114] Loss: 0.2560
# Epoch [7] Batch [20/114] Loss: 0.3228
# Epoch [7] Batch [30/114] Loss: 0.3030
# Epoch [7] Batch [40/114] Loss: 0.4676
# Epoch [7] Batch [50/114] Loss: 0.4423
# Epoch [7] Batch [60/114] Loss: 0.3147
# Epoch [7] Batch [70/114] Loss: 0.3582
# Epoch [7] Batch [80/114] Loss: 0.4072
# Epoch [7] Batch [90/114] Loss: 0.3838
# Epoch [7] Batch [100/114] Loss: 0.3095
# Epoch [7] Batch [110/114] Loss: 0.3738
#
# Training Loss: 0.3722
# Validation Loss: 0.3366
#
# ============================================================
# Epoch 7 - VAL
# ============================================================
# Accuracy:  0.9192
# Precision: 0.9187
# Recall:    0.9190
# F1 Score:  0.9188
#
# Confusion Matrix:
# [[609  51]
#  [ 48 518]]
#
# Per-Class Metrics:
#   cherry_clean:
#     Precision: 0.9269
#     Recall:    0.9227
#     F1:        0.9248
#   cherry_pit:
#     Precision: 0.9104
#     Recall:    0.9152
#     F1:        0.9128
# ============================================================
#
#
# Epoch completed in 7.9 seconds
#
# ============================================================
# EPOCH 8/30
# ============================================================
# Epoch [8] Batch [10/114] Loss: 0.3878
# Epoch [8] Batch [20/114] Loss: 0.3273
# Epoch [8] Batch [30/114] Loss: 0.4047
# Epoch [8] Batch [40/114] Loss: 0.3484
# Epoch [8] Batch [50/114] Loss: 0.3367
# Epoch [8] Batch [60/114] Loss: 0.3374
# Epoch [8] Batch [70/114] Loss: 0.4059
# Epoch [8] Batch [80/114] Loss: 0.3246
# Epoch [8] Batch [90/114] Loss: 0.2913
# Epoch [8] Batch [100/114] Loss: 0.4646
# Epoch [8] Batch [110/114] Loss: 0.4562
#
# Training Loss: 0.3569
# Validation Loss: 0.3423
#
# ============================================================
# Epoch 8 - VAL
# ============================================================
# Accuracy:  0.9127
# Precision: 0.9132
# Recall:    0.9111
# F1 Score:  0.9120
#
# Confusion Matrix:
# [[615  45]
#  [ 62 504]]
#
# Per-Class Metrics:
#   cherry_clean:
#     Precision: 0.9084
#     Recall:    0.9318
#     F1:        0.9200
#   cherry_pit:
#     Precision: 0.9180
#     Recall:    0.8905
#     F1:        0.9040
# ============================================================
#
#
# Epoch completed in 7.9 seconds
#
# ============================================================
# EPOCH 9/30
# ============================================================
# Epoch [9] Batch [10/114] Loss: 0.4883
# Epoch [9] Batch [20/114] Loss: 0.4093
# Epoch [9] Batch [30/114] Loss: 0.4133
# Epoch [9] Batch [40/114] Loss: 0.3993
# Epoch [9] Batch [50/114] Loss: 0.2965
# Epoch [9] Batch [60/114] Loss: 0.3985
# Epoch [9] Batch [70/114] Loss: 0.3920
# Epoch [9] Batch [80/114] Loss: 0.2758
# Epoch [9] Batch [90/114] Loss: 0.3412
# Epoch [9] Batch [100/114] Loss: 0.3156
# Epoch [9] Batch [110/114] Loss: 0.2854
#
# Training Loss: 0.3605
# Validation Loss: 0.3373
#
# ============================================================
# Epoch 9 - VAL
# ============================================================
# Accuracy:  0.9184
# Precision: 0.9196
# Recall:    0.9164
# F1 Score:  0.9177
#
# Confusion Matrix:
# [[622  38]
#  [ 62 504]]
#
# Per-Class Metrics:
#   cherry_clean:
#     Precision: 0.9094
#     Recall:    0.9424
#     F1:        0.9256
#   cherry_pit:
#     Precision: 0.9299
#     Recall:    0.8905
#     F1:        0.9097
# ============================================================
#
#
# Epoch completed in 8.2 seconds
#
# ============================================================
# EPOCH 10/30
# ============================================================
# Epoch [10] Batch [10/114] Loss: 0.4123
# Epoch [10] Batch [20/114] Loss: 0.4048
# Epoch [10] Batch [30/114] Loss: 0.4468
# Epoch [10] Batch [40/114] Loss: 0.3648
# Epoch [10] Batch [50/114] Loss: 0.3076
# Epoch [10] Batch [60/114] Loss: 0.2698
# Epoch [10] Batch [70/114] Loss: 0.2705
# Epoch [10] Batch [80/114] Loss: 0.3621
# Epoch [10] Batch [90/114] Loss: 0.2671
# Epoch [10] Batch [100/114] Loss: 0.4040
# Epoch [10] Batch [110/114] Loss: 0.3664
#
# Training Loss: 0.3543
# Validation Loss: 0.3367
#
# ============================================================
# Epoch 10 - VAL
# ============================================================
# Accuracy:  0.9274
# Precision: 0.9295
# Recall:    0.9250
# F1 Score:  0.9266
#
# Confusion Matrix:
# [[631  29]
#  [ 60 506]]
#
# Per-Class Metrics:
#   cherry_clean:
#     Precision: 0.9132
#     Recall:    0.9561
#     F1:        0.9341
#   cherry_pit:
#     Precision: 0.9458
#     Recall:    0.8940
#     F1:        0.9192
# ============================================================
#
# Checkpoint saved: /content/drive/MyDrive/cherry_experiments/efficientnet_b2_label_smooth_seed42/checkpoint_epoch_10.pt
# Model weights saved: /content/drive/MyDrive/cherry_experiments/efficientnet_b2_label_smooth_seed42/model_best.pt
#
# New best model saved! Validation accuracy: 0.9274
#
# Epoch completed in 8.5 seconds
#
# ============================================================
# EPOCH 11/30
# ============================================================
# Epoch [11] Batch [10/114] Loss: 0.4643
# Epoch [11] Batch [20/114] Loss: 0.4185
# Epoch [11] Batch [30/114] Loss: 0.3535
# Epoch [11] Batch [40/114] Loss: 0.3553
# Epoch [11] Batch [50/114] Loss: 0.3227
# Epoch [11] Batch [60/114] Loss: 0.3304
# Epoch [11] Batch [70/114] Loss: 0.3561
# Epoch [11] Batch [80/114] Loss: 0.3345
# Epoch [11] Batch [90/114] Loss: 0.3393
# Epoch [11] Batch [100/114] Loss: 0.4191
# Epoch [11] Batch [110/114] Loss: 0.3448
#
# Training Loss: 0.3509
# Validation Loss: 0.3352
#
# ============================================================
# Epoch 11 - VAL
# ============================================================
# Accuracy:  0.9111
# Precision: 0.9106
# Recall:    0.9105
# F1 Score:  0.9106
#
# Confusion Matrix:
# [[606  54]
#  [ 55 511]]
#
# Per-Class Metrics:
#   cherry_clean:
#     Precision: 0.9168
#     Recall:    0.9182
#     F1:        0.9175
#   cherry_pit:
#     Precision: 0.9044
#     Recall:    0.9028
#     F1:        0.9036
# ============================================================
#
#
# Epoch completed in 8.6 seconds
#
# ============================================================
# EPOCH 12/30
# ============================================================
# Epoch [12] Batch [10/114] Loss: 0.4601
# Epoch [12] Batch [20/114] Loss: 0.3188
# Epoch [12] Batch [30/114] Loss: 0.3983
# Epoch [12] Batch [40/114] Loss: 0.3142
# Epoch [12] Batch [50/114] Loss: 0.2954
# Epoch [12] Batch [60/114] Loss: 0.2777
# Epoch [12] Batch [70/114] Loss: 0.4153
# Epoch [12] Batch [80/114] Loss: 0.2765
# Epoch [12] Batch [90/114] Loss: 0.4578
# Epoch [12] Batch [100/114] Loss: 0.4730
# Epoch [12] Batch [110/114] Loss: 0.3982
#
# Training Loss: 0.3464
# Validation Loss: 0.3332
#
# ============================================================
# Epoch 12 - VAL
# ============================================================
# Accuracy:  0.9282
# Precision: 0.9298
# Recall:    0.9262
# F1 Score:  0.9275
#
# Confusion Matrix:
# [[629  31]
#  [ 57 509]]
#
# Per-Class Metrics:
#   cherry_clean:
#     Precision: 0.9169
#     Recall:    0.9530
#     F1:        0.9346
#   cherry_pit:
#     Precision: 0.9426
#     Recall:    0.8993
#     F1:        0.9204
# ============================================================
#
# Model weights saved: /content/drive/MyDrive/cherry_experiments/efficientnet_b2_label_smooth_seed42/model_best.pt
#
# New best model saved! Validation accuracy: 0.9282
#
# Epoch completed in 8.1 seconds
#
# ============================================================
# EPOCH 13/30
# ============================================================
# Epoch [13] Batch [10/114] Loss: 0.3298
# Epoch [13] Batch [20/114] Loss: 0.3465
# Epoch [13] Batch [30/114] Loss: 0.2514
# Epoch [13] Batch [40/114] Loss: 0.3858
# Epoch [13] Batch [50/114] Loss: 0.4070
# Epoch [13] Batch [60/114] Loss: 0.2843
# Epoch [13] Batch [70/114] Loss: 0.3703
# Epoch [13] Batch [80/114] Loss: 0.3852
# Epoch [13] Batch [90/114] Loss: 0.3103
# Epoch [13] Batch [100/114] Loss: 0.3098
# Epoch [13] Batch [110/114] Loss: 0.4127
#
# Training Loss: 0.3495
# Validation Loss: 0.3330
#
# ============================================================
# Epoch 13 - VAL
# ============================================================
# Accuracy:  0.9233
# Precision: 0.9239
# Recall:    0.9219
# F1 Score:  0.9227
#
# Confusion Matrix:
# [[621  39]
#  [ 55 511]]
#
# Per-Class Metrics:
#   cherry_clean:
#     Precision: 0.9186
#     Recall:    0.9409
#     F1:        0.9296
#   cherry_pit:
#     Precision: 0.9291
#     Recall:    0.9028
#     F1:        0.9158
# ============================================================
#
#
# Epoch completed in 8.1 seconds
#
# ============================================================
# EPOCH 14/30
# ============================================================
# Epoch [14] Batch [10/114] Loss: 0.3925
# Epoch [14] Batch [20/114] Loss: 0.2512
# Epoch [14] Batch [30/114] Loss: 0.3167
# Epoch [14] Batch [40/114] Loss: 0.4236
# Epoch [14] Batch [50/114] Loss: 0.3973
# Epoch [14] Batch [60/114] Loss: 0.3581
# Epoch [14] Batch [70/114] Loss: 0.4325
# Epoch [14] Batch [80/114] Loss: 0.3899
# Epoch [14] Batch [90/114] Loss: 0.4682
# Epoch [14] Batch [100/114] Loss: 0.4080
# Epoch [14] Batch [110/114] Loss: 0.4136
#
# Training Loss: 0.3453
# Validation Loss: 0.3296
#
# ============================================================
# Epoch 14 - VAL
# ============================================================
# Accuracy:  0.9201
# Precision: 0.9201
# Recall:    0.9190
# F1 Score:  0.9195
#
# Confusion Matrix:
# [[616  44]
#  [ 54 512]]
#
# Per-Class Metrics:
#   cherry_clean:
#     Precision: 0.9194
#     Recall:    0.9333
#     F1:        0.9263
#   cherry_pit:
#     Precision: 0.9209
#     Recall:    0.9046
#     F1:        0.9127
# ============================================================
#
#
# Epoch completed in 8.2 seconds
#
# ============================================================
# EPOCH 15/30
# ============================================================
# Epoch [15] Batch [10/114] Loss: 0.3459
# Epoch [15] Batch [20/114] Loss: 0.4034
# Epoch [15] Batch [30/114] Loss: 0.2241
# Epoch [15] Batch [40/114] Loss: 0.3195
# Epoch [15] Batch [50/114] Loss: 0.3524
# Epoch [15] Batch [60/114] Loss: 0.2813
# Epoch [15] Batch [70/114] Loss: 0.3879
# Epoch [15] Batch [80/114] Loss: 0.3648
# Epoch [15] Batch [90/114] Loss: 0.3309
# Epoch [15] Batch [100/114] Loss: 0.3216
# Epoch [15] Batch [110/114] Loss: 0.3208
#
# Training Loss: 0.3415
# Validation Loss: 0.3275
#
# ============================================================
# Epoch 15 - VAL
# ============================================================
# Accuracy:  0.9250
# Precision: 0.9259
# Recall:    0.9233
# F1 Score:  0.9243
#
# Confusion Matrix:
# [[624  36]
#  [ 56 510]]
#
# Per-Class Metrics:
#   cherry_clean:
#     Precision: 0.9176
#     Recall:    0.9455
#     F1:        0.9313
#   cherry_pit:
#     Precision: 0.9341
#     Recall:    0.9011
#     F1:        0.9173
# ============================================================
#
# Checkpoint saved: /content/drive/MyDrive/cherry_experiments/efficientnet_b2_label_smooth_seed42/checkpoint_epoch_15.pt
#
# Epoch completed in 8.3 seconds
#
# ============================================================
# EPOCH 16/30
# ============================================================
# Epoch [16] Batch [10/114] Loss: 0.3750
# Epoch [16] Batch [20/114] Loss: 0.3046
# Epoch [16] Batch [30/114] Loss: 0.2997
# Epoch [16] Batch [40/114] Loss: 0.2554
# Epoch [16] Batch [50/114] Loss: 0.4633
# Epoch [16] Batch [60/114] Loss: 0.2832
# Epoch [16] Batch [70/114] Loss: 0.2572
# Epoch [16] Batch [80/114] Loss: 0.3808
# Epoch [16] Batch [90/114] Loss: 0.2848
# Epoch [16] Batch [100/114] Loss: 0.3117
# Epoch [16] Batch [110/114] Loss: 0.3752
#
# Training Loss: 0.3402
# Validation Loss: 0.3285
#
# ============================================================
# Epoch 16 - VAL
# ============================================================
# Accuracy:  0.9241
# Precision: 0.9251
# Recall:    0.9224
# F1 Score:  0.9235
#
# Confusion Matrix:
# [[624  36]
#  [ 57 509]]
#
# Per-Class Metrics:
#   cherry_clean:
#     Precision: 0.9163
#     Recall:    0.9455
#     F1:        0.9306
#   cherry_pit:
#     Precision: 0.9339
#     Recall:    0.8993
#     F1:        0.9163
# ============================================================
#
#
# Epoch completed in 8.0 seconds
#
# ============================================================
# EPOCH 17/30
# ============================================================
# Epoch [17] Batch [10/114] Loss: 0.2749
# Epoch [17] Batch [20/114] Loss: 0.3019
# Epoch [17] Batch [30/114] Loss: 0.3899
# Epoch [17] Batch [40/114] Loss: 0.3823
# Epoch [17] Batch [50/114] Loss: 0.3769
# Epoch [17] Batch [60/114] Loss: 0.3242
# Epoch [17] Batch [70/114] Loss: 0.2729
# Epoch [17] Batch [80/114] Loss: 0.4273
# Epoch [17] Batch [90/114] Loss: 0.2551
# Epoch [17] Batch [100/114] Loss: 0.3623
# Epoch [17] Batch [110/114] Loss: 0.3013
#
# Training Loss: 0.3387
# Validation Loss: 0.3293
#
# ============================================================
# Epoch 17 - VAL
# ============================================================
# Accuracy:  0.9266
# Precision: 0.9293
# Recall:    0.9239
# F1 Score:  0.9258
#
# Confusion Matrix:
# [[633  27]
#  [ 63 503]]
#
# Per-Class Metrics:
#   cherry_clean:
#     Precision: 0.9095
#     Recall:    0.9591
#     F1:        0.9336
#   cherry_pit:
#     Precision: 0.9491
#     Recall:    0.8887
#     F1:        0.9179
# ============================================================
#
#
# Epoch completed in 8.2 seconds
#
# ============================================================
# EPOCH 18/30
# ============================================================
# Epoch [18] Batch [10/114] Loss: 0.3047
# Epoch [18] Batch [20/114] Loss: 0.3849
# Epoch [18] Batch [30/114] Loss: 0.2806
# Epoch [18] Batch [40/114] Loss: 0.3026
# Epoch [18] Batch [50/114] Loss: 0.3946
# Epoch [18] Batch [60/114] Loss: 0.3753
# Epoch [18] Batch [70/114] Loss: 0.3291
# Epoch [18] Batch [80/114] Loss: 0.4033
# Epoch [18] Batch [90/114] Loss: 0.3821
# Epoch [18] Batch [100/114] Loss: 0.3113
# Epoch [18] Batch [110/114] Loss: 0.3877
#
# Training Loss: 0.3417
# Validation Loss: 0.3329
#
# ============================================================
# Epoch 18 - VAL
# ============================================================
# Accuracy:  0.9103
# Precision: 0.9096
# Recall:    0.9119
# F1 Score:  0.9101
#
# Confusion Matrix:
# [[588  72]
#  [ 38 528]]
#
# Per-Class Metrics:
#   cherry_clean:
#     Precision: 0.9393
#     Recall:    0.8909
#     F1:        0.9145
#   cherry_pit:
#     Precision: 0.8800
#     Recall:    0.9329
#     F1:        0.9057
# ============================================================
#
#
# Epoch completed in 8.0 seconds
#
# ============================================================
# EPOCH 19/30
# ============================================================
# Epoch [19] Batch [10/114] Loss: 0.3723
# Epoch [19] Batch [20/114] Loss: 0.3580
# Epoch [19] Batch [30/114] Loss: 0.2714
# Epoch [19] Batch [40/114] Loss: 0.3305
# Epoch [19] Batch [50/114] Loss: 0.4439
# Epoch [19] Batch [60/114] Loss: 0.4385
# Epoch [19] Batch [70/114] Loss: 0.2571
# Epoch [19] Batch [80/114] Loss: 0.4164
# Epoch [19] Batch [90/114] Loss: 0.2353
# Epoch [19] Batch [100/114] Loss: 0.4075
# Epoch [19] Batch [110/114] Loss: 0.3846
#
# Training Loss: 0.3443
# Validation Loss: 0.3242
#
# ============================================================
# Epoch 19 - VAL
# ============================================================
# Accuracy:  0.9250
# Precision: 0.9257
# Recall:    0.9234
# F1 Score:  0.9243
#
# Confusion Matrix:
# [[623  37]
#  [ 55 511]]
#
# Per-Class Metrics:
#   cherry_clean:
#     Precision: 0.9189
#     Recall:    0.9439
#     F1:        0.9312
#   cherry_pit:
#     Precision: 0.9325
#     Recall:    0.9028
#     F1:        0.9174
# ============================================================
#
#
# Epoch completed in 8.0 seconds
#
# ============================================================
# EPOCH 20/30
# ============================================================
# Epoch [20] Batch [10/114] Loss: 0.2713
# Epoch [20] Batch [20/114] Loss: 0.4007
# Epoch [20] Batch [30/114] Loss: 0.3437
# Epoch [20] Batch [40/114] Loss: 0.2563
# Epoch [20] Batch [50/114] Loss: 0.3998
# Epoch [20] Batch [60/114] Loss: 0.2537
# Epoch [20] Batch [70/114] Loss: 0.4013
# Epoch [20] Batch [80/114] Loss: 0.2548
# Epoch [20] Batch [90/114] Loss: 0.2919
# Epoch [20] Batch [100/114] Loss: 0.3575
# Epoch [20] Batch [110/114] Loss: 0.3493
#
# Training Loss: 0.3286
# Validation Loss: 0.3221
#
# ============================================================
# Epoch 20 - VAL
# ============================================================
# Accuracy:  0.9266
# Precision: 0.9273
# Recall:    0.9250
# F1 Score:  0.9260
#
# Confusion Matrix:
# [[624  36]
#  [ 54 512]]
#
# Per-Class Metrics:
#   cherry_clean:
#     Precision: 0.9204
#     Recall:    0.9455
#     F1:        0.9327
#   cherry_pit:
#     Precision: 0.9343
#     Recall:    0.9046
#     F1:        0.9192
# ============================================================
#
# Checkpoint saved: /content/drive/MyDrive/cherry_experiments/efficientnet_b2_label_smooth_seed42/checkpoint_epoch_20.pt
#
# Epoch completed in 8.4 seconds
#
# ============================================================
# EPOCH 21/30
# ============================================================
# Epoch [21] Batch [10/114] Loss: 0.3283
# Epoch [21] Batch [20/114] Loss: 0.2791
# Epoch [21] Batch [30/114] Loss: 0.2563
# Epoch [21] Batch [40/114] Loss: 0.2558
# Epoch [21] Batch [50/114] Loss: 0.3046
# Epoch [21] Batch [60/114] Loss: 0.3314
# Epoch [21] Batch [70/114] Loss: 0.2759
# Epoch [21] Batch [80/114] Loss: 0.4242
# Epoch [21] Batch [90/114] Loss: 0.2553
# Epoch [21] Batch [100/114] Loss: 0.4826
# Epoch [21] Batch [110/114] Loss: 0.3047
#
# Training Loss: 0.3316
# Validation Loss: 0.3210
#
# ============================================================
# Epoch 21 - VAL
# ============================================================
# Accuracy:  0.9258
# Precision: 0.9276
# Recall:    0.9235
# F1 Score:  0.9250
#
# Confusion Matrix:
# [[629  31]
#  [ 60 506]]
#
# Per-Class Metrics:
#   cherry_clean:
#     Precision: 0.9129
#     Recall:    0.9530
#     F1:        0.9325
#   cherry_pit:
#     Precision: 0.9423
#     Recall:    0.8940
#     F1:        0.9175
# ============================================================
#
#
# Epoch completed in 7.9 seconds
#
# ============================================================
# EPOCH 22/30
# ============================================================
# Epoch [22] Batch [10/114] Loss: 0.4400
# Epoch [22] Batch [20/114] Loss: 0.4179
# Epoch [22] Batch [30/114] Loss: 0.2874
# Epoch [22] Batch [40/114] Loss: 0.2679
# Epoch [22] Batch [50/114] Loss: 0.3762
# Epoch [22] Batch [60/114] Loss: 0.2974
# Epoch [22] Batch [70/114] Loss: 0.2810
# Epoch [22] Batch [80/114] Loss: 0.2152
# Epoch [22] Batch [90/114] Loss: 0.3626
# Epoch [22] Batch [100/114] Loss: 0.3632
# Epoch [22] Batch [110/114] Loss: 0.2404
#
# Training Loss: 0.3331
# Validation Loss: 0.3223
#
# ============================================================
# Epoch 22 - VAL
# ============================================================
# Accuracy:  0.9241
# Precision: 0.9241
# Recall:    0.9233
# F1 Score:  0.9236
#
# Confusion Matrix:
# [[617  43]
#  [ 50 516]]
#
# Per-Class Metrics:
#   cherry_clean:
#     Precision: 0.9250
#     Recall:    0.9348
#     F1:        0.9299
#   cherry_pit:
#     Precision: 0.9231
#     Recall:    0.9117
#     F1:        0.9173
# ============================================================
#
#
# Epoch completed in 8.2 seconds
#
# ============================================================
# EPOCH 23/30
# ============================================================
# Epoch [23] Batch [10/114] Loss: 0.3516
# Epoch [23] Batch [20/114] Loss: 0.3291
# Epoch [23] Batch [30/114] Loss: 0.3437
# Epoch [23] Batch [40/114] Loss: 0.3543
# Epoch [23] Batch [50/114] Loss: 0.2376
# Epoch [23] Batch [60/114] Loss: 0.3123
# Epoch [23] Batch [70/114] Loss: 0.2296
# Epoch [23] Batch [80/114] Loss: 0.3604
# Epoch [23] Batch [90/114] Loss: 0.3203
# Epoch [23] Batch [100/114] Loss: 0.3432
# Epoch [23] Batch [110/114] Loss: 0.2369
#
# Training Loss: 0.3323
# Validation Loss: 0.3307
#
# ============================================================
# Epoch 23 - VAL
# ============================================================
# Accuracy:  0.9299
# Precision: 0.9350
# Recall:    0.9262
# F1 Score:  0.9288
#
# Confusion Matrix:
# [[643  17]
#  [ 69 497]]
#
# Per-Class Metrics:
#   cherry_clean:
#     Precision: 0.9031
#     Recall:    0.9742
#     F1:        0.9373
#   cherry_pit:
#     Precision: 0.9669
#     Recall:    0.8781
#     F1:        0.9204
# ============================================================
#
# Model weights saved: /content/drive/MyDrive/cherry_experiments/efficientnet_b2_label_smooth_seed42/model_best.pt
#
# New best model saved! Validation accuracy: 0.9299
#
# Epoch completed in 8.2 seconds
#
# ============================================================
# EPOCH 24/30
# ============================================================
# Epoch [24] Batch [10/114] Loss: 0.3039
# Epoch [24] Batch [20/114] Loss: 0.3210
# Epoch [24] Batch [30/114] Loss: 0.3964
# Epoch [24] Batch [40/114] Loss: 0.2373
# Epoch [24] Batch [50/114] Loss: 0.2668
# Epoch [24] Batch [60/114] Loss: 0.3745
# Epoch [24] Batch [70/114] Loss: 0.3633
# Epoch [24] Batch [80/114] Loss: 0.3149
# Epoch [24] Batch [90/114] Loss: 0.2232
# Epoch [24] Batch [100/114] Loss: 0.2816
# Epoch [24] Batch [110/114] Loss: 0.4639
#
# Training Loss: 0.3274
# Validation Loss: 0.3312
#
# ============================================================
# Epoch 24 - VAL
# ============================================================
# Accuracy:  0.9192
# Precision: 0.9184
# Recall:    0.9197
# F1 Score:  0.9189
#
# Confusion Matrix:
# [[603  57]
#  [ 42 524]]
#
# Per-Class Metrics:
#   cherry_clean:
#     Precision: 0.9349
#     Recall:    0.9136
#     F1:        0.9241
#   cherry_pit:
#     Precision: 0.9019
#     Recall:    0.9258
#     F1:        0.9137
# ============================================================
#
#
# Epoch completed in 7.9 seconds
#
# ============================================================
# EPOCH 25/30
# ============================================================
# Epoch [25] Batch [10/114] Loss: 0.3213
# Epoch [25] Batch [20/114] Loss: 0.3639
# Epoch [25] Batch [30/114] Loss: 0.2380
# Epoch [25] Batch [40/114] Loss: 0.5550
# Epoch [25] Batch [50/114] Loss: 0.3337
# Epoch [25] Batch [60/114] Loss: 0.2268
# Epoch [25] Batch [70/114] Loss: 0.3651
# Epoch [25] Batch [80/114] Loss: 0.3322
# Epoch [25] Batch [90/114] Loss: 0.2945
# Epoch [25] Batch [100/114] Loss: 0.3549
# Epoch [25] Batch [110/114] Loss: 0.3179
#
# Training Loss: 0.3274
# Validation Loss: 0.3351
#
# ============================================================
# Epoch 25 - VAL
# ============================================================
# Accuracy:  0.9250
# Precision: 0.9297
# Recall:    0.9214
# F1 Score:  0.9239
#
# Confusion Matrix:
# [[639  21]
#  [ 71 495]]
#
# Per-Class Metrics:
#   cherry_clean:
#     Precision: 0.9000
#     Recall:    0.9682
#     F1:        0.9328
#   cherry_pit:
#     Precision: 0.9593
#     Recall:    0.8746
#     F1:        0.9150
# ============================================================
#
# Checkpoint saved: /content/drive/MyDrive/cherry_experiments/efficientnet_b2_label_smooth_seed42/checkpoint_epoch_25.pt
#
# Epoch completed in 8.5 seconds
#
# ============================================================
# EPOCH 26/30
# ============================================================
# Epoch [26] Batch [10/114] Loss: 0.2658
# Epoch [26] Batch [20/114] Loss: 0.5167
# Epoch [26] Batch [30/114] Loss: 0.2601
# Epoch [26] Batch [40/114] Loss: 0.2602
# Epoch [26] Batch [50/114] Loss: 0.2424
# Epoch [26] Batch [60/114] Loss: 0.4411
# Epoch [26] Batch [70/114] Loss: 0.2801
# Epoch [26] Batch [80/114] Loss: 0.2748
# Epoch [26] Batch [90/114] Loss: 0.3516
# Epoch [26] Batch [100/114] Loss: 0.3002
# Epoch [26] Batch [110/114] Loss: 0.3228
#
# Training Loss: 0.3282
# Validation Loss: 0.3212
#
# ============================================================
# Epoch 26 - VAL
# ============================================================
# Accuracy:  0.9315
# Precision: 0.9348
# Recall:    0.9286
# F1 Score:  0.9307
#
# Confusion Matrix:
# [[638  22]
#  [ 62 504]]
#
# Per-Class Metrics:
#   cherry_clean:
#     Precision: 0.9114
#     Recall:    0.9667
#     F1:        0.9382
#   cherry_pit:
#     Precision: 0.9582
#     Recall:    0.8905
#     F1:        0.9231
# ============================================================
#
# Model weights saved: /content/drive/MyDrive/cherry_experiments/efficientnet_b2_label_smooth_seed42/model_best.pt
#
# New best model saved! Validation accuracy: 0.9315
#
# Epoch completed in 8.2 seconds
#
# ============================================================
# EPOCH 27/30
# ============================================================
# Epoch [27] Batch [10/114] Loss: 0.3500
# Epoch [27] Batch [20/114] Loss: 0.2743
# Epoch [27] Batch [30/114] Loss: 0.3311
# Epoch [27] Batch [40/114] Loss: 0.3109
# Epoch [27] Batch [50/114] Loss: 0.3482
# Epoch [27] Batch [60/114] Loss: 0.2267
# Epoch [27] Batch [70/114] Loss: 0.4014
# Epoch [27] Batch [80/114] Loss: 0.3353
# Epoch [27] Batch [90/114] Loss: 0.3701
# Epoch [27] Batch [100/114] Loss: 0.3707
# Epoch [27] Batch [110/114] Loss: 0.3912
#
# Training Loss: 0.3202
# Validation Loss: 0.3210
#
# ============================================================
# Epoch 27 - VAL
# ============================================================
# Accuracy:  0.9241
# Precision: 0.9245
# Recall:    0.9229
# F1 Score:  0.9236
#
# Confusion Matrix:
# [[620  40]
#  [ 53 513]]
#
# Per-Class Metrics:
#   cherry_clean:
#     Precision: 0.9212
#     Recall:    0.9394
#     F1:        0.9302
#   cherry_pit:
#     Precision: 0.9277
#     Recall:    0.9064
#     F1:        0.9169
# ============================================================
#
#
# Epoch completed in 8.0 seconds
#
# ============================================================
# EPOCH 28/30
# ============================================================
# Epoch [28] Batch [10/114] Loss: 0.3611
# Epoch [28] Batch [20/114] Loss: 0.2763
# Epoch [28] Batch [30/114] Loss: 0.3832
# Epoch [28] Batch [40/114] Loss: 0.3626
# Epoch [28] Batch [50/114] Loss: 0.2743
# Epoch [28] Batch [60/114] Loss: 0.2974
# Epoch [28] Batch [70/114] Loss: 0.3523
# Epoch [28] Batch [80/114] Loss: 0.3468
# Epoch [28] Batch [90/114] Loss: 0.2511
# Epoch [28] Batch [100/114] Loss: 0.2890
# Epoch [28] Batch [110/114] Loss: 0.2977
#
# Training Loss: 0.3166
# Validation Loss: 0.3242
#
# ============================================================
# Epoch 28 - VAL
# ============================================================
# Accuracy:  0.9184
# Precision: 0.9189
# Recall:    0.9169
# F1 Score:  0.9178
#
# Confusion Matrix:
# [[618  42]
#  [ 58 508]]
#
# Per-Class Metrics:
#   cherry_clean:
#     Precision: 0.9142
#     Recall:    0.9364
#     F1:        0.9251
#   cherry_pit:
#     Precision: 0.9236
#     Recall:    0.8975
#     F1:        0.9104
# ============================================================
#
#
# Epoch completed in 7.9 seconds
#
# ============================================================
# EPOCH 29/30
# ============================================================
# Epoch [29] Batch [10/114] Loss: 0.2842
# Epoch [29] Batch [20/114] Loss: 0.2848
# Epoch [29] Batch [30/114] Loss: 0.3953
# Epoch [29] Batch [40/114] Loss: 0.2679
# Epoch [29] Batch [50/114] Loss: 0.2726
# Epoch [29] Batch [60/114] Loss: 0.3624
# Epoch [29] Batch [70/114] Loss: 0.2511
# Epoch [29] Batch [80/114] Loss: 0.2661
# Epoch [29] Batch [90/114] Loss: 0.2672
# Epoch [29] Batch [100/114] Loss: 0.3266
# Epoch [29] Batch [110/114] Loss: 0.3039
#
# Training Loss: 0.3237
# Validation Loss: 0.3194
#
# ============================================================
# Epoch 29 - VAL
# ============================================================
# Accuracy:  0.9209
# Precision: 0.9208
# Recall:    0.9200
# F1 Score:  0.9203
#
# Confusion Matrix:
# [[615  45]
#  [ 52 514]]
#
# Per-Class Metrics:
#   cherry_clean:
#     Precision: 0.9220
#     Recall:    0.9318
#     F1:        0.9269
#   cherry_pit:
#     Precision: 0.9195
#     Recall:    0.9081
#     F1:        0.9138
# ============================================================
#
#
# Epoch completed in 8.3 seconds
#
# ============================================================
# EPOCH 30/30
# ============================================================
# Epoch [30] Batch [10/114] Loss: 0.2210
# Epoch [30] Batch [20/114] Loss: 0.3439
# Epoch [30] Batch [30/114] Loss: 0.3833
# Epoch [30] Batch [40/114] Loss: 0.3182
# Epoch [30] Batch [50/114] Loss: 0.3600
# Epoch [30] Batch [60/114] Loss: 0.3028
# Epoch [30] Batch [70/114] Loss: 0.3771
# Epoch [30] Batch [80/114] Loss: 0.3314
# Epoch [30] Batch [90/114] Loss: 0.3640
# Epoch [30] Batch [100/114] Loss: 0.3834
# Epoch [30] Batch [110/114] Loss: 0.3434
#
# Training Loss: 0.3229
# Validation Loss: 0.3201
#
# ============================================================
# Epoch 30 - VAL
# ============================================================
# Accuracy:  0.9258
# Precision: 0.9283
# Recall:    0.9231
# F1 Score:  0.9249
#
# Confusion Matrix:
# [[632  28]
#  [ 63 503]]
#
# Per-Class Metrics:
#   cherry_clean:
#     Precision: 0.9094
#     Recall:    0.9576
#     F1:        0.9328
#   cherry_pit:
#     Precision: 0.9473
#     Recall:    0.8887
#     F1:        0.9170
# ============================================================
#
# Checkpoint saved: /content/drive/MyDrive/cherry_experiments/efficientnet_b2_label_smooth_seed42/checkpoint_epoch_30.pt
#
# Epoch completed in 8.3 seconds
# Model weights saved: /content/drive/MyDrive/cherry_experiments/efficientnet_b2_label_smooth_seed42/model_final.pt
#
# ============================================================
# TRAINING COMPLETE
# ============================================================
# Final model saved to: /content/drive/MyDrive/cherry_experiments/efficientnet_b2_label_smooth_seed42/model_final.pt
# Best validation accuracy: 0.9315
# Logs saved to: /content/drive/MyDrive/cherry_experiments/efficientnet_b2_label_smooth_seed42/metrics.json
#
# ============================================================
# Training complete! Results: /content/drive/MyDrive/cherry_experiments/efficientnet_b2_label_smooth_seed42
# ============================================================

# %% [markdown]
# ## Cell 10: EXP-006A - DINOv2 ViT-S/14 Linear Probe (NEW - Phase 2)
#
# **Type:** Training (frozen backbone)
# **Duration:** ~4-6 hours (fast training - only linear head optimized)
# **Architecture:** DINOv2 ViT-S/14 foundation model
# **Key Feature:** Self-supervised features, frozen backbone + trainable head
# **Hypothesis:** Foundation model features will achieve ≥94.5% with minimal training

# %%
if SKIP_EXP_006A:
    print("EXP-006A: SKIPPED (set SKIP_EXP_006A=False to run)")
else:
    print("\n" + "=" * 60)
    print("RUNNING EXP-006A: DINOv2 ViT-S/14 Linear Probe (Phase 2)")
    print("Features: Frozen foundation backbone, fast training, normalized input")
    print("=" * 60)

    # Set random seed
    random.seed(RANDOM_SEED)
    np.random.seed(RANDOM_SEED)
    torch.manual_seed(RANDOM_SEED)
    if torch.cuda.is_available():
        torch.cuda.manual_seed_all(RANDOM_SEED)

    print(f"Random seed set: {RANDOM_SEED}")

    # Load config
    config_path = "/content/cherries/training/configs/experiments/dinov2_vits14_linear_probe_seed42.yaml"

    with open(config_path, 'r') as f:
        config = yaml.safe_load(f)

    # Override paths
    config['checkpointing']['output_dir'] = f"{DRIVE_BASE_PATH}/dinov2_vits14_linear_probe_seed42"
    config['data']['root'] = DATA_PATH

    # Apply smoke test settings
    if SMOKE_TEST:
        print("\nSMOKE TEST MODE: 1 epoch, 3 batches")
        config['training']['epochs'] = 1
        config['checkpointing']['save_every'] = 1

    # Save temp config
    temp_config = "/tmp/dinov2_vits14_linear_probe_seed42.yaml"
    with open(temp_config, 'w') as f:
        yaml.dump(config, f)

    # Run training
    # !python /content/cherries/training/scripts/train.py \
        --config {temp_config} \
        --data-root {DATA_PATH}

    print("\n" + "=" * 60)
    print(f"Training complete! Results: {config['checkpointing']['output_dir']}")
    print("\nNOTE: DINOv2 inference may be slower than CNNs. If accurate but slow,")
    print("      consider using it as a teacher for distillation.")
    print("=" * 60)
# Out:
# ============================================================
# RUNNING EXP-006A: DINOv2 ViT-S/14 Linear Probe (Phase 2)
# Features: Frozen foundation backbone, fast training, normalized input
# ============================================================
# Random seed set: 42
# Using cache found in /root/.cache/torch/hub/facebookresearch_dinov2_main
# /root/.cache/torch/hub/facebookresearch_dinov2_main/dinov2/layers/swiglu_ffn.py:51: UserWarning: xFormers is not available (SwiGLU)
#   warnings.warn("xFormers is not available (SwiGLU)")
# /root/.cache/torch/hub/facebookresearch_dinov2_main/dinov2/layers/attention.py:33: UserWarning: xFormers is not available (Attention)
#   warnings.warn("xFormers is not available (Attention)")
# /root/.cache/torch/hub/facebookresearch_dinov2_main/dinov2/layers/block.py:40: UserWarning: xFormers is not available (Block)
#   warnings.warn("xFormers is not available (Block)")
#
# Loading config from: /tmp/dinov2_vits14_linear_probe_seed42.yaml
# Output directory: /content/drive/MyDrive/cherry_experiments/dinov2_vits14_linear_probe_seed42
# Config saved to: /content/drive/MyDrive/cherry_experiments/dinov2_vits14_linear_probe_seed42/config.yaml
# Using device: cuda
#
# ============================================================
# LOADING DATA
# ============================================================
#
# Dataset loaded from: /content/cherry_classification/data
# Training samples: 3676
# Validation samples: 1226
# Classes: ['cherry_clean', 'cherry_pit']
# Class distribution (train): {'cherry_clean': 1978, 'cherry_pit': 1698}
# Class distribution (val): {'cherry_clean': 660, 'cherry_pit': 566}
#
# Class names: ['cherry_clean', 'cherry_pit']
#
# ============================================================
# CREATING MODEL
# ============================================================
# Architecture: dinov2_vits14
# Using cache found in /root/.cache/torch/hub/facebookresearch_dinov2_main
# Loaded DINOv2 ViT-S/14 backbone from torch hub
# Freezing DINOv2 backbone (linear probe mode)
# Created linear classifier head: Linear(384, 2)
# Model moved to device: cuda
# Optimizer: adam
# Learning rate: 0.001
# Weight decay: 0.0001
# Using scheduler: cosine
# Using standard CrossEntropyLoss (no label smoothing)
#
# ============================================================
# STARTING TRAINING
# ============================================================
# Training for 30 epochs
# Starting from epoch 0
#
# ============================================================
# EPOCH 1/30
# ============================================================
# Epoch [1] Batch [10/114] Loss: 0.6637
# Epoch [1] Batch [20/114] Loss: 0.5897
# Epoch [1] Batch [30/114] Loss: 0.6285
# Epoch [1] Batch [40/114] Loss: 0.6296
# Epoch [1] Batch [50/114] Loss: 0.5034
# Epoch [1] Batch [60/114] Loss: 0.5264
# Epoch [1] Batch [70/114] Loss: 0.5209
# Epoch [1] Batch [80/114] Loss: 0.5010
# Epoch [1] Batch [90/114] Loss: 0.4328
# Epoch [1] Batch [100/114] Loss: 0.4788
# Epoch [1] Batch [110/114] Loss: 0.4240
#
# Training Loss: 0.6091
# Validation Loss: 0.4930
# Stepped scheduler. New LR: 0.000997
#
# ============================================================
# Epoch 1 - VAL
# ============================================================
# Accuracy:  0.7594
# Precision: 0.7669
# Recall:    0.7511
# F1 Score:  0.7526
#
# Confusion Matrix:
# [[567  93]
#  [202 364]]
#
# Per-Class Metrics:
#   cherry_clean:
#     Precision: 0.7373
#     Recall:    0.8591
#     F1:        0.7936
#   cherry_pit:
#     Precision: 0.7965
#     Recall:    0.6431
#     F1:        0.7116
# ============================================================
#
# Model weights saved: /content/drive/MyDrive/cherry_experiments/dinov2_vits14_linear_probe_seed42/model_best.pt
#
# New best model saved! Validation accuracy: 0.7594
#
# Epoch completed in 5.3 seconds
#
# ============================================================
# EPOCH 2/30
# ============================================================
# Epoch [2] Batch [10/114] Loss: 0.4139
# Epoch [2] Batch [20/114] Loss: 0.5258
# Epoch [2] Batch [30/114] Loss: 0.3671
# Epoch [2] Batch [40/114] Loss: 0.6265
# Epoch [2] Batch [50/114] Loss: 0.3782
# Epoch [2] Batch [60/114] Loss: 0.4161
# Epoch [2] Batch [70/114] Loss: 0.3801
# Epoch [2] Batch [80/114] Loss: 0.4013
# Epoch [2] Batch [90/114] Loss: 0.4525
# Epoch [2] Batch [100/114] Loss: 0.4351
# Epoch [2] Batch [110/114] Loss: 0.2711
#
# Training Loss: 0.4573
# Validation Loss: 0.4483
# Stepped scheduler. New LR: 0.000989
#
# ============================================================
# Epoch 2 - VAL
# ============================================================
# Accuracy:  0.8002
# Precision: 0.7993
# Recall:    0.8008
# F1 Score:  0.7996
#
# Confusion Matrix:
# [[523 137]
#  [108 458]]
#
# Per-Class Metrics:
#   cherry_clean:
#     Precision: 0.8288
#     Recall:    0.7924
#     F1:        0.8102
#   cherry_pit:
#     Precision: 0.7697
#     Recall:    0.8092
#     F1:        0.7890
# ============================================================
#
# Model weights saved: /content/drive/MyDrive/cherry_experiments/dinov2_vits14_linear_probe_seed42/model_best.pt
#
# New best model saved! Validation accuracy: 0.8002
#
# Epoch completed in 4.9 seconds
#
# ============================================================
# EPOCH 3/30
# ============================================================
# Epoch [3] Batch [10/114] Loss: 0.5292
# Epoch [3] Batch [20/114] Loss: 0.4771
# Epoch [3] Batch [30/114] Loss: 0.3266
# Epoch [3] Batch [40/114] Loss: 0.6360
# Epoch [3] Batch [50/114] Loss: 0.3307
# Epoch [3] Batch [60/114] Loss: 0.4812
# Epoch [3] Batch [70/114] Loss: 0.5162
# Epoch [3] Batch [80/114] Loss: 0.7126
# Epoch [3] Batch [90/114] Loss: 0.5928
# Epoch [3] Batch [100/114] Loss: 0.3192
# Epoch [3] Batch [110/114] Loss: 0.3251
#
# Training Loss: 0.4410
# Validation Loss: 0.4352
# Stepped scheduler. New LR: 0.000976
#
# ============================================================
# Epoch 3 - VAL
# ============================================================
# Accuracy:  0.8059
# Precision: 0.8110
# Recall:    0.7998
# F1 Score:  0.8020
#
# Confusion Matrix:
# [[580  80]
#  [158 408]]
#
# Per-Class Metrics:
#   cherry_clean:
#     Precision: 0.7859
#     Recall:    0.8788
#     F1:        0.8298
#   cherry_pit:
#     Precision: 0.8361
#     Recall:    0.7208
#     F1:        0.7742
# ============================================================
#
# Model weights saved: /content/drive/MyDrive/cherry_experiments/dinov2_vits14_linear_probe_seed42/model_best.pt
#
# New best model saved! Validation accuracy: 0.8059
#
# Epoch completed in 4.9 seconds
#
# ============================================================
# EPOCH 4/30
# ============================================================
# Epoch [4] Batch [10/114] Loss: 0.5387
# Epoch [4] Batch [20/114] Loss: 0.3940
# Epoch [4] Batch [30/114] Loss: 0.3123
# Epoch [4] Batch [40/114] Loss: 0.3720
# Epoch [4] Batch [50/114] Loss: 0.4545
# Epoch [4] Batch [60/114] Loss: 0.3761
# Epoch [4] Batch [70/114] Loss: 0.3128
# Epoch [4] Batch [80/114] Loss: 0.4105
# Epoch [4] Batch [90/114] Loss: 0.3840
# Epoch [4] Batch [100/114] Loss: 0.5261
# Epoch [4] Batch [110/114] Loss: 0.4813
#
# Training Loss: 0.4110
# Validation Loss: 0.4221
# Stepped scheduler. New LR: 0.000957
#
# ============================================================
# Epoch 4 - VAL
# ============================================================
# Accuracy:  0.8042
# Precision: 0.8044
# Recall:    0.8011
# F1 Score:  0.8022
#
# Confusion Matrix:
# [[556 104]
#  [136 430]]
#
# Per-Class Metrics:
#   cherry_clean:
#     Precision: 0.8035
#     Recall:    0.8424
#     F1:        0.8225
#   cherry_pit:
#     Precision: 0.8052
#     Recall:    0.7597
#     F1:        0.7818
# ============================================================
#
#
# Epoch completed in 4.8 seconds
#
# ============================================================
# EPOCH 5/30
# ============================================================
# Epoch [5] Batch [10/114] Loss: 0.3965
# Epoch [5] Batch [20/114] Loss: 0.3916
# Epoch [5] Batch [30/114] Loss: 0.3963
# Epoch [5] Batch [40/114] Loss: 0.3342
# Epoch [5] Batch [50/114] Loss: 0.4959
# Epoch [5] Batch [60/114] Loss: 0.4110
# Epoch [5] Batch [70/114] Loss: 0.3664
# Epoch [5] Batch [80/114] Loss: 0.3648
# Epoch [5] Batch [90/114] Loss: 0.3218
# Epoch [5] Batch [100/114] Loss: 0.4547
# Epoch [5] Batch [110/114] Loss: 0.4602
#
# Training Loss: 0.3859
# Validation Loss: 0.4180
# Stepped scheduler. New LR: 0.000933
#
# ============================================================
# Epoch 5 - VAL
# ============================================================
# Accuracy:  0.8100
# Precision: 0.8124
# Recall:    0.8052
# F1 Score:  0.8070
#
# Confusion Matrix:
# [[572  88]
#  [145 421]]
#
# Per-Class Metrics:
#   cherry_clean:
#     Precision: 0.7978
#     Recall:    0.8667
#     F1:        0.8308
#   cherry_pit:
#     Precision: 0.8271
#     Recall:    0.7438
#     F1:        0.7833
# ============================================================
#
# Checkpoint saved: /content/drive/MyDrive/cherry_experiments/dinov2_vits14_linear_probe_seed42/checkpoint_epoch_5.pt
# Model weights saved: /content/drive/MyDrive/cherry_experiments/dinov2_vits14_linear_probe_seed42/model_best.pt
#
# New best model saved! Validation accuracy: 0.8100
#
# Epoch completed in 5.1 seconds
#
# ============================================================
# EPOCH 6/30
# ============================================================
# Epoch [6] Batch [10/114] Loss: 0.3643
# Epoch [6] Batch [20/114] Loss: 0.4227
# Epoch [6] Batch [30/114] Loss: 0.3139
# Epoch [6] Batch [40/114] Loss: 0.4724
# Epoch [6] Batch [50/114] Loss: 0.4756
# Epoch [6] Batch [60/114] Loss: 0.2598
# Epoch [6] Batch [70/114] Loss: 0.2303
# Epoch [6] Batch [80/114] Loss: 0.3709
# Epoch [6] Batch [90/114] Loss: 0.4985
# Epoch [6] Batch [100/114] Loss: 0.4315
# Epoch [6] Batch [110/114] Loss: 0.2042
#
# Training Loss: 0.3809
# Validation Loss: 0.4056
# Stepped scheduler. New LR: 0.000905
#
# ============================================================
# Epoch 6 - VAL
# ============================================================
# Accuracy:  0.8173
# Precision: 0.8205
# Recall:    0.8214
# F1 Score:  0.8173
#
# Confusion Matrix:
# [[507 153]
#  [ 71 495]]
#
# Per-Class Metrics:
#   cherry_clean:
#     Precision: 0.8772
#     Recall:    0.7682
#     F1:        0.8191
#   cherry_pit:
#     Precision: 0.7639
#     Recall:    0.8746
#     F1:        0.8155
# ============================================================
#
# Model weights saved: /content/drive/MyDrive/cherry_experiments/dinov2_vits14_linear_probe_seed42/model_best.pt
#
# New best model saved! Validation accuracy: 0.8173
#
# Epoch completed in 5.0 seconds
#
# ============================================================
# EPOCH 7/30
# ============================================================
# Epoch [7] Batch [10/114] Loss: 0.5113
# Epoch [7] Batch [20/114] Loss: 0.3277
# Epoch [7] Batch [30/114] Loss: 0.3135
# Epoch [7] Batch [40/114] Loss: 0.3949
# Epoch [7] Batch [50/114] Loss: 0.2482
# Epoch [7] Batch [60/114] Loss: 0.4936
# Epoch [7] Batch [70/114] Loss: 0.4632
# Epoch [7] Batch [80/114] Loss: 0.7116
# Epoch [7] Batch [90/114] Loss: 0.3710
# Epoch [7] Batch [100/114] Loss: 0.2614
# Epoch [7] Batch [110/114] Loss: 0.4048
#
# Training Loss: 0.3890
# Validation Loss: 0.3952
# Stepped scheduler. New LR: 0.000872
#
# ============================================================
# Epoch 7 - VAL
# ============================================================
# Accuracy:  0.8214
# Precision: 0.8206
# Recall:    0.8223
# F1 Score:  0.8209
#
# Confusion Matrix:
# [[535 125]
#  [ 94 472]]
#
# Per-Class Metrics:
#   cherry_clean:
#     Precision: 0.8506
#     Recall:    0.8106
#     F1:        0.8301
#   cherry_pit:
#     Precision: 0.7906
#     Recall:    0.8339
#     F1:        0.8117
# ============================================================
#
# Model weights saved: /content/drive/MyDrive/cherry_experiments/dinov2_vits14_linear_probe_seed42/model_best.pt
#
# New best model saved! Validation accuracy: 0.8214
#
# Epoch completed in 5.0 seconds
#
# ============================================================
# EPOCH 8/30
# ============================================================
# Epoch [8] Batch [10/114] Loss: 0.5213
# Epoch [8] Batch [20/114] Loss: 0.2394
# Epoch [8] Batch [30/114] Loss: 0.4339
# Epoch [8] Batch [40/114] Loss: 0.5122
# Epoch [8] Batch [50/114] Loss: 0.4771
# Epoch [8] Batch [60/114] Loss: 0.3219
# Epoch [8] Batch [70/114] Loss: 0.4087
# Epoch [8] Batch [80/114] Loss: 0.3366
# Epoch [8] Batch [90/114] Loss: 0.3594
# Epoch [8] Batch [100/114] Loss: 0.4514
# Epoch [8] Batch [110/114] Loss: 0.5725
#
# Training Loss: 0.3725
# Validation Loss: 0.3940
# Stepped scheduler. New LR: 0.000835
#
# ============================================================
# Epoch 8 - VAL
# ============================================================
# Accuracy:  0.8279
# Precision: 0.8271
# Recall:    0.8288
# F1 Score:  0.8274
#
# Confusion Matrix:
# [[539 121]
#  [ 90 476]]
#
# Per-Class Metrics:
#   cherry_clean:
#     Precision: 0.8569
#     Recall:    0.8167
#     F1:        0.8363
#   cherry_pit:
#     Precision: 0.7973
#     Recall:    0.8410
#     F1:        0.8186
# ============================================================
#
# Model weights saved: /content/drive/MyDrive/cherry_experiments/dinov2_vits14_linear_probe_seed42/model_best.pt
#
# New best model saved! Validation accuracy: 0.8279
#
# Epoch completed in 4.9 seconds
#
# ============================================================
# EPOCH 9/30
# ============================================================
# Epoch [9] Batch [10/114] Loss: 0.3030
# Epoch [9] Batch [20/114] Loss: 0.4005
# Epoch [9] Batch [30/114] Loss: 0.5486
# Epoch [9] Batch [40/114] Loss: 0.3733
# Epoch [9] Batch [50/114] Loss: 0.4766
# Epoch [9] Batch [60/114] Loss: 0.4469
# Epoch [9] Batch [70/114] Loss: 0.3465
# Epoch [9] Batch [80/114] Loss: 0.2947
# Epoch [9] Batch [90/114] Loss: 0.3326
# Epoch [9] Batch [100/114] Loss: 0.3281
# Epoch [9] Batch [110/114] Loss: 0.3694
#
# Training Loss: 0.3726
# Validation Loss: 0.3977
# Stepped scheduler. New LR: 0.000794
#
# ============================================================
# Epoch 9 - VAL
# ============================================================
# Accuracy:  0.8263
# Precision: 0.8297
# Recall:    0.8214
# F1 Score:  0.8234
#
# Confusion Matrix:
# [[584  76]
#  [137 429]]
#
# Per-Class Metrics:
#   cherry_clean:
#     Precision: 0.8100
#     Recall:    0.8848
#     F1:        0.8458
#   cherry_pit:
#     Precision: 0.8495
#     Recall:    0.7580
#     F1:        0.8011
# ============================================================
#
#
# Epoch completed in 4.7 seconds
#
# ============================================================
# EPOCH 10/30
# ============================================================
# Epoch [10] Batch [10/114] Loss: 0.2410
# Epoch [10] Batch [20/114] Loss: 0.2829
# Epoch [10] Batch [30/114] Loss: 0.3695
# Epoch [10] Batch [40/114] Loss: 0.6033
# Epoch [10] Batch [50/114] Loss: 0.4212
# Epoch [10] Batch [60/114] Loss: 0.3021
# Epoch [10] Batch [70/114] Loss: 0.3532
# Epoch [10] Batch [80/114] Loss: 0.4408
# Epoch [10] Batch [90/114] Loss: 0.3466
# Epoch [10] Batch [100/114] Loss: 0.3467
# Epoch [10] Batch [110/114] Loss: 0.4355
#
# Training Loss: 0.3725
# Validation Loss: 0.3936
# Stepped scheduler. New LR: 0.000750
#
# ============================================================
# Epoch 10 - VAL
# ============================================================
# Accuracy:  0.8279
# Precision: 0.8299
# Recall:    0.8313
# F1 Score:  0.8278
#
# Confusion Matrix:
# [[519 141]
#  [ 70 496]]
#
# Per-Class Metrics:
#   cherry_clean:
#     Precision: 0.8812
#     Recall:    0.7864
#     F1:        0.8311
#   cherry_pit:
#     Precision: 0.7786
#     Recall:    0.8763
#     F1:        0.8246
# ============================================================
#
# Checkpoint saved: /content/drive/MyDrive/cherry_experiments/dinov2_vits14_linear_probe_seed42/checkpoint_epoch_10.pt
#
# Epoch completed in 4.9 seconds
#
# ============================================================
# EPOCH 11/30
# ============================================================
# Epoch [11] Batch [10/114] Loss: 0.3348
# Epoch [11] Batch [20/114] Loss: 0.3366
# Epoch [11] Batch [30/114] Loss: 0.3041
# Epoch [11] Batch [40/114] Loss: 0.5522
# Epoch [11] Batch [50/114] Loss: 0.3654
# Epoch [11] Batch [60/114] Loss: 0.4349
# Epoch [11] Batch [70/114] Loss: 0.3579
# Epoch [11] Batch [80/114] Loss: 0.3785
# Epoch [11] Batch [90/114] Loss: 0.3994
# Epoch [11] Batch [100/114] Loss: 0.4235
# Epoch [11] Batch [110/114] Loss: 0.2374
#
# Training Loss: 0.3690
# Validation Loss: 0.3993
# Stepped scheduler. New LR: 0.000703
#
# ============================================================
# Epoch 11 - VAL
# ============================================================
# Accuracy:  0.8222
# Precision: 0.8265
# Recall:    0.8268
# F1 Score:  0.8222
#
# Confusion Matrix:
# [[506 154]
#  [ 64 502]]
#
# Per-Class Metrics:
#   cherry_clean:
#     Precision: 0.8877
#     Recall:    0.7667
#     F1:        0.8228
#   cherry_pit:
#     Precision: 0.7652
#     Recall:    0.8869
#     F1:        0.8216
# ============================================================
#
#
# Epoch completed in 4.7 seconds
#
# ============================================================
# EPOCH 12/30
# ============================================================
# Epoch [12] Batch [10/114] Loss: 0.4213
# Epoch [12] Batch [20/114] Loss: 0.2954
# Epoch [12] Batch [30/114] Loss: 0.2846
# Epoch [12] Batch [40/114] Loss: 0.2796
# Epoch [12] Batch [50/114] Loss: 0.6647
# Epoch [12] Batch [60/114] Loss: 0.4111
# Epoch [12] Batch [70/114] Loss: 0.4211
# Epoch [12] Batch [80/114] Loss: 0.4570
# Epoch [12] Batch [90/114] Loss: 0.2917
# Epoch [12] Batch [100/114] Loss: 0.4918
# Epoch [12] Batch [110/114] Loss: 0.3415
#
# Training Loss: 0.3642
# Validation Loss: 0.3946
# Stepped scheduler. New LR: 0.000655
#
# ============================================================
# Epoch 12 - VAL
# ============================================================
# Accuracy:  0.8230
# Precision: 0.8278
# Recall:    0.8175
# F1 Score:  0.8197
#
# Confusion Matrix:
# [[587  73]
#  [144 422]]
#
# Per-Class Metrics:
#   cherry_clean:
#     Precision: 0.8030
#     Recall:    0.8894
#     F1:        0.8440
#   cherry_pit:
#     Precision: 0.8525
#     Recall:    0.7456
#     F1:        0.7955
# ============================================================
#
#
# Epoch completed in 4.8 seconds
#
# ============================================================
# EPOCH 13/30
# ============================================================
# Epoch [13] Batch [10/114] Loss: 0.3562
# Epoch [13] Batch [20/114] Loss: 0.2715
# Epoch [13] Batch [30/114] Loss: 0.2429
# Epoch [13] Batch [40/114] Loss: 0.3292
# Epoch [13] Batch [50/114] Loss: 0.3883
# Epoch [13] Batch [60/114] Loss: 0.3871
# Epoch [13] Batch [70/114] Loss: 0.4612
# Epoch [13] Batch [80/114] Loss: 0.3948
# Epoch [13] Batch [90/114] Loss: 0.2073
# Epoch [13] Batch [100/114] Loss: 0.2578
# Epoch [13] Batch [110/114] Loss: 0.1986
#
# Training Loss: 0.3506
# Validation Loss: 0.3782
# Stepped scheduler. New LR: 0.000604
#
# ============================================================
# Epoch 13 - VAL
# ============================================================
# Accuracy:  0.8328
# Precision: 0.8348
# Recall:    0.8288
# F1 Score:  0.8305
#
# Confusion Matrix:
# [[581  79]
#  [126 440]]
#
# Per-Class Metrics:
#   cherry_clean:
#     Precision: 0.8218
#     Recall:    0.8803
#     F1:        0.8500
#   cherry_pit:
#     Precision: 0.8478
#     Recall:    0.7774
#     F1:        0.8111
# ============================================================
#
# Model weights saved: /content/drive/MyDrive/cherry_experiments/dinov2_vits14_linear_probe_seed42/model_best.pt
#
# New best model saved! Validation accuracy: 0.8328
#
# Epoch completed in 4.8 seconds
#
# ============================================================
# EPOCH 14/30
# ============================================================
# Epoch [14] Batch [10/114] Loss: 0.4766
# Epoch [14] Batch [20/114] Loss: 0.4171
# Epoch [14] Batch [30/114] Loss: 0.4290
# Epoch [14] Batch [40/114] Loss: 0.5141
# Epoch [14] Batch [50/114] Loss: 0.6287
# Epoch [14] Batch [60/114] Loss: 0.2548
# Epoch [14] Batch [70/114] Loss: 0.3997
# Epoch [14] Batch [80/114] Loss: 0.4070
# Epoch [14] Batch [90/114] Loss: 0.3331
# Epoch [14] Batch [100/114] Loss: 0.4322
# Epoch [14] Batch [110/114] Loss: 0.5356
#
# Training Loss: 0.3581
# Validation Loss: 0.3909
# Stepped scheduler. New LR: 0.000552
#
# ============================================================
# Epoch 14 - VAL
# ============================================================
# Accuracy:  0.8336
# Precision: 0.8380
# Recall:    0.8383
# F1 Score:  0.8336
#
# Confusion Matrix:
# [[513 147]
#  [ 57 509]]
#
# Per-Class Metrics:
#   cherry_clean:
#     Precision: 0.9000
#     Recall:    0.7773
#     F1:        0.8341
#   cherry_pit:
#     Precision: 0.7759
#     Recall:    0.8993
#     F1:        0.8331
# ============================================================
#
# Model weights saved: /content/drive/MyDrive/cherry_experiments/dinov2_vits14_linear_probe_seed42/model_best.pt
#
# New best model saved! Validation accuracy: 0.8336
#
# Epoch completed in 5.1 seconds
#
# ============================================================
# EPOCH 15/30
# ============================================================
# Epoch [15] Batch [10/114] Loss: 0.2975
# Epoch [15] Batch [20/114] Loss: 0.2811
# Epoch [15] Batch [30/114] Loss: 0.4048
# Epoch [15] Batch [40/114] Loss: 0.5994
# Epoch [15] Batch [50/114] Loss: 0.4091
# Epoch [15] Batch [60/114] Loss: 0.4041
# Epoch [15] Batch [70/114] Loss: 0.6038
# Epoch [15] Batch [80/114] Loss: 0.1567
# Epoch [15] Batch [90/114] Loss: 0.4746
# Epoch [15] Batch [100/114] Loss: 0.4174
# Epoch [15] Batch [110/114] Loss: 0.2650
#
# Training Loss: 0.3560
# Validation Loss: 0.3746
# Stepped scheduler. New LR: 0.000500
#
# ============================================================
# Epoch 15 - VAL
# ============================================================
# Accuracy:  0.8263
# Precision: 0.8252
# Recall:    0.8256
# F1 Score:  0.8253
#
# Confusion Matrix:
# [[551 109]
#  [104 462]]
#
# Per-Class Metrics:
#   cherry_clean:
#     Precision: 0.8412
#     Recall:    0.8348
#     F1:        0.8380
#   cherry_pit:
#     Precision: 0.8091
#     Recall:    0.8163
#     F1:        0.8127
# ============================================================
#
# Checkpoint saved: /content/drive/MyDrive/cherry_experiments/dinov2_vits14_linear_probe_seed42/checkpoint_epoch_15.pt
#
# Epoch completed in 4.9 seconds
#
# ============================================================
# EPOCH 16/30
# ============================================================
# Epoch [16] Batch [10/114] Loss: 0.3955
# Epoch [16] Batch [20/114] Loss: 0.3331
# Epoch [16] Batch [30/114] Loss: 0.2872
# Epoch [16] Batch [40/114] Loss: 0.3586
# Epoch [16] Batch [50/114] Loss: 0.3289
# Epoch [16] Batch [60/114] Loss: 0.5129
# Epoch [16] Batch [70/114] Loss: 0.2065
# Epoch [16] Batch [80/114] Loss: 0.2306
# Epoch [16] Batch [90/114] Loss: 0.2567
# Epoch [16] Batch [100/114] Loss: 0.4988
# Epoch [16] Batch [110/114] Loss: 0.2446
#
# Training Loss: 0.3524
# Validation Loss: 0.3913
# Stepped scheduler. New LR: 0.000448
#
# ============================================================
# Epoch 16 - VAL
# ============================================================
# Accuracy:  0.8303
# Precision: 0.8350
# Recall:    0.8351
# F1 Score:  0.8303
#
# Confusion Matrix:
# [[510 150]
#  [ 58 508]]
#
# Per-Class Metrics:
#   cherry_clean:
#     Precision: 0.8979
#     Recall:    0.7727
#     F1:        0.8306
#   cherry_pit:
#     Precision: 0.7720
#     Recall:    0.8975
#     F1:        0.8301
# ============================================================
#
#
# Epoch completed in 4.9 seconds
#
# ============================================================
# EPOCH 17/30
# ============================================================
# Epoch [17] Batch [10/114] Loss: 0.4030
# Epoch [17] Batch [20/114] Loss: 0.2836
# Epoch [17] Batch [30/114] Loss: 0.2301
# Epoch [17] Batch [40/114] Loss: 0.3500
# Epoch [17] Batch [50/114] Loss: 0.3556
# Epoch [17] Batch [60/114] Loss: 0.4302
# Epoch [17] Batch [70/114] Loss: 0.3306
# Epoch [17] Batch [80/114] Loss: 0.4220
# Epoch [17] Batch [90/114] Loss: 0.3525
# Epoch [17] Batch [100/114] Loss: 0.1623
# Epoch [17] Batch [110/114] Loss: 0.2900
#
# Training Loss: 0.3522
# Validation Loss: 0.3830
# Stepped scheduler. New LR: 0.000396
#
# ============================================================
# Epoch 17 - VAL
# ============================================================
# Accuracy:  0.8312
# Precision: 0.8328
# Recall:    0.8344
# F1 Score:  0.8311
#
# Confusion Matrix:
# [[523 137]
#  [ 70 496]]
#
# Per-Class Metrics:
#   cherry_clean:
#     Precision: 0.8820
#     Recall:    0.7924
#     F1:        0.8348
#   cherry_pit:
#     Precision: 0.7836
#     Recall:    0.8763
#     F1:        0.8274
# ============================================================
#
#
# Epoch completed in 4.9 seconds
#
# ============================================================
# EPOCH 18/30
# ============================================================
# Epoch [18] Batch [10/114] Loss: 0.4015
# Epoch [18] Batch [20/114] Loss: 0.2511
# Epoch [18] Batch [30/114] Loss: 0.4128
# Epoch [18] Batch [40/114] Loss: 0.3005
# Epoch [18] Batch [50/114] Loss: 0.3349
# Epoch [18] Batch [60/114] Loss: 0.2976
# Epoch [18] Batch [70/114] Loss: 0.2607
# Epoch [18] Batch [80/114] Loss: 0.3298
# Epoch [18] Batch [90/114] Loss: 0.4486
# Epoch [18] Batch [100/114] Loss: 0.3125
# Epoch [18] Batch [110/114] Loss: 0.2800
#
# Training Loss: 0.3534
# Validation Loss: 0.3794
# Stepped scheduler. New LR: 0.000345
#
# ============================================================
# Epoch 18 - VAL
# ============================================================
# Accuracy:  0.8303
# Precision: 0.8313
# Recall:    0.8331
# F1 Score:  0.8302
#
# Confusion Matrix:
# [[526 134]
#  [ 74 492]]
#
# Per-Class Metrics:
#   cherry_clean:
#     Precision: 0.8767
#     Recall:    0.7970
#     F1:        0.8349
#   cherry_pit:
#     Precision: 0.7859
#     Recall:    0.8693
#     F1:        0.8255
# ============================================================
#
#
# Epoch completed in 4.7 seconds
#
# ============================================================
# EPOCH 19/30
# ============================================================
# Epoch [19] Batch [10/114] Loss: 0.3748
# Epoch [19] Batch [20/114] Loss: 0.4276
# Epoch [19] Batch [30/114] Loss: 0.3502
# Epoch [19] Batch [40/114] Loss: 0.3245
# Epoch [19] Batch [50/114] Loss: 0.3009
# Epoch [19] Batch [60/114] Loss: 0.2779
# Epoch [19] Batch [70/114] Loss: 0.3801
# Epoch [19] Batch [80/114] Loss: 0.1824
# Epoch [19] Batch [90/114] Loss: 0.2231
# Epoch [19] Batch [100/114] Loss: 0.3569
# Epoch [19] Batch [110/114] Loss: 0.3162
#
# Training Loss: 0.3448
# Validation Loss: 0.3684
# Stepped scheduler. New LR: 0.000297
#
# ============================================================
# Epoch 19 - VAL
# ============================================================
# Accuracy:  0.8295
# Precision: 0.8285
# Recall:    0.8286
# F1 Score:  0.8285
#
# Confusion Matrix:
# [[555 105]
#  [104 462]]
#
# Per-Class Metrics:
#   cherry_clean:
#     Precision: 0.8422
#     Recall:    0.8409
#     F1:        0.8415
#   cherry_pit:
#     Precision: 0.8148
#     Recall:    0.8163
#     F1:        0.8155
# ============================================================
#
#
# Epoch completed in 4.9 seconds
#
# ============================================================
# EPOCH 20/30
# ============================================================
# Epoch [20] Batch [10/114] Loss: 0.2107
# Epoch [20] Batch [20/114] Loss: 0.3643
# Epoch [20] Batch [30/114] Loss: 0.3114
# Epoch [20] Batch [40/114] Loss: 0.2695
# Epoch [20] Batch [50/114] Loss: 0.3078
# Epoch [20] Batch [60/114] Loss: 0.2967
# Epoch [20] Batch [70/114] Loss: 0.3271
# Epoch [20] Batch [80/114] Loss: 0.3762
# Epoch [20] Batch [90/114] Loss: 0.3344
# Epoch [20] Batch [100/114] Loss: 0.3426
# Epoch [20] Batch [110/114] Loss: 0.2306
#
# Training Loss: 0.3390
# Validation Loss: 0.3691
# Stepped scheduler. New LR: 0.000250
#
# ============================================================
# Epoch 20 - VAL
# ============================================================
# Accuracy:  0.8377
# Precision: 0.8388
# Recall:    0.8344
# F1 Score:  0.8358
#
# Confusion Matrix:
# [[579  81]
#  [118 448]]
#
# Per-Class Metrics:
#   cherry_clean:
#     Precision: 0.8307
#     Recall:    0.8773
#     F1:        0.8534
#   cherry_pit:
#     Precision: 0.8469
#     Recall:    0.7915
#     F1:        0.8183
# ============================================================
#
# Checkpoint saved: /content/drive/MyDrive/cherry_experiments/dinov2_vits14_linear_probe_seed42/checkpoint_epoch_20.pt
# Model weights saved: /content/drive/MyDrive/cherry_experiments/dinov2_vits14_linear_probe_seed42/model_best.pt
#
# New best model saved! Validation accuracy: 0.8377
#
# Epoch completed in 5.1 seconds
#
# ============================================================
# EPOCH 21/30
# ============================================================
# Epoch [21] Batch [10/114] Loss: 0.2731
# Epoch [21] Batch [20/114] Loss: 0.3409
# Epoch [21] Batch [30/114] Loss: 0.3199
# Epoch [21] Batch [40/114] Loss: 0.2993
# Epoch [21] Batch [50/114] Loss: 0.2918
# Epoch [21] Batch [60/114] Loss: 0.4732
# Epoch [21] Batch [70/114] Loss: 0.3663
# Epoch [21] Batch [80/114] Loss: 0.3999
# Epoch [21] Batch [90/114] Loss: 0.2275
# Epoch [21] Batch [100/114] Loss: 0.3654
# Epoch [21] Batch [110/114] Loss: 0.3300
#
# Training Loss: 0.3332
# Validation Loss: 0.3653
# Stepped scheduler. New LR: 0.000206
#
# ============================================================
# Epoch 21 - VAL
# ============================================================
# Accuracy:  0.8312
# Precision: 0.8301
# Recall:    0.8306
# F1 Score:  0.8303
#
# Confusion Matrix:
# [[553 107]
#  [100 466]]
#
# Per-Class Metrics:
#   cherry_clean:
#     Precision: 0.8469
#     Recall:    0.8379
#     F1:        0.8423
#   cherry_pit:
#     Precision: 0.8133
#     Recall:    0.8233
#     F1:        0.8183
# ============================================================
#
#
# Epoch completed in 4.6 seconds
#
# ============================================================
# EPOCH 22/30
# ============================================================
# Epoch [22] Batch [10/114] Loss: 0.1841
# Epoch [22] Batch [20/114] Loss: 0.3580
# Epoch [22] Batch [30/114] Loss: 0.2126
# Epoch [22] Batch [40/114] Loss: 0.4030
# Epoch [22] Batch [50/114] Loss: 0.4136
# Epoch [22] Batch [60/114] Loss: 0.3370
# Epoch [22] Batch [70/114] Loss: 0.2361
# Epoch [22] Batch [80/114] Loss: 0.4884
# Epoch [22] Batch [90/114] Loss: 0.4398
# Epoch [22] Batch [100/114] Loss: 0.3239
# Epoch [22] Batch [110/114] Loss: 0.3788
#
# Training Loss: 0.3445
# Validation Loss: 0.3643
# Stepped scheduler. New LR: 0.000165
#
# ============================================================
# Epoch 22 - VAL
# ============================================================
# Accuracy:  0.8369
# Precision: 0.8359
# Recall:    0.8359
# F1 Score:  0.8359
#
# Confusion Matrix:
# [[560 100]
#  [100 466]]
#
# Per-Class Metrics:
#   cherry_clean:
#     Precision: 0.8485
#     Recall:    0.8485
#     F1:        0.8485
#   cherry_pit:
#     Precision: 0.8233
#     Recall:    0.8233
#     F1:        0.8233
# ============================================================
#
#
# Epoch completed in 4.8 seconds
#
# ============================================================
# EPOCH 23/30
# ============================================================
# Epoch [23] Batch [10/114] Loss: 0.3486
# Epoch [23] Batch [20/114] Loss: 0.2364
# Epoch [23] Batch [30/114] Loss: 0.3208
# Epoch [23] Batch [40/114] Loss: 0.3016
# Epoch [23] Batch [50/114] Loss: 0.4245
# Epoch [23] Batch [60/114] Loss: 0.3177
# Epoch [23] Batch [70/114] Loss: 0.3605
# Epoch [23] Batch [80/114] Loss: 0.4118
# Epoch [23] Batch [90/114] Loss: 0.3264
# Epoch [23] Batch [100/114] Loss: 0.4721
# Epoch [23] Batch [110/114] Loss: 0.4287
#
# Training Loss: 0.3441
# Validation Loss: 0.3636
# Stepped scheduler. New LR: 0.000128
#
# ============================================================
# Epoch 23 - VAL
# ============================================================
# Accuracy:  0.8369
# Precision: 0.8358
# Recall:    0.8370
# F1 Score:  0.8362
#
# Confusion Matrix:
# [[551 109]
#  [ 91 475]]
#
# Per-Class Metrics:
#   cherry_clean:
#     Precision: 0.8583
#     Recall:    0.8348
#     F1:        0.8464
#   cherry_pit:
#     Precision: 0.8134
#     Recall:    0.8392
#     F1:        0.8261
# ============================================================
#
#
# Epoch completed in 4.6 seconds
#
# ============================================================
# EPOCH 24/30
# ============================================================
# Epoch [24] Batch [10/114] Loss: 0.3104
# Epoch [24] Batch [20/114] Loss: 0.2674
# Epoch [24] Batch [30/114] Loss: 0.3291
# Epoch [24] Batch [40/114] Loss: 0.2180
# Epoch [24] Batch [50/114] Loss: 0.2659
# Epoch [24] Batch [60/114] Loss: 0.3885
# Epoch [24] Batch [70/114] Loss: 0.2979
# Epoch [24] Batch [80/114] Loss: 0.3778
# Epoch [24] Batch [90/114] Loss: 0.5466
# Epoch [24] Batch [100/114] Loss: 0.2979
# Epoch [24] Batch [110/114] Loss: 0.4925
#
# Training Loss: 0.3409
# Validation Loss: 0.3628
# Stepped scheduler. New LR: 0.000095
#
# ============================================================
# Epoch 24 - VAL
# ============================================================
# Accuracy:  0.8377
# Precision: 0.8366
# Recall:    0.8372
# F1 Score:  0.8369
#
# Confusion Matrix:
# [[557 103]
#  [ 96 470]]
#
# Per-Class Metrics:
#   cherry_clean:
#     Precision: 0.8530
#     Recall:    0.8439
#     F1:        0.8484
#   cherry_pit:
#     Precision: 0.8202
#     Recall:    0.8304
#     F1:        0.8253
# ============================================================
#
#
# Epoch completed in 4.8 seconds
#
# ============================================================
# EPOCH 25/30
# ============================================================
# Epoch [25] Batch [10/114] Loss: 0.3403
# Epoch [25] Batch [20/114] Loss: 0.3790
# Epoch [25] Batch [30/114] Loss: 0.3326
# Epoch [25] Batch [40/114] Loss: 0.3522
# Epoch [25] Batch [50/114] Loss: 0.2699
# Epoch [25] Batch [60/114] Loss: 0.2196
# Epoch [25] Batch [70/114] Loss: 0.3089
# Epoch [25] Batch [80/114] Loss: 0.3136
# Epoch [25] Batch [90/114] Loss: 0.3596
# Epoch [25] Batch [100/114] Loss: 0.3061
# Epoch [25] Batch [110/114] Loss: 0.3215
#
# Training Loss: 0.3378
# Validation Loss: 0.3643
# Stepped scheduler. New LR: 0.000067
#
# ============================================================
# Epoch 25 - VAL
# ============================================================
# Accuracy:  0.8393
# Precision: 0.8385
# Recall:    0.8403
# F1 Score:  0.8389
#
# Confusion Matrix:
# [[546 114]
#  [ 83 483]]
#
# Per-Class Metrics:
#   cherry_clean:
#     Precision: 0.8680
#     Recall:    0.8273
#     F1:        0.8472
#   cherry_pit:
#     Precision: 0.8090
#     Recall:    0.8534
#     F1:        0.8306
# ============================================================
#
# Checkpoint saved: /content/drive/MyDrive/cherry_experiments/dinov2_vits14_linear_probe_seed42/checkpoint_epoch_25.pt
# Model weights saved: /content/drive/MyDrive/cherry_experiments/dinov2_vits14_linear_probe_seed42/model_best.pt
#
# New best model saved! Validation accuracy: 0.8393
#
# Epoch completed in 5.1 seconds
#
# ============================================================
# EPOCH 26/30
# ============================================================
# Epoch [26] Batch [10/114] Loss: 0.3497
# Epoch [26] Batch [20/114] Loss: 0.3649
# Epoch [26] Batch [30/114] Loss: 0.3342
# Epoch [26] Batch [40/114] Loss: 0.5114
# Epoch [26] Batch [50/114] Loss: 0.3359
# Epoch [26] Batch [60/114] Loss: 0.3583
# Epoch [26] Batch [70/114] Loss: 0.2477
# Epoch [26] Batch [80/114] Loss: 0.3684
# Epoch [26] Batch [90/114] Loss: 0.2278
# Epoch [26] Batch [100/114] Loss: 0.3618
# Epoch [26] Batch [110/114] Loss: 0.5091
#
# Training Loss: 0.3415
# Validation Loss: 0.3631
# Stepped scheduler. New LR: 0.000043
#
# ============================================================
# Epoch 26 - VAL
# ============================================================
# Accuracy:  0.8377
# Precision: 0.8369
# Recall:    0.8363
# F1 Score:  0.8366
#
# Confusion Matrix:
# [[564  96]
#  [103 463]]
#
# Per-Class Metrics:
#   cherry_clean:
#     Precision: 0.8456
#     Recall:    0.8545
#     F1:        0.8500
#   cherry_pit:
#     Precision: 0.8283
#     Recall:    0.8180
#     F1:        0.8231
# ============================================================
#
#
# Epoch completed in 4.8 seconds
#
# ============================================================
# EPOCH 27/30
# ============================================================
# Epoch [27] Batch [10/114] Loss: 0.6396
# Epoch [27] Batch [20/114] Loss: 0.2975
# Epoch [27] Batch [30/114] Loss: 0.3024
# Epoch [27] Batch [40/114] Loss: 0.2949
# Epoch [27] Batch [50/114] Loss: 0.3476
# Epoch [27] Batch [60/114] Loss: 0.4771
# Epoch [27] Batch [70/114] Loss: 0.3495
# Epoch [27] Batch [80/114] Loss: 0.2999
# Epoch [27] Batch [90/114] Loss: 0.1798
# Epoch [27] Batch [100/114] Loss: 0.3305
# Epoch [27] Batch [110/114] Loss: 0.1730
#
# Training Loss: 0.3375
# Validation Loss: 0.3632
# Stepped scheduler. New LR: 0.000024
#
# ============================================================
# Epoch 27 - VAL
# ============================================================
# Accuracy:  0.8369
# Precision: 0.8358
# Recall:    0.8368
# F1 Score:  0.8362
#
# Confusion Matrix:
# [[553 107]
#  [ 93 473]]
#
# Per-Class Metrics:
#   cherry_clean:
#     Precision: 0.8560
#     Recall:    0.8379
#     F1:        0.8469
#   cherry_pit:
#     Precision: 0.8155
#     Recall:    0.8357
#     F1:        0.8255
# ============================================================
#
#
# Epoch completed in 4.8 seconds
#
# ============================================================
# EPOCH 28/30
# ============================================================
# Epoch [28] Batch [10/114] Loss: 0.2661
# Epoch [28] Batch [20/114] Loss: 0.4617
# Epoch [28] Batch [30/114] Loss: 0.5970
# Epoch [28] Batch [40/114] Loss: 0.3987
# Epoch [28] Batch [50/114] Loss: 0.1774
# Epoch [28] Batch [60/114] Loss: 0.4160
# Epoch [28] Batch [70/114] Loss: 0.3217
# Epoch [28] Batch [80/114] Loss: 0.2197
# Epoch [28] Batch [90/114] Loss: 0.1842
# Epoch [28] Batch [100/114] Loss: 0.2800
# Epoch [28] Batch [110/114] Loss: 0.4104
#
# Training Loss: 0.3418
# Validation Loss: 0.3630
# Stepped scheduler. New LR: 0.000011
#
# ============================================================
# Epoch 28 - VAL
# ============================================================
# Accuracy:  0.8377
# Precision: 0.8366
# Recall:    0.8374
# F1 Score:  0.8369
#
# Confusion Matrix:
# [[555 105]
#  [ 94 472]]
#
# Per-Class Metrics:
#   cherry_clean:
#     Precision: 0.8552
#     Recall:    0.8409
#     F1:        0.8480
#   cherry_pit:
#     Precision: 0.8180
#     Recall:    0.8339
#     F1:        0.8259
# ============================================================
#
#
# Epoch completed in 4.8 seconds
#
# ============================================================
# EPOCH 29/30
# ============================================================
# Epoch [29] Batch [10/114] Loss: 0.3424
# Epoch [29] Batch [20/114] Loss: 0.3978
# Epoch [29] Batch [30/114] Loss: 0.5231
# Epoch [29] Batch [40/114] Loss: 0.4973
# Epoch [29] Batch [50/114] Loss: 0.3795
# Epoch [29] Batch [60/114] Loss: 0.3980
# Epoch [29] Batch [70/114] Loss: 0.3040
# Epoch [29] Batch [80/114] Loss: 0.2786
# Epoch [29] Batch [90/114] Loss: 0.3894
# Epoch [29] Batch [100/114] Loss: 0.3300
# Epoch [29] Batch [110/114] Loss: 0.1992
#
# Training Loss: 0.3404
# Validation Loss: 0.3631
# Stepped scheduler. New LR: 0.000003
#
# ============================================================
# Epoch 29 - VAL
# ============================================================
# Accuracy:  0.8361
# Precision: 0.8351
# Recall:    0.8351
# F1 Score:  0.8351
#
# Confusion Matrix:
# [[559 101]
#  [100 466]]
#
# Per-Class Metrics:
#   cherry_clean:
#     Precision: 0.8483
#     Recall:    0.8470
#     F1:        0.8476
#   cherry_pit:
#     Precision: 0.8219
#     Recall:    0.8233
#     F1:        0.8226
# ============================================================
#
#
# Epoch completed in 4.8 seconds
#
# ============================================================
# EPOCH 30/30
# ============================================================
# Epoch [30] Batch [10/114] Loss: 0.2355
# Epoch [30] Batch [20/114] Loss: 0.4292
# Epoch [30] Batch [30/114] Loss: 0.3304
# Epoch [30] Batch [40/114] Loss: 0.5801
# Epoch [30] Batch [50/114] Loss: 0.3836
# Epoch [30] Batch [60/114] Loss: 0.4141
# Epoch [30] Batch [70/114] Loss: 0.2588
# Epoch [30] Batch [80/114] Loss: 0.5414
# Epoch [30] Batch [90/114] Loss: 0.5100
# Epoch [30] Batch [100/114] Loss: 0.4451
# Epoch [30] Batch [110/114] Loss: 0.4074
#
# Training Loss: 0.3376
# Validation Loss: 0.3631
# Stepped scheduler. New LR: 0.000000
#
# ============================================================
# Epoch 30 - VAL
# ============================================================
# Accuracy:  0.8361
# Precision: 0.8351
# Recall:    0.8350
# F1 Score:  0.8351
#
# Confusion Matrix:
# [[560 100]
#  [101 465]]
#
# Per-Class Metrics:
#   cherry_clean:
#     Precision: 0.8472
#     Recall:    0.8485
#     F1:        0.8478
#   cherry_pit:
#     Precision: 0.8230
#     Recall:    0.8216
#     F1:        0.8223
# ============================================================
#
# Checkpoint saved: /content/drive/MyDrive/cherry_experiments/dinov2_vits14_linear_probe_seed42/checkpoint_epoch_30.pt
#
# Epoch completed in 4.9 seconds
# Model weights saved: /content/drive/MyDrive/cherry_experiments/dinov2_vits14_linear_probe_seed42/model_final.pt
#
# ============================================================
# TRAINING COMPLETE
# ============================================================
# Final model saved to: /content/drive/MyDrive/cherry_experiments/dinov2_vits14_linear_probe_seed42/model_final.pt
# Best validation accuracy: 0.8393
# Logs saved to: /content/drive/MyDrive/cherry_experiments/dinov2_vits14_linear_probe_seed42/metrics.json
#
# ============================================================
# Training complete! Results: /content/drive/MyDrive/cherry_experiments/dinov2_vits14_linear_probe_seed42
#
# NOTE: DINOv2 inference may be slower than CNNs. If accurate but slow,
#       consider using it as a teacher for distillation.
# ============================================================

# %% [markdown]
# ## Cell 11: Experiment Summary
#
# View all completed experiments and their results.

# %%
print("\n" + "=" * 60)
print("EXPERIMENT SUMMARY - Phase 2 SOTA")
print("=" * 60)

import json
from pathlib import Path

base_path = Path(DRIVE_BASE_PATH)

print("\nCompleted Experiments:")
print("-" * 60)

results = []

# Check each experiment directory
for exp_dir in sorted(base_path.glob("*")):
    if exp_dir.is_dir():
        metrics_file = exp_dir / "metrics.json"
        model_file = exp_dir / "model_best.pt"

        if metrics_file.exists():
            # Read last line for final metrics
            with open(metrics_file) as f:
                lines = f.readlines()
                if lines:
                    try:
                        last_entry = json.loads(lines[-1])
                        acc = last_entry.get('accuracy', 'N/A')
                        epoch = last_entry.get('epoch', 'N/A')
                        phase = last_entry.get('phase', 'N/A')

                        if phase == 'val':
                            status = '✓' if model_file.exists() else '⚠'
                            print(f"{status} {exp_dir.name:45s} | Epoch {str(epoch):>2s} | Acc: {acc}")
                            results.append({
                                'name': exp_dir.name,
                                'accuracy': acc,
                                'epoch': epoch
                            })
                    except json.JSONDecodeError:
                        pass

print("-" * 60)

if results:
    print(f"\nTotal experiments completed: {len(results)}")

    # Find best accuracy
    valid_results = [r for r in results if isinstance(r['accuracy'], (int, float))]
    if valid_results:
        best = max(valid_results, key=lambda x: x['accuracy'])
        print(f"\nBest model: {best['name']}")
        print(f"Accuracy: {best['accuracy']:.2%}")

        # Identify Phase 2 experiments
        phase2_models = [r for r in valid_results if 'convnextv2' in r['name'] or 'dinov2' in r['name']]
        if phase2_models:
            best_p2 = max(phase2_models, key=lambda x: x['accuracy'])
            print(f"\nBest Phase 2 (SOTA) model: {best_p2['name']}")
            print(f"Accuracy: {best_p2['accuracy']:.2%}")
else:
    print("\nNo completed experiments found yet.")

print("\n" + "=" * 60)
print(f"All results saved to: {DRIVE_BASE_PATH}")
print("\nDownload these files for local analysis:")
print("  - model_best.pt (trained model weights)")
print("  - metrics.json (training history)")
print("  - config.yaml (experiment configuration)")
print("=" * 60)
# Out:
# ============================================================
# EXPERIMENT SUMMARY - Phase 2 SOTA
# ============================================================
#
# Completed Experiments:
# ------------------------------------------------------------
# ✓ convnextv2_tiny_baseline_seed42               | Epoch 30 | Acc: N/A
# ✓ convnextv2_tiny_label_smooth_seed42           | Epoch 30 | Acc: N/A
# ✓ dinov2_vits14_linear_probe_seed42             | Epoch 30 | Acc: N/A
# ✓ efficientnet_b2_baseline_seed42               | Epoch 30 | Acc: N/A
# ✓ efficientnet_b2_label_smooth_seed42           | Epoch 30 | Acc: N/A
# ------------------------------------------------------------
#
# Total experiments completed: 5
#
# ============================================================
# All results saved to: /content/drive/MyDrive/cherry_experiments
#
# Download these files for local analysis:
#   - model_best.pt (trained model weights)
#   - metrics.json (training history)
#   - config.yaml (experiment configuration)
# ============================================================

# %% [markdown]
# ## Cell 12: Model Comparison & Decision Matrix
#
# Compare all trained models and make deployment decision.

# %%
print("\n" + "=" * 60)
print("MODEL COMPARISON & DECISION MATRIX")
print("=" * 60)

# Find all model_best.pt files
model_files = list(Path(DRIVE_BASE_PATH).rglob("model_best.pt"))

print(f"\nFound {len(model_files)} trained model(s)")

if len(model_files) >= 1:
    print("\nModels available:")
    for i, model_path in enumerate(model_files, 1):
        exp_name = model_path.parent.name
        is_phase2 = 'convnextv2' in exp_name or 'dinov2' in exp_name
        marker = " [Phase 2 SOTA]" if is_phase2 else ""
        print(f"  {i}. {exp_name}{marker}")

    print("\n" + "=" * 60)
    print("DECISION CRITERIA:")
    print("=" * 60)
    print("Deploy if:")
    print("  ✓ Accuracy ≥ 94.05% (beats baseline)")
    print("  ✓ Latency < 30ms on CPU")
    print("  ✓ Pit recall ≥ 99.0% (food safety)")
    print("\nPhase 2 Priority:")
    print("  1. ConvNeXt V2-Tiny (best accuracy/speed tradeoff)")
    print("  2. DINOv2 (if accuracy > 95%, consider distillation)")
    print("  3. EfficientNet-B2 (if speed is critical)")

    print("\n" + "=" * 60)
    print("Next steps after training:")
    print("  1. Run local comparison: python scripts/compare_models.py")
    print("  2. Benchmark latency on production hardware")
    print("  3. Optimize thresholds for 3-class deployment")

print("=" * 60)
# Out:
# ============================================================
# MODEL COMPARISON & DECISION MATRIX
# ============================================================
#
# Found 5 trained model(s)
#
# Models available:
#   1. convnextv2_tiny_baseline_seed42 [Phase 2 SOTA]
#   2. convnextv2_tiny_label_smooth_seed42 [Phase 2 SOTA]
#   3. efficientnet_b2_baseline_seed42
#   4. efficientnet_b2_label_smooth_seed42
#   5. dinov2_vits14_linear_probe_seed42 [Phase 2 SOTA]
#
# ============================================================
# DECISION CRITERIA:
# ============================================================
# Deploy if:
#   ✓ Accuracy ≥ 94.05% (beats baseline)
#   ✓ Latency < 30ms on CPU
#   ✓ Pit recall ≥ 99.0% (food safety)
#
# Phase 2 Priority:
#   1. ConvNeXt V2-Tiny (best accuracy/speed tradeoff)
#   2. DINOv2 (if accuracy > 95%, consider distillation)
#   3. EfficientNet-B2 (if speed is critical)
#
# ============================================================
# Next steps after training:
#   1. Run local comparison: python scripts/compare_models.py
#   2. Benchmark latency on production hardware
#   3. Optimize thresholds for 3-class deployment
# ============================================================

# %% [markdown]
# ## Cell 13: Download Results
#
# Create download script for transferring results from Drive to local machine.

# %%
# Create download script
download_script = f"""
#!/bin/bash
# Download Phase 2 experiment results from Google Drive

# Source (Google Drive path)
DRIVE_SOURCE="{DRIVE_BASE_PATH}"

# Destination (local path)
LOCAL_DEST="./training/experiments"

echo "Downloading Phase 2 experiment results..."
echo "From: $DRIVE_SOURCE"
echo "To: $LOCAL_DEST"

# Create destination directory
mkdir -p $LOCAL_DEST

# Sync from Drive
rsync -av --progress "$DRIVE_SOURCE/" "$LOCAL_DEST/"

echo "Download complete!"
echo "\nPhase 2 models to evaluate:"
ls -lh $LOCAL_DEST/*/model_best.pt 2>/dev/null || echo "No models found"
"""

# Save script
script_path = f"{DRIVE_BASE_PATH}/download_phase2_results.sh"
with open(script_path, 'w') as f:
    f.write(download_script)

print("\n" + "=" * 60)
print("DOWNLOAD INSTRUCTIONS")
print("=" * 60)
print(f"Download script created: {script_path}")
print("\nTo download results to your local machine:")
print("1. Open a terminal on your local machine")
print("2. Navigate to your project root")
print("3. Run the download script:")
print(f"\n   bash {script_path}")
print("\nOr manually copy from Google Drive:")
print(f"   Source: {DRIVE_BASE_PATH}")
print("   Dest: ./training/experiments/")
print("=" * 60)
# Out:
# ============================================================
# DOWNLOAD INSTRUCTIONS
# ============================================================
# Download script created: /content/drive/MyDrive/cherry_experiments/download_phase2_results.sh
#
# To download results to your local machine:
# 1. Open a terminal on your local machine
# 2. Navigate to your project root
# 3. Run the download script:
#
#    bash /content/drive/MyDrive/cherry_experiments/download_phase2_results.sh
#
# Or manually copy from Google Drive:
#    Source: /content/drive/MyDrive/cherry_experiments
#    Dest: ./training/experiments/
# ============================================================

# %% [markdown]
# ---
#
# ## Summary
#
# This Phase 2 notebook implements state-of-the-art approaches based on external research:
#
# ### What's New
# 1. **ConvNeXt V2** - FCMAE pre-training for superior defect detection
# 2. **DINOv2** - Foundation model with linear probe (fast training, high accuracy)
# 3. **Enhanced Augmentations** - Motion blur + photometric distortion for conveyor realism
#
# ### Experiment Priority
# 1. **EXP-001** - Run first (CPU, immediate value)
# 2. **EXP-006A** - DINOv2 (fast, high potential)
# 3. **EXP-002A/B** - ConvNeXt V2 (main contender)
# 4. **EXP-003A/B** - EfficientNet (speed alternative)
#
# ### Success Criteria
# - **Minimum:** ≥94.05% accuracy (beat baseline)
# - **Target:** ≥94.5% accuracy
# - **Stretch:** ≥95% accuracy or <10ms latency
#
# ### References
# - [Experiment Specifications](../../docs/reference/EXPERIMENT_SPECIFICATIONS.md)
# - [Phase 2 Implementation Summary](../../docs/reference/PHASE2_IMPLEMENTATION_SUMMARY.md)
# - External Research: temp-external-research/claude.md, gemini.md, gpt.md
